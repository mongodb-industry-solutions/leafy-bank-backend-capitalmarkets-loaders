# %% [markdown]
# # Dataset: ashraq/financial-news
#
# Link:
# https://huggingface.co/datasets/ashraq/financial-news

# %%
# Install packages
# %pip install pandas fastparquet
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 684.1/684.1 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 15.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_parquet("hf://datasets/ashraq/financial-news/data/train-00000-of-00001-8ec327f23bbe0948.parquet")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Github/mongodb/mongodb-industry-solutions/leafy-bank-backend-capitalmarkets/.venv/lib/python3.10/site-packages/fsspec/registry.py:246, in get_filesystem_class(protocol)
#     245 try:
# --> 246     register_implementation(protocol, _import_class(bit["class"]))
#     247 except ImportError as e:
#
# File ~/Github/mongodb/mongodb-industry-solutions/leafy-bank-backend-capitalmarkets/.venv/lib/python3.10/site-packages/fsspec/registry.py:281, in _import_class(fqp)
#     280 is_s3 = mod == "s3fs"
# --> 281 mod = importlib.import_module(mod)
#     282 if is_s3 and mod.__version__.split(".") < ["0", "5"]:
#
# File /opt/homebrew/Cellar/python@3.10/3.10.15/Frameworks/Python.framework/Versions/3.10/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# ...
