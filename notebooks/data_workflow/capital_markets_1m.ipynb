# %% [markdown]
# # Capital Markets Workflow (Simplified)

# %%
# 02/24/2025 12:08:00

# %%
# Install packages
# %pip install -U --quiet yfinance pandas 
# %pip install -U --quiet langgraph langchain-community langchain-aws langchain-mongodb
# %pip install -U --quiet pymongo
# %pip install -U --quiet python-dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Set environment variables

# %%
from dotenv import load_dotenv
import os

# Load environment variables
load_dotenv()

# Set environment variables
MONGODB_URI = os.getenv("MONGODB_URI")
AWS_REGION = os.getenv("AWS_REGION")
AWS_ACCESS_KEY_ID = os.getenv("AWS_ACCESS_KEY_ID")
AWS_SECRET_ACCESS_KEY = os.getenv("AWS_SECRET_ACCESS_KEY")

# Set database name
DATABASE_NAME = "agentic_capital_markets"

# %% [markdown]
# ## Getting Market Data from yfinance
#
# ### yfinance documentation
# https://ranaroussi.github.io/yfinance/reference/
#
# Yahoo!, Y!Finance, and Yahoo! finance are registered trademarks of Yahoo, Inc.
#
# yfinance is not affiliated, endorsed, or vetted by Yahoo, Inc. It’s an open-source tool that uses Yahoo’s publicly available APIs, and is intended for research and educational purposes.
#
# You should refer to Yahoo!’s terms of use (here), (here), and (here) for details on your rights to use the actual data downloaded. Remember - the Yahoo! finance API is intended for personal use only.

# %% [markdown]
# ## Important note
#
# ### $SPY: possibly delisted; no price data found  (period=2y) (Yahoo error = "1m data not available for startTime=1676894054 and endTime=1739966054. Only 8 days worth of 1m granularity data are allowed to be fetched per request.")

# %%
# Import libraries
import pandas as pd
import yfinance as yf

# %% [markdown]
# https://stackoverflow.com/questions/76605981/can-not-download-6-months-tsla-with-interval-of-1-minute-in-yfinance

# %% [markdown]
# ### Getting equities data

# %%
EQUITIES = 'SPY QQQ EEM XLE'

equities = yf.Tickers(EQUITIES)

# period='max' equals to 1 week

spy = equities.tickers['SPY'].history(period='max', interval='1m').drop(columns=['Dividends', 'Stock Splits', 'Capital Gains'])
qqq = equities.tickers['QQQ'].history(period='max', interval='1m').drop(columns=['Dividends', 'Stock Splits', 'Capital Gains'])
eem = equities.tickers['EEM'].history(period='max', interval='1m').drop(columns=['Dividends', 'Stock Splits', 'Capital Gains'])
xle = equities.tickers['XLE'].history(period='max', interval='1m').drop(columns=['Dividends', 'Stock Splits', 'Capital Gains'])

spy.tail(5)
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2025-02-21 15:55:00-05:00  600.359985  600.489990  600.140015  600.169983
# 2025-02-21 15:56:00-05:00  600.179993  600.239014  599.500000  599.799988
# 2025-02-21 15:57:00-05:00  599.799988  599.950012  599.659973  599.840027
# 2025-02-21 15:58:00-05:00  599.820007  600.044983  599.789978  599.979980
# 2025-02-21 15:59:00-05:00  599.989990  600.114990  599.520020  600.000000
#
#                             Volume
# Datetime
# 2025-02-21 15:55:00-05:00   522217
# 2025-02-21 15:56:00-05:00   468964
# 2025-02-21 15:57:00-05:00   750453
# 2025-02-21 15:58:00-05:00   534184
# 2025-02-21 15:59:00-05:00  1648981

# %%
spy.head(5)

# starting date with 1m data
# 2025-02-18 09:30:00-05:00
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2025-02-18 09:30:00-05:00  610.880005  611.000000  610.594971  610.872375
# 2025-02-18 09:31:00-05:00  610.890015  610.924988  610.380005  610.465027
# 2025-02-18 09:32:00-05:00  610.450012  610.780029  610.400024  610.710022
# 2025-02-18 09:33:00-05:00  610.705017  610.840027  610.650024  610.700012
# 2025-02-18 09:34:00-05:00  610.700012  610.760010  610.554993  610.659729
#
#                            Volume
# Datetime
# 2025-02-18 09:30:00-05:00  924797
# 2025-02-18 09:31:00-05:00  169403
# 2025-02-18 09:32:00-05:00  133589
# 2025-02-18 09:33:00-05:00   89924
# 2025-02-18 09:34:00-05:00   77008

# %% [markdown]
# ### Getting Bonds (U.S. Treasuries) data

# %%
BONDS = 'TLT LQD HYG'

bonds = yf.Tickers(BONDS)

tlt = bonds.tickers['TLT'].history(period='max', interval='1m').drop(columns=['Dividends', 'Stock Splits', 'Capital Gains'])
lqd = bonds.tickers['LQD'].history(period='max', interval='1m').drop(columns=['Dividends', 'Stock Splits', 'Capital Gains'])
hyg = bonds.tickers['HYG'].history(period='max', interval='1m').drop(columns=['Dividends', 'Stock Splits', 'Capital Gains'])

tlt.tail(5)
# Out:
#                                 Open       High        Low      Close   Volume
# Datetime
# 2025-02-21 15:55:00-05:00  89.669998  89.669998  89.625000  89.635002   460046
# 2025-02-21 15:56:00-05:00  89.637299  89.660004  89.629997  89.640701   424624
# 2025-02-21 15:57:00-05:00  89.639999  89.639999  89.589996  89.620003   426289
# 2025-02-21 15:58:00-05:00  89.625000  89.629997  89.595001  89.595001   485722
# 2025-02-21 15:59:00-05:00  89.595001  89.620003  89.550102  89.599998  1247116

# %% [markdown]
# ### Getting Commodities data (Gold, Oil, etc.)

# %%
COMMODITIES = 'GLD USO'

commodities = yf.Tickers(COMMODITIES)

gld = commodities.tickers['GLD'].history(period='max', interval='1m').drop(columns=['Dividends', 'Stock Splits', 'Capital Gains'])
uso = commodities.tickers['USO'].history(period='max', interval='1m').drop(columns=['Dividends', 'Stock Splits', 'Capital Gains'])

gld.tail(5)
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2025-02-21 15:55:00-05:00  270.809998  270.820007  270.739990  270.779999
# 2025-02-21 15:56:00-05:00  270.769989  270.795013  270.720001  270.779999
# 2025-02-21 15:57:00-05:00  270.765015  270.779999  270.700012  270.725006
# 2025-02-21 15:58:00-05:00  270.725006  270.859985  270.709991  270.809998
# 2025-02-21 15:59:00-05:00  270.809998  270.820007  270.730011  270.779999
#
#                            Volume
# Datetime
# 2025-02-21 15:55:00-05:00   63322
# 2025-02-21 15:56:00-05:00   41921
# 2025-02-21 15:57:00-05:00   75099
# 2025-02-21 15:58:00-05:00   84496
# 2025-02-21 15:59:00-05:00   70330

# %% [markdown]
# ### Getting Market Volatility Index data

# %%
MARKET_VOLATILITY = '^VIX'

market_volatility = yf.Tickers(MARKET_VOLATILITY)

vix = market_volatility.tickers['^VIX'].history(period='max', interval='1m').drop(columns=['Dividends', 'Stock Splits'])

vix.tail(5)
# Out:
#                             Open       High    Low      Close  Volume
# Datetime
# 2025-02-24 04:49:00-06:00  17.68  17.680000  17.68  17.680000       0
# 2025-02-24 04:50:00-06:00  17.68  17.680000  17.67  17.670000       0
# 2025-02-24 04:51:00-06:00  17.67  17.680000  17.67  17.680000       0
# 2025-02-24 04:52:00-06:00  17.68  17.700001  17.68  17.690001       0
# 2025-02-24 04:53:00-06:00  17.68  17.680000  17.68  17.680000       0

# %% [markdown]
# ## We can leverage Scheduled Triggers in MongoDB Atlas to run the script at a specific recurring time.
#
# Scheduled Triggers allow you to execute server-side logic on a regular schedule that you define. You can use scheduled Triggers to do work that happens on a periodic basis, such as updating a document every minute, generating a nightly report, or sending an automated weekly email newsletter.
#
# https://www.mongodb.com/docs/atlas/atlas-ui/triggers/scheduled-triggers/
#
# ## We can leverage Atlas Functions as well
#
# An Atlas Function is a piece of server-side JavaScript code that you write to define your app's behavior. You can call your app's Functions directly from a client app or define services that integrate and call Functions automatically.
#
# Functions can call other Functions and include a built-in client for working with data in MongoDB Atlas clusters. They also include helpful global utilities, support common Node.js built-in modules, and can import and use external packages from the npm registry.
#
# https://www.mongodb.com/docs/atlas/atlas-ui/triggers/functions/
#
# Video Tutorial: https://www.youtube.com/watch?v=3Q6J1J1JZ3A

# %% [markdown]
# ## MongoDB Database Setup

# %%
# Import libraries
from pymongo import MongoClient, ASCENDING

# %%
DATABASE_NAME = "agentic_capital_markets"

def get_mongo_client(mongo_uri):
    """Establish connection to the MongoDB and ping the database."""

    # gateway to interacting with a MongoDB database cluster
    client = MongoClient(mongo_uri, appname="ist.demo.agentic_capital_markets.python", tz_aware=True)

    # Ping the database to ensure the connection is successful
    try:
        client.admin.command("ping")
        print("Connection to MongoDB successful")
    except Exception as e:
        print(f"Error connecting to MongoDB: {e}")
        return None

    return client


if not MONGODB_URI:
    print("MONGO_URI not set in environment variables")

mongo_client = get_mongo_client(MONGODB_URI)

if mongo_client:
    # Pymongo client of database
    db = mongo_client.get_database(DATABASE_NAME)
else:
    print("Failed to connect to MongoDB. Exiting...")
    exit(1)
# Out:
# Connection to MongoDB successful

# %% [markdown]
# ### Create Timeseries Collection

# %%
# Check if the 'yfinanceMarketData' collection exists
if "yfinanceMarketData" in db.list_collection_names():
    db.yfinanceMarketData.drop()  # ⚠️ This will delete all data!

from bson.codec_options import CodecOptions
from bson.datetime_ms import DatetimeConversion

# For more information on datetime conversion options, see:
# https://www.mongodb.com/docs/languages/python/pymongo-driver/current/data-formats/dates-and-times/
codec_options = CodecOptions(datetime_conversion=DatetimeConversion.DATETIME_AUTO)

# Check if the 'yfinanceMarketData' collection exists
if "yfinanceMarketData" not in db.list_collection_names():
    # Create the collection with a time-series configuration
    db.create_collection(
        "yfinanceMarketData",
        timeseries={
            "timeField": "timestamp",
            "metaField": "symbol",
            "granularity": "minutes"
        },
        codec_options=codec_options
        # expireAfterSeconds=604800  # Document expires 7 days (604800 seconds)
    )
    
    # Create an index on the `symbol` and `timestamp` fields
    db.yfinanceMarketData.create_index(
        [("symbol", ASCENDING), ("timestamp", ASCENDING)]
    )
    
    print("Collection and index created successfully.")
else:
    print("The 'yfinanceMarketData' collection already exists.")
# Out:
# Collection and index created successfully.

# %% [markdown]
# ## Data Ingestion

# %%
# Checking pandas DataFrame info
spy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1557 entries, 2025-02-18 09:30:00-05:00 to 2025-02-21 15:59:00-05:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1557 non-null   float64
#  1   High    1557 non-null   float64
#  2   Low     1557 non-null   float64
#  3   Close   1557 non-null   float64
#  4   Volume  1557 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 73.0 KB

# %% [markdown]
# ###  Transformations

# %%
from datetime import datetime
import pytz


def transform_data(symbol, df):
    """
    Transforms the given DataFrame by performing the following operations:
        - Reset the index (Datetime) and rename it to 'timestamp'.
        - Add a new column 'symbol' with the given value.
        - Convert all column names to lowercase.
        - Reorder columns as 'timestamp', 'symbol', 'open', 'high', 'low', 'close', 'volume'.
        - Convert 'timestamp' to UTC timezone if not already.
    Parameters:
        - symbol (str): The symbol name to be added in the 'symbol' column.
        - df (pd.DataFrame): The input DataFrame with 'Datetime' as the index.
    Returns:
        - pd.DataFrame: Transformed DataFrame.
    """
    # Reset index and explicitly rename 'Datetime' to 'timestamp'
    df = df.reset_index().rename(columns={'Datetime': 'timestamp'})

    # Convert timestamp to datetime if not already
    df['timestamp'] = pd.to_datetime(df['timestamp'])

    # Ensure timestamp is localized to US/Eastern only if it’s naive (has no timezone)
    if df['timestamp'].dt.tz is None:
        eastern = pytz.timezone('US/Eastern')
        df['timestamp'] = df['timestamp'].dt.tz_localize(
            eastern, ambiguous='NaT', nonexistent='shift_forward')

    # Convert 'timestamp' to UTC
    df['timestamp'] = df['timestamp'].dt.tz_convert('UTC')

    # Add the 'symbol' column
    df['symbol'] = symbol

    # Convert all column names to lowercase
    df.columns = df.columns.str.lower()

    # Reorder columns
    df = df[['timestamp', 'symbol', 'open', 'high', 'low', 'close', 'volume']]

    return df

# %%
# Equity transformation - SPY as example
df_spy = transform_data('SPY-USD', spy)
df_spy.head()
# Out:
#                   timestamp   symbol        open        high         low  \
# 0 2025-02-18 14:30:00+00:00  SPY-USD  610.880005  611.000000  610.594971
# 1 2025-02-18 14:31:00+00:00  SPY-USD  610.890015  610.924988  610.380005
# 2 2025-02-18 14:32:00+00:00  SPY-USD  610.450012  610.780029  610.400024
# 3 2025-02-18 14:33:00+00:00  SPY-USD  610.705017  610.840027  610.650024
# 4 2025-02-18 14:34:00+00:00  SPY-USD  610.700012  610.760010  610.554993
#
#         close  volume
# 0  610.872375  924797
# 1  610.465027  169403
# 2  610.710022  133589
# 3  610.700012   89924
# 4  610.659729   77008

# %%
df_spy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1557 entries, 0 to 1556
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  1557 non-null   datetime64[ns, UTC]
#  1   symbol     1557 non-null   object
#  2   open       1557 non-null   float64
#  3   high       1557 non-null   float64
#  4   low        1557 non-null   float64
#  5   close      1557 non-null   float64
#  6   volume     1557 non-null   int64
# dtypes: datetime64[ns, UTC](1), float64(4), int64(1), object(1)
# memory usage: 85.3+ KB

# %%
# Equity transformations
df_qqq = transform_data('QQQ-USD', qqq)
df_eem = transform_data('EEM-USD', eem)
df_xle = transform_data('XLE-USD', xle)

# Bonds transformations
df_tlt = transform_data('TLT-USD', tlt)
df_lqd = transform_data('LQD-USD', lqd)
df_hyg = transform_data('HYG-USD', hyg)

# Commodities transformations
df_gld = transform_data('GLD-USD', gld)
df_uso = transform_data('USO-USD', uso)

# Market Volatility transformations
df_vix = transform_data('VIX-USD', vix)

# %%
df_uso.sort_index(ascending=False).head()
# Out:
#                      timestamp   symbol       open       high        low  \
# 1521 2025-02-21 20:59:00+00:00  USO-USD  75.349998  75.364998  75.339996
# 1520 2025-02-21 20:58:00+00:00  USO-USD  75.360001  75.379997  75.339996
# 1519 2025-02-21 20:57:00+00:00  USO-USD  75.355003  75.379997  75.349998
# 1518 2025-02-21 20:56:00+00:00  USO-USD  75.410004  75.410004  75.349998
# 1517 2025-02-21 20:55:00+00:00  USO-USD  75.445000  75.445000  75.410004
#
#           close  volume
# 1521  75.349998   45524
# 1520  75.355003   69943
# 1519  75.355003   53837
# 1518  75.355003   58335
# 1517  75.415001   36443

# %% [markdown]
# ### Clean Data

# %%
# Ensure that the collection is empty by deleting all documents
db.yfinanceMarketData.delete_many({})

print("The 'yfinanceMarketData' collection is now empty.")
# Out:
# The 'yfinanceMarketData' collection is now empty.

# %% [markdown]
# ### Insert data into MongoDB time series collection

# %%
# df_spy sort by timestamp in ascending order
df_spy = df_spy.sort_index(ascending=True)
df_spy.tail(20)
# Out:
#                      timestamp   symbol        open        high         low  \
# 1537 2025-02-21 20:40:00+00:00  SPY-USD  600.590027  600.690002  600.460022
# 1538 2025-02-21 20:41:00+00:00  SPY-USD  600.465027  600.465027  600.159973
# 1539 2025-02-21 20:42:00+00:00  SPY-USD  600.320007  600.340027  600.070007
# 1540 2025-02-21 20:43:00+00:00  SPY-USD  600.440002  600.460022  600.070007
# 1541 2025-02-21 20:44:00+00:00  SPY-USD  600.459106  600.510010  600.034973
# 1542 2025-02-21 20:45:00+00:00  SPY-USD  600.059998  600.070007  599.799988
# 1543 2025-02-21 20:46:00+00:00  SPY-USD  599.960022  600.020020  599.710022
# 1544 2025-02-21 20:47:00+00:00  SPY-USD  599.780029  599.950012  599.780029
# 1545 2025-02-21 20:48:00+00:00  SPY-USD  599.890015  600.109985  599.859985
# 1546 2025-02-21 20:49:00+00:00  SPY-USD  600.070007  600.340027  600.000000
# 1547 2025-02-21 20:50:00+00:00  SPY-USD  600.169983  600.539978  600.130005
# 1548 2025-02-21 20:51:00+00:00  SPY-USD  600.150024  600.390015  600.059998
# 1549 2025-02-21 20:52:00+00:00  SPY-USD  600.380005  600.429993  600.109985
# 1550 2025-02-21 20:53:00+00:00  SPY-USD  600.239990  600.299988  599.969971
# 1551 2025-02-21 20:54:00+00:00  SPY-USD  600.020020  600.429993  599.940002
# 1552 2025-02-21 20:55:00+00:00  SPY-USD  600.359985  600.489990  600.140015
# 1553 2025-02-21 20:56:00+00:00  SPY-USD  600.179993  600.239014  599.500000
# 1554 2025-02-21 20:57:00+00:00  SPY-USD  599.799988  599.950012  599.659973
# 1555 2025-02-21 20:58:00+00:00  SPY-USD  599.820007  600.044983  599.789978
# 1556 2025-02-21 20:59:00+00:00  SPY-USD  599.989990  600.114990  599.520020
#
#            close   volume
# 1537  600.469971   112230
# 1538  600.330017   232625
# 1539  600.075012   394448
# 1540  600.440002   243765
# 1541  600.039978   580507
# 1542  599.955017   332241
# 1543  599.789978   263789
# 1544  599.890015   323456
# 1545  600.064026   374513
# 1546  600.179993   316901
# 1547  600.169983   282292
# 1548  600.380005   541824
# 1549  600.250000   446204
# 1550  600.015015   304306
# 1551  600.369995   363190
# 1552  600.169983   522217
# 1553  599.799988   468964
# 1554  599.840027   750453
# 1555  599.979980   534184
# 1556  600.000000  1648981

# %%
# df_spy sort by timestamp in descending order
df_spy = df_spy.sort_index(ascending=False)
df_spy.tail(20)
# Out:
#                    timestamp   symbol        open        high         low  \
# 19 2025-02-18 14:49:00+00:00  SPY-USD  610.299988  610.369995  610.219971
# 18 2025-02-18 14:48:00+00:00  SPY-USD  610.043823  610.330017  610.043823
# 17 2025-02-18 14:47:00+00:00  SPY-USD  610.179993  610.199890  609.960022
# 16 2025-02-18 14:46:00+00:00  SPY-USD  610.200012  610.460022  610.109985
# 15 2025-02-18 14:45:00+00:00  SPY-USD  610.184998  610.414978  610.169983
# 14 2025-02-18 14:44:00+00:00  SPY-USD  610.489990  610.580017  610.099976
# 13 2025-02-18 14:43:00+00:00  SPY-USD  610.539978  610.609985  610.469971
# 12 2025-02-18 14:42:00+00:00  SPY-USD  610.640015  610.729126  610.530029
# 11 2025-02-18 14:41:00+00:00  SPY-USD  610.590027  610.659973  610.479980
# 10 2025-02-18 14:40:00+00:00  SPY-USD  610.750000  610.801575  610.590027
# 9  2025-02-18 14:39:00+00:00  SPY-USD  610.690002  610.760010  610.622803
# 8  2025-02-18 14:38:00+00:00  SPY-USD  610.680115  610.849976  610.599976
# 7  2025-02-18 14:37:00+00:00  SPY-USD  610.539795  610.707520  610.289978
# 6  2025-02-18 14:36:00+00:00  SPY-USD  610.650024  610.710022  610.500000
# 5  2025-02-18 14:35:00+00:00  SPY-USD  610.679993  610.739990  610.609985
# 4  2025-02-18 14:34:00+00:00  SPY-USD  610.700012  610.760010  610.554993
# 3  2025-02-18 14:33:00+00:00  SPY-USD  610.705017  610.840027  610.650024
# 2  2025-02-18 14:32:00+00:00  SPY-USD  610.450012  610.780029  610.400024
# 1  2025-02-18 14:31:00+00:00  SPY-USD  610.890015  610.924988  610.380005
# 0  2025-02-18 14:30:00+00:00  SPY-USD  610.880005  611.000000  610.594971
#
#          close  volume
# 19  610.269897   60436
# 18  610.280029  100997
# 17  610.039917   81853
# 16  610.200012   72192
# 15  610.190002  129269
# 14  610.180115  101647
# 13  610.509888   80958
# 12  610.562988   45173
# 11  610.629883   63679
# 10  610.619019   61119
# 9   610.760010   49130
# 8   610.700012   95724
# 7   610.700012   98946
# 6   610.544983   56562
# 5   610.655029   79603
# 4   610.659729   77008
# 3   610.700012   89924
# 2   610.710022  133589
# 1   610.465027  169403
# 0   610.872375  924797

# %%
# Pandas DataFrame to dictionary, example with SPY
spy_records = df_spy.to_dict(orient="records")
spy_records
# Out:
# [{'timestamp': Timestamp('2025-02-21 20:59:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.989990234375,
#   'high': 600.114990234375,
#   'low': 599.52001953125,
#   'close': 600.0,
#   'volume': 1648981},
#  {'timestamp': Timestamp('2025-02-21 20:58:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.8200073242188,
#   'high': 600.0449829101562,
#   'low': 599.7899780273438,
#   'close': 599.97998046875,
#   'volume': 534184},
#  {'timestamp': Timestamp('2025-02-21 20:57:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.7999877929688,
#   'high': 599.9500122070312,
#   'low': 599.6599731445312,
#   'close': 599.8400268554688,
#   'volume': 750453},
#  {'timestamp': Timestamp('2025-02-21 20:56:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.1799926757812,
#   'high': 600.239013671875,
#   'low': 599.5,
#   'close': 599.7999877929688,
#   'volume': 468964},
#  {'timestamp': Timestamp('2025-02-21 20:55:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.3599853515625,
#   'high': 600.489990234375,
#   'low': 600.1400146484375,
#   'close': 600.1699829101562,
#   'volume': 522217},
#  {'timestamp': Timestamp('2025-02-21 20:54:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.02001953125,
#   'high': 600.4299926757812,
#   'low': 599.9400024414062,
#   'close': 600.3699951171875,
#   'volume': 363190},
#  {'timestamp': Timestamp('2025-02-21 20:53:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.239990234375,
#   'high': 600.2999877929688,
#   'low': 599.969970703125,
#   'close': 600.0150146484375,
#   'volume': 304306},
#  {'timestamp': Timestamp('2025-02-21 20:52:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.3800048828125,
#   'high': 600.4299926757812,
#   'low': 600.1099853515625,
#   'close': 600.25,
#   'volume': 446204},
#  {'timestamp': Timestamp('2025-02-21 20:51:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.1500244140625,
#   'high': 600.3900146484375,
#   'low': 600.0599975585938,
#   'close': 600.3800048828125,
#   'volume': 541824},
#  {'timestamp': Timestamp('2025-02-21 20:50:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.1699829101562,
#   'high': 600.5399780273438,
#   'low': 600.1300048828125,
#   'close': 600.1699829101562,
#   'volume': 282292},
#  {'timestamp': Timestamp('2025-02-21 20:49:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.0700073242188,
#   'high': 600.3400268554688,
#   'low': 600.0,
#   'close': 600.1799926757812,
#   'volume': 316901},
#  {'timestamp': Timestamp('2025-02-21 20:48:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.8900146484375,
#   'high': 600.1099853515625,
#   'low': 599.8599853515625,
#   'close': 600.0640258789062,
#   'volume': 374513},
#  {'timestamp': Timestamp('2025-02-21 20:47:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.780029296875,
#   'high': 599.9500122070312,
#   'low': 599.780029296875,
#   'close': 599.8900146484375,
#   'volume': 323456},
#  {'timestamp': Timestamp('2025-02-21 20:46:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.9600219726562,
#   'high': 600.02001953125,
#   'low': 599.7100219726562,
#   'close': 599.7899780273438,
#   'volume': 263789},
#  {'timestamp': Timestamp('2025-02-21 20:45:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.0599975585938,
#   'high': 600.0700073242188,
#   'low': 599.7999877929688,
#   'close': 599.9550170898438,
#   'volume': 332241},
#  {'timestamp': Timestamp('2025-02-21 20:44:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.4591064453125,
#   'high': 600.510009765625,
#   'low': 600.0349731445312,
#   'close': 600.0399780273438,
#   'volume': 580507},
#  {'timestamp': Timestamp('2025-02-21 20:43:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.4400024414062,
#   'high': 600.4600219726562,
#   'low': 600.0700073242188,
#   'close': 600.4400024414062,
#   'volume': 243765},
#  {'timestamp': Timestamp('2025-02-21 20:42:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.3200073242188,
#   'high': 600.3400268554688,
#   'low': 600.0700073242188,
#   'close': 600.0750122070312,
#   'volume': 394448},
#  {'timestamp': Timestamp('2025-02-21 20:41:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.4650268554688,
#   'high': 600.4650268554688,
#   'low': 600.1599731445312,
#   'close': 600.3300170898438,
#   'volume': 232625},
#  {'timestamp': Timestamp('2025-02-21 20:40:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.5900268554688,
#   'high': 600.6900024414062,
#   'low': 600.4600219726562,
#   'close': 600.469970703125,
#   'volume': 112230},
#  {'timestamp': Timestamp('2025-02-21 20:39:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.5700073242188,
#   'high': 600.6599731445312,
#   'low': 600.4550170898438,
#   'close': 600.5900268554688,
#   'volume': 144623},
#  {'timestamp': Timestamp('2025-02-21 20:38:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.489990234375,
#   'high': 600.6099243164062,
#   'low': 600.3707885742188,
#   'close': 600.5700073242188,
#   'volume': 101666},
#  {'timestamp': Timestamp('2025-02-21 20:37:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.489990234375,
#   'high': 600.489990234375,
#   'low': 600.2507934570312,
#   'close': 600.489990234375,
#   'volume': 304382},
#  {'timestamp': Timestamp('2025-02-21 20:36:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.52001953125,
#   'high': 600.6500244140625,
#   'low': 600.494384765625,
#   'close': 600.494384765625,
#   'volume': 124185},
#  {'timestamp': Timestamp('2025-02-21 20:35:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.6599731445312,
#   'high': 600.739990234375,
#   'low': 600.469970703125,
#   'close': 600.510009765625,
#   'volume': 119553},
#  {'timestamp': Timestamp('2025-02-21 20:34:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.6599731445312,
#   'high': 600.760009765625,
#   'low': 600.5999755859375,
#   'close': 600.6699829101562,
#   'volume': 171839},
#  {'timestamp': Timestamp('2025-02-21 20:33:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.72998046875,
#   'high': 600.7999877929688,
#   'low': 600.5900268554688,
#   'close': 600.6300048828125,
#   'volume': 126159},
#  {'timestamp': Timestamp('2025-02-21 20:32:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.4199829101562,
#   'high': 600.739990234375,
#   'low': 600.4099731445312,
#   'close': 600.719970703125,
#   'volume': 145336},
#  {'timestamp': Timestamp('2025-02-21 20:31:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.8200073242188,
#   'high': 600.9099731445312,
#   'low': 600.3699951171875,
#   'close': 600.419921875,
#   'volume': 169144},
#  {'timestamp': Timestamp('2025-02-21 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.5800170898438,
#   'high': 600.9000244140625,
#   'low': 600.4600219726562,
#   'close': 600.8900146484375,
#   'volume': 199799},
#  {'timestamp': Timestamp('2025-02-21 20:29:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.5,
#   'high': 600.6199951171875,
#   'low': 600.430908203125,
#   'close': 600.5599975585938,
#   'volume': 116280},
#  {'timestamp': Timestamp('2025-02-21 20:28:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.489990234375,
#   'high': 600.6400146484375,
#   'low': 600.4299926757812,
#   'close': 600.489990234375,
#   'volume': 112729},
#  {'timestamp': Timestamp('2025-02-21 20:27:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.47998046875,
#   'high': 600.5999755859375,
#   'low': 600.3049926757812,
#   'close': 600.4400024414062,
#   'volume': 149572},
#  {'timestamp': Timestamp('2025-02-21 20:26:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.489990234375,
#   'high': 600.5599975585938,
#   'low': 600.3400268554688,
#   'close': 600.489990234375,
#   'volume': 95291},
#  {'timestamp': Timestamp('2025-02-21 20:25:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.6099853515625,
#   'high': 600.6300048828125,
#   'low': 600.2899780273438,
#   'close': 600.47998046875,
#   'volume': 119057},
#  {'timestamp': Timestamp('2025-02-21 20:24:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.47998046875,
#   'high': 600.6400146484375,
#   'low': 600.47998046875,
#   'close': 600.5900268554688,
#   'volume': 211458},
#  {'timestamp': Timestamp('2025-02-21 20:23:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.2999877929688,
#   'high': 600.47998046875,
#   'low': 600.1400756835938,
#   'close': 600.4699096679688,
#   'volume': 85986},
#  {'timestamp': Timestamp('2025-02-21 20:22:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.3599853515625,
#   'high': 600.389892578125,
#   'low': 600.2000122070312,
#   'close': 600.3300170898438,
#   'volume': 113416},
#  {'timestamp': Timestamp('2025-02-21 20:21:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.239990234375,
#   'high': 600.3800048828125,
#   'low': 600.0999755859375,
#   'close': 600.3400268554688,
#   'volume': 73693},
#  {'timestamp': Timestamp('2025-02-21 20:20:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.260009765625,
#   'high': 600.2999877929688,
#   'low': 600.0900268554688,
#   'close': 600.2301025390625,
#   'volume': 93433},
#  {'timestamp': Timestamp('2025-02-21 20:19:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.27001953125,
#   'high': 600.27001953125,
#   'low': 600.27001953125,
#   'close': 600.27001953125,
#   'volume': 1135781},
#  {'timestamp': Timestamp('2025-02-21 20:18:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.02490234375,
#   'high': 600.1599731445312,
#   'low': 599.9000244140625,
#   'close': 600.0700073242188,
#   'volume': 231274},
#  {'timestamp': Timestamp('2025-02-21 20:17:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.02001953125,
#   'high': 600.2100219726562,
#   'low': 599.8685302734375,
#   'close': 600.02001953125,
#   'volume': 161352},
#  {'timestamp': Timestamp('2025-02-21 20:16:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.2890014648438,
#   'high': 600.2890014648438,
#   'low': 600.0599975585938,
#   'close': 600.1500244140625,
#   'volume': 310874},
#  {'timestamp': Timestamp('2025-02-21 20:15:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.1400146484375,
#   'high': 600.2899780273438,
#   'low': 600.1199951171875,
#   'close': 600.22998046875,
#   'volume': 29247},
#  {'timestamp': Timestamp('2025-02-21 20:14:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.1500244140625,
#   'high': 600.280029296875,
#   'low': 600.0900268554688,
#   'close': 600.1500244140625,
#   'volume': 167958},
#  {'timestamp': Timestamp('2025-02-21 20:13:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.4000244140625,
#   'high': 600.47998046875,
#   'low': 600.1514282226562,
#   'close': 600.2899780273438,
#   'volume': 200988},
#  {'timestamp': Timestamp('2025-02-21 20:12:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.9000244140625,
#   'high': 600.4400024414062,
#   'low': 599.9000244140625,
#   'close': 600.4000244140625,
#   'volume': 176936},
#  {'timestamp': Timestamp('2025-02-21 20:11:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.7449951171875,
#   'high': 599.9500122070312,
#   'low': 599.719970703125,
#   'close': 599.8900146484375,
#   'volume': 358346},
#  {'timestamp': Timestamp('2025-02-21 20:10:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.9600219726562,
#   'high': 599.97998046875,
#   'low': 599.6599731445312,
#   'close': 599.7650146484375,
#   'volume': 138038},
#  {'timestamp': Timestamp('2025-02-21 20:09:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.9149780273438,
#   'high': 599.9749755859375,
#   'low': 599.8800048828125,
#   'close': 599.9299926757812,
#   'volume': 54532},
#  {'timestamp': Timestamp('2025-02-21 20:08:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.0900268554688,
#   'high': 600.1099853515625,
#   'low': 599.8800048828125,
#   'close': 599.9400024414062,
#   'volume': 67159},
#  {'timestamp': Timestamp('2025-02-21 20:07:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.1500244140625,
#   'high': 600.25,
#   'low': 600.0150146484375,
#   'close': 600.0999755859375,
#   'volume': 50622},
#  {'timestamp': Timestamp('2025-02-21 20:06:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.030029296875,
#   'high': 600.239990234375,
#   'low': 600.0200805664062,
#   'close': 600.135009765625,
#   'volume': 70169},
#  {'timestamp': Timestamp('2025-02-21 20:05:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.0250244140625,
#   'high': 600.1500244140625,
#   'low': 599.9299926757812,
#   'close': 600.030029296875,
#   'volume': 66433},
#  {'timestamp': Timestamp('2025-02-21 20:04:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.02001953125,
#   'high': 600.02001953125,
#   'low': 600.02001953125,
#   'close': 600.02001953125,
#   'volume': 68653},
#  {'timestamp': Timestamp('2025-02-21 20:03:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.8900146484375,
#   'high': 600.1400146484375,
#   'low': 599.77001953125,
#   'close': 600.0599975585938,
#   'volume': 55768},
#  {'timestamp': Timestamp('2025-02-21 20:02:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.8200073242188,
#   'high': 599.9299926757812,
#   'low': 599.760009765625,
#   'close': 599.8699951171875,
#   'volume': 100119},
#  {'timestamp': Timestamp('2025-02-21 20:01:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.22998046875,
#   'high': 600.4199829101562,
#   'low': 599.7899780273438,
#   'close': 599.8336791992188,
#   'volume': 126588},
#  {'timestamp': Timestamp('2025-02-21 20:00:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.030029296875,
#   'high': 600.260009765625,
#   'low': 599.760009765625,
#   'close': 600.22998046875,
#   'volume': 151599},
#  {'timestamp': Timestamp('2025-02-21 19:59:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.280029296875,
#   'high': 600.2849731445312,
#   'low': 600.0,
#   'close': 600.0349731445312,
#   'volume': 150950},
#  {'timestamp': Timestamp('2025-02-21 19:58:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.2899780273438,
#   'high': 600.4400024414062,
#   'low': 600.1799926757812,
#   'close': 600.2650146484375,
#   'volume': 116792},
#  {'timestamp': Timestamp('2025-02-21 19:57:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.4949951171875,
#   'high': 600.6099853515625,
#   'low': 600.27001953125,
#   'close': 600.27001953125,
#   'volume': 96602},
#  {'timestamp': Timestamp('2025-02-21 19:56:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.469970703125,
#   'high': 600.5650024414062,
#   'low': 600.4099731445312,
#   'close': 600.510009765625,
#   'volume': 501330},
#  {'timestamp': Timestamp('2025-02-21 19:55:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.4600219726562,
#   'high': 600.4600219726562,
#   'low': 600.0899047851562,
#   'close': 600.4600219726562,
#   'volume': 120516},
#  {'timestamp': Timestamp('2025-02-21 19:54:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.4349975585938,
#   'high': 600.4349975585938,
#   'low': 599.989990234375,
#   'close': 600.0999755859375,
#   'volume': 145391},
#  {'timestamp': Timestamp('2025-02-21 19:53:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.6099853515625,
#   'high': 600.6599731445312,
#   'low': 600.3300170898438,
#   'close': 600.4450073242188,
#   'volume': 120728},
#  {'timestamp': Timestamp('2025-02-21 19:52:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.4000244140625,
#   'high': 600.6400146484375,
#   'low': 600.4000244140625,
#   'close': 600.6300048828125,
#   'volume': 133432},
#  {'timestamp': Timestamp('2025-02-21 19:51:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.39501953125,
#   'high': 600.5399780273438,
#   'low': 600.3599853515625,
#   'close': 600.4000244140625,
#   'volume': 190801},
#  {'timestamp': Timestamp('2025-02-21 19:50:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.9500122070312,
#   'high': 600.4000244140625,
#   'low': 599.9349975585938,
#   'close': 600.3900146484375,
#   'volume': 152119},
#  {'timestamp': Timestamp('2025-02-21 19:49:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.9500122070312,
#   'high': 600.1699829101562,
#   'low': 599.9000244140625,
#   'close': 599.9400024414062,
#   'volume': 137515},
#  {'timestamp': Timestamp('2025-02-21 19:48:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.8200073242188,
#   'high': 600.0189819335938,
#   'low': 599.719970703125,
#   'close': 599.9500122070312,
#   'volume': 130422},
#  {'timestamp': Timestamp('2025-02-21 19:47:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.9000244140625,
#   'high': 599.989990234375,
#   'low': 599.7000122070312,
#   'close': 599.7999877929688,
#   'volume': 79047},
#  {'timestamp': Timestamp('2025-02-21 19:46:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.8599853515625,
#   'high': 600.0654907226562,
#   'low': 599.7899780273438,
#   'close': 599.9000244140625,
#   'volume': 267064},
#  {'timestamp': Timestamp('2025-02-21 19:45:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.0700073242188,
#   'high': 600.2000122070312,
#   'low': 599.8499755859375,
#   'close': 599.8499755859375,
#   'volume': 230814},
#  {'timestamp': Timestamp('2025-02-21 19:44:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.9500122070312,
#   'high': 600.1400146484375,
#   'low': 599.7899780273438,
#   'close': 600.0900268554688,
#   'volume': 156669},
#  {'timestamp': Timestamp('2025-02-21 19:43:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.6099853515625,
#   'high': 599.989990234375,
#   'low': 599.6099853515625,
#   'close': 599.9500122070312,
#   'volume': 151759},
#  {'timestamp': Timestamp('2025-02-21 19:42:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.5800170898438,
#   'high': 599.7000122070312,
#   'low': 599.469970703125,
#   'close': 599.5999755859375,
#   'volume': 135640},
#  {'timestamp': Timestamp('2025-02-21 19:41:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.719970703125,
#   'high': 599.760009765625,
#   'low': 599.530029296875,
#   'close': 599.6199951171875,
#   'volume': 104415},
#  {'timestamp': Timestamp('2025-02-21 19:40:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.8099975585938,
#   'high': 599.9099731445312,
#   'low': 599.6900024414062,
#   'close': 599.7249755859375,
#   'volume': 90119},
#  {'timestamp': Timestamp('2025-02-21 19:39:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.739990234375,
#   'high': 599.9199829101562,
#   'low': 599.655029296875,
#   'close': 599.780029296875,
#   'volume': 79365},
#  {'timestamp': Timestamp('2025-02-21 19:38:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.0999755859375,
#   'high': 600.1199951171875,
#   'low': 599.6199951171875,
#   'close': 599.7498779296875,
#   'volume': 105969},
#  {'timestamp': Timestamp('2025-02-21 19:37:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.989990234375,
#   'high': 600.0900268554688,
#   'low': 599.739990234375,
#   'close': 600.0800170898438,
#   'volume': 95528},
#  {'timestamp': Timestamp('2025-02-21 19:36:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.0,
#   'high': 600.0,
#   'low': 600.0,
#   'close': 600.0,
#   'volume': 39283},
#  {'timestamp': Timestamp('2025-02-21 19:35:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.1500244140625,
#   'high': 600.2899780273438,
#   'low': 599.9650268554688,
#   'close': 600.0499877929688,
#   'volume': 78548},
#  {'timestamp': Timestamp('2025-02-21 19:34:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.4600219726562,
#   'high': 600.4600219726562,
#   'low': 600.1099853515625,
#   'close': 600.1500244140625,
#   'volume': 88763},
#  {'timestamp': Timestamp('2025-02-21 19:33:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.3699951171875,
#   'high': 600.64501953125,
#   'low': 600.3699951171875,
#   'close': 600.4598999023438,
#   'volume': 102084},
#  {'timestamp': Timestamp('2025-02-21 19:32:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.2050170898438,
#   'high': 600.52001953125,
#   'low': 600.2050170898438,
#   'close': 600.3599853515625,
#   'volume': 106016},
#  {'timestamp': Timestamp('2025-02-21 19:31:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.3900146484375,
#   'high': 600.52001953125,
#   'low': 600.094970703125,
#   'close': 600.2100219726562,
#   'volume': 311390},
#  {'timestamp': Timestamp('2025-02-21 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.909912109375,
#   'high': 600.4000244140625,
#   'low': 599.8101196289062,
#   'close': 600.3800048828125,
#   'volume': 184897},
#  {'timestamp': Timestamp('2025-02-21 19:29:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.9099731445312,
#   'high': 600.4299926757812,
#   'low': 599.6500244140625,
#   'close': 599.9099731445312,
#   'volume': 385327},
#  {'timestamp': Timestamp('2025-02-21 19:28:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.4199829101562,
#   'high': 600.52001953125,
#   'low': 600.25,
#   'close': 600.3599853515625,
#   'volume': 154030},
#  {'timestamp': Timestamp('2025-02-21 19:27:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.1732788085938,
#   'high': 600.6099853515625,
#   'low': 600.1400146484375,
#   'close': 600.4500122070312,
#   'volume': 191241},
#  {'timestamp': Timestamp('2025-02-21 19:26:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.5,
#   'high': 600.530029296875,
#   'low': 600.1599731445312,
#   'close': 600.1799926757812,
#   'volume': 77487},
#  {'timestamp': Timestamp('2025-02-21 19:25:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.5,
#   'high': 600.7100219726562,
#   'low': 600.4000244140625,
#   'close': 600.5,
#   'volume': 109205},
#  {'timestamp': Timestamp('2025-02-21 19:24:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.5900268554688,
#   'high': 600.6900024414062,
#   'low': 600.4500122070312,
#   'close': 600.6699829101562,
#   'volume': 226947},
#  {'timestamp': Timestamp('2025-02-21 19:23:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.7100219726562,
#   'high': 600.8400268554688,
#   'low': 600.5499877929688,
#   'close': 600.5999755859375,
#   'volume': 75547},
#  {'timestamp': Timestamp('2025-02-21 19:22:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.760009765625,
#   'high': 600.8499755859375,
#   'low': 600.6589965820312,
#   'close': 600.77001953125,
#   'volume': 112335},
#  {'timestamp': Timestamp('2025-02-21 19:21:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.969970703125,
#   'high': 601.030029296875,
#   'low': 600.72998046875,
#   'close': 600.75,
#   'volume': 132250},
#  {'timestamp': Timestamp('2025-02-21 19:20:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.3300170898438,
#   'high': 601.3699951171875,
#   'low': 600.9400024414062,
#   'close': 600.9400024414062,
#   'volume': 183032},
#  {'timestamp': Timestamp('2025-02-21 19:19:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.6500244140625,
#   'high': 601.7498779296875,
#   'low': 601.3400268554688,
#   'close': 601.3699951171875,
#   'volume': 94731},
#  {'timestamp': Timestamp('2025-02-21 19:18:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.6699829101562,
#   'high': 601.7100219726562,
#   'low': 601.5599975585938,
#   'close': 601.6502075195312,
#   'volume': 188636},
#  {'timestamp': Timestamp('2025-02-21 19:17:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.5999755859375,
#   'high': 601.77001953125,
#   'low': 601.5999755859375,
#   'close': 601.669921875,
#   'volume': 83458},
#  {'timestamp': Timestamp('2025-02-21 19:16:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.6199951171875,
#   'high': 601.9249877929688,
#   'low': 601.530029296875,
#   'close': 601.6199951171875,
#   'volume': 80457},
#  {'timestamp': Timestamp('2025-02-21 19:15:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.14501953125,
#   'high': 602.14501953125,
#   'low': 601.9299926757812,
#   'close': 601.9349975585938,
#   'volume': 74876},
#  {'timestamp': Timestamp('2025-02-21 19:14:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.9824829101562,
#   'high': 602.3300170898438,
#   'low': 601.969970703125,
#   'close': 602.1400146484375,
#   'volume': 118232},
#  {'timestamp': Timestamp('2025-02-21 19:13:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.7999877929688,
#   'high': 602.02001953125,
#   'low': 601.7999877929688,
#   'close': 601.989990234375,
#   'volume': 110587},
#  {'timestamp': Timestamp('2025-02-21 19:12:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.5250244140625,
#   'high': 601.7971801757812,
#   'low': 601.5050048828125,
#   'close': 601.7899780273438,
#   'volume': 84099},
#  {'timestamp': Timestamp('2025-02-21 19:11:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.7999877929688,
#   'high': 601.8699951171875,
#   'low': 601.4299926757812,
#   'close': 601.5250244140625,
#   'volume': 163515},
#  {'timestamp': Timestamp('2025-02-21 19:10:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.760009765625,
#   'high': 601.7999877929688,
#   'low': 601.6212158203125,
#   'close': 601.780029296875,
#   'volume': 100566},
#  {'timestamp': Timestamp('2025-02-21 19:09:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.5399780273438,
#   'high': 601.75,
#   'low': 601.530029296875,
#   'close': 601.75,
#   'volume': 131411},
#  {'timestamp': Timestamp('2025-02-21 19:08:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.489990234375,
#   'high': 601.6900024414062,
#   'low': 601.4099731445312,
#   'close': 601.530029296875,
#   'volume': 70142},
#  {'timestamp': Timestamp('2025-02-21 19:07:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.4400024414062,
#   'high': 601.530029296875,
#   'low': 601.3800048828125,
#   'close': 601.469970703125,
#   'volume': 185950},
#  {'timestamp': Timestamp('2025-02-21 19:06:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.3400268554688,
#   'high': 601.5999755859375,
#   'low': 601.3400268554688,
#   'close': 601.4299926757812,
#   'volume': 97733},
#  {'timestamp': Timestamp('2025-02-21 19:05:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.3499755859375,
#   'high': 601.47998046875,
#   'low': 601.25,
#   'close': 601.3499755859375,
#   'volume': 107910},
#  {'timestamp': Timestamp('2025-02-21 19:04:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.3800048828125,
#   'high': 601.417724609375,
#   'low': 601.22998046875,
#   'close': 601.364990234375,
#   'volume': 138405},
#  {'timestamp': Timestamp('2025-02-21 19:03:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.3400268554688,
#   'high': 601.4600219726562,
#   'low': 601.3250122070312,
#   'close': 601.3699951171875,
#   'volume': 282011},
#  {'timestamp': Timestamp('2025-02-21 19:02:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.489990234375,
#   'high': 601.5900268554688,
#   'low': 601.3400268554688,
#   'close': 601.3400268554688,
#   'volume': 103399},
#  {'timestamp': Timestamp('2025-02-21 19:01:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.7849731445312,
#   'high': 601.8150024414062,
#   'low': 601.22998046875,
#   'close': 601.47998046875,
#   'volume': 208987},
#  {'timestamp': Timestamp('2025-02-21 19:00:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.760009765625,
#   'high': 601.9099731445312,
#   'low': 601.6828002929688,
#   'close': 601.77001953125,
#   'volume': 51534},
#  {'timestamp': Timestamp('2025-02-21 18:59:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.6199951171875,
#   'high': 601.780029296875,
#   'low': 601.5700073242188,
#   'close': 601.7534790039062,
#   'volume': 87624},
#  {'timestamp': Timestamp('2025-02-21 18:58:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.8599853515625,
#   'high': 601.8699951171875,
#   'low': 601.6400146484375,
#   'close': 601.6599731445312,
#   'volume': 69644},
#  {'timestamp': Timestamp('2025-02-21 18:57:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.0499877929688,
#   'high': 602.0599975585938,
#   'low': 601.719970703125,
#   'close': 601.8400268554688,
#   'volume': 144499},
#  {'timestamp': Timestamp('2025-02-21 18:56:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.0900268554688,
#   'high': 602.1900024414062,
#   'low': 601.969970703125,
#   'close': 602.0704956054688,
#   'volume': 65628},
#  {'timestamp': Timestamp('2025-02-21 18:55:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.1900024414062,
#   'high': 602.2100219726562,
#   'low': 602.0399780273438,
#   'close': 602.10498046875,
#   'volume': 161467},
#  {'timestamp': Timestamp('2025-02-21 18:54:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.0408935546875,
#   'high': 602.219970703125,
#   'low': 602.0408935546875,
#   'close': 602.2100219726562,
#   'volume': 72527},
#  {'timestamp': Timestamp('2025-02-21 18:53:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.9349975585938,
#   'high': 602.22998046875,
#   'low': 601.8099975585938,
#   'close': 602.0700073242188,
#   'volume': 85442},
#  {'timestamp': Timestamp('2025-02-21 18:52:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.989990234375,
#   'high': 602.0897216796875,
#   'low': 601.9099731445312,
#   'close': 601.9349975585938,
#   'volume': 32546},
#  {'timestamp': Timestamp('2025-02-21 18:51:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.969970703125,
#   'high': 602.1199951171875,
#   'low': 601.9099731445312,
#   'close': 602.0599975585938,
#   'volume': 51464},
#  {'timestamp': Timestamp('2025-02-21 18:50:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.8800048828125,
#   'high': 602.2000122070312,
#   'low': 601.8800048828125,
#   'close': 601.9605102539062,
#   'volume': 90602},
#  {'timestamp': Timestamp('2025-02-21 18:49:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.9099731445312,
#   'high': 601.989990234375,
#   'low': 601.780029296875,
#   'close': 601.9099731445312,
#   'volume': 114926},
#  {'timestamp': Timestamp('2025-02-21 18:48:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.9099731445312,
#   'high': 602.010009765625,
#   'low': 601.8099975585938,
#   'close': 601.9099731445312,
#   'volume': 304982},
#  {'timestamp': Timestamp('2025-02-21 18:47:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.9500122070312,
#   'high': 602.0499877929688,
#   'low': 601.780029296875,
#   'close': 601.9500122070312,
#   'volume': 192497},
#  {'timestamp': Timestamp('2025-02-21 18:46:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.9000244140625,
#   'high': 601.9199829101562,
#   'low': 601.739990234375,
#   'close': 601.8200073242188,
#   'volume': 163590},
#  {'timestamp': Timestamp('2025-02-21 18:45:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.8300170898438,
#   'high': 601.9500122070312,
#   'low': 601.77001953125,
#   'close': 601.8800048828125,
#   'volume': 76845},
#  {'timestamp': Timestamp('2025-02-21 18:44:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.0499877929688,
#   'high': 602.1199951171875,
#   'low': 601.8200073242188,
#   'close': 601.8399047851562,
#   'volume': 78176},
#  {'timestamp': Timestamp('2025-02-21 18:43:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.280029296875,
#   'high': 602.3499755859375,
#   'low': 602.030029296875,
#   'close': 602.0435180664062,
#   'volume': 48597},
#  {'timestamp': Timestamp('2025-02-21 18:42:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.052490234375,
#   'high': 602.3400268554688,
#   'low': 602.010009765625,
#   'close': 602.27001953125,
#   'volume': 80710},
#  {'timestamp': Timestamp('2025-02-21 18:41:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.3800048828125,
#   'high': 602.4550170898438,
#   'low': 602.0599975585938,
#   'close': 602.0599975585938,
#   'volume': 73522},
#  {'timestamp': Timestamp('2025-02-21 18:40:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.4199829101562,
#   'high': 602.7100219726562,
#   'low': 602.4199829101562,
#   'close': 602.4349975585938,
#   'volume': 67417},
#  {'timestamp': Timestamp('2025-02-21 18:39:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.8300170898438,
#   'high': 602.8400268554688,
#   'low': 602.3499755859375,
#   'close': 602.3887329101562,
#   'volume': 98159},
#  {'timestamp': Timestamp('2025-02-21 18:38:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.989990234375,
#   'high': 603.2249755859375,
#   'low': 602.7550048828125,
#   'close': 602.8499755859375,
#   'volume': 236312},
#  {'timestamp': Timestamp('2025-02-21 18:37:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.5599975585938,
#   'high': 602.9777221679688,
#   'low': 602.5,
#   'close': 602.9600219726562,
#   'volume': 140738},
#  {'timestamp': Timestamp('2025-02-21 18:36:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.2297973632812,
#   'high': 602.5850219726562,
#   'low': 602.1950073242188,
#   'close': 602.530029296875,
#   'volume': 219967},
#  {'timestamp': Timestamp('2025-02-21 18:35:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.0599975585938,
#   'high': 602.3599853515625,
#   'low': 602.010009765625,
#   'close': 602.2550048828125,
#   'volume': 239320},
#  {'timestamp': Timestamp('2025-02-21 18:34:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.9718017578125,
#   'high': 602.1599731445312,
#   'low': 601.844970703125,
#   'close': 602.0499877929688,
#   'volume': 782212},
#  {'timestamp': Timestamp('2025-02-21 18:33:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.739990234375,
#   'high': 602.0599975585938,
#   'low': 601.739990234375,
#   'close': 601.9749755859375,
#   'volume': 103547},
#  {'timestamp': Timestamp('2025-02-21 18:32:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.6900024414062,
#   'high': 601.8699951171875,
#   'low': 601.5900268554688,
#   'close': 601.7999877929688,
#   'volume': 129459},
#  {'timestamp': Timestamp('2025-02-21 18:31:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.02001953125,
#   'high': 602.0399780273438,
#   'low': 601.6710205078125,
#   'close': 601.7100219726562,
#   'volume': 135496},
#  {'timestamp': Timestamp('2025-02-21 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.14501953125,
#   'high': 602.1900024414062,
#   'low': 601.8599853515625,
#   'close': 602.030029296875,
#   'volume': 180075},
#  {'timestamp': Timestamp('2025-02-21 18:29:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.5,
#   'high': 602.510009765625,
#   'low': 602.10009765625,
#   'close': 602.1599731445312,
#   'volume': 113116},
#  {'timestamp': Timestamp('2025-02-21 18:28:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.6199951171875,
#   'high': 602.6199951171875,
#   'low': 602.39501953125,
#   'close': 602.530029296875,
#   'volume': 135323},
#  {'timestamp': Timestamp('2025-02-21 18:27:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.7999877929688,
#   'high': 602.8099975585938,
#   'low': 602.530029296875,
#   'close': 602.6199951171875,
#   'volume': 105285},
#  {'timestamp': Timestamp('2025-02-21 18:26:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.969970703125,
#   'high': 603.0499877929688,
#   'low': 602.7899780273438,
#   'close': 602.8499755859375,
#   'volume': 65448},
#  {'timestamp': Timestamp('2025-02-21 18:25:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.65869140625,
#   'high': 603.0,
#   'low': 602.60498046875,
#   'close': 602.951171875,
#   'volume': 69766},
#  {'timestamp': Timestamp('2025-02-21 18:24:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.6900024414062,
#   'high': 602.7899780273438,
#   'low': 602.5399780273438,
#   'close': 602.6900024414062,
#   'volume': 86309},
#  {'timestamp': Timestamp('2025-02-21 18:23:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.6199951171875,
#   'high': 603.010009765625,
#   'low': 602.6099853515625,
#   'close': 602.7750244140625,
#   'volume': 123288},
#  {'timestamp': Timestamp('2025-02-21 18:22:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.5999755859375,
#   'high': 602.6987915039062,
#   'low': 602.5599975585938,
#   'close': 602.6500244140625,
#   'volume': 114966},
#  {'timestamp': Timestamp('2025-02-21 18:21:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.760009765625,
#   'high': 602.780029296875,
#   'low': 602.530029296875,
#   'close': 602.6199951171875,
#   'volume': 130416},
#  {'timestamp': Timestamp('2025-02-21 18:20:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.8599243164062,
#   'high': 602.97998046875,
#   'low': 602.719970703125,
#   'close': 602.77001953125,
#   'volume': 61325},
#  {'timestamp': Timestamp('2025-02-21 18:19:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.0,
#   'high': 603.0,
#   'low': 602.7509155273438,
#   'close': 602.8499755859375,
#   'volume': 99479},
#  {'timestamp': Timestamp('2025-02-21 18:18:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.4400024414062,
#   'high': 603.539794921875,
#   'low': 603.0352783203125,
#   'close': 603.0399780273438,
#   'volume': 102672},
#  {'timestamp': Timestamp('2025-02-21 18:17:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.260009765625,
#   'high': 603.5,
#   'low': 603.219970703125,
#   'close': 603.4700927734375,
#   'volume': 83760},
#  {'timestamp': Timestamp('2025-02-21 18:16:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.3400268554688,
#   'high': 603.4500122070312,
#   'low': 603.2000122070312,
#   'close': 603.280029296875,
#   'volume': 210239},
#  {'timestamp': Timestamp('2025-02-21 18:15:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.9299926757812,
#   'high': 603.3300170898438,
#   'low': 602.9299926757812,
#   'close': 603.3300170898438,
#   'volume': 208249},
#  {'timestamp': Timestamp('2025-02-21 18:14:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.5399780273438,
#   'high': 602.9600219726562,
#   'low': 602.52001953125,
#   'close': 602.9500122070312,
#   'volume': 526231},
#  {'timestamp': Timestamp('2025-02-21 18:13:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.27001953125,
#   'high': 602.5700073242188,
#   'low': 602.2100219726562,
#   'close': 602.5399169921875,
#   'volume': 228318},
#  {'timestamp': Timestamp('2025-02-21 18:12:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.5499877929688,
#   'high': 602.5499877929688,
#   'low': 602.2449951171875,
#   'close': 602.2899780273438,
#   'volume': 249373},
#  {'timestamp': Timestamp('2025-02-21 18:11:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.5800170898438,
#   'high': 602.760009765625,
#   'low': 602.44091796875,
#   'close': 602.5650024414062,
#   'volume': 181065},
#  {'timestamp': Timestamp('2025-02-21 18:10:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.7999877929688,
#   'high': 602.8400268554688,
#   'low': 602.5499877929688,
#   'close': 602.5999755859375,
#   'volume': 117874},
#  {'timestamp': Timestamp('2025-02-21 18:09:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.02001953125,
#   'high': 603.0399780273438,
#   'low': 602.719970703125,
#   'close': 602.7899780273438,
#   'volume': 102284},
#  {'timestamp': Timestamp('2025-02-21 18:08:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.1099853515625,
#   'high': 603.1599731445312,
#   'low': 602.9500122070312,
#   'close': 603.0599975585938,
#   'volume': 102827},
#  {'timestamp': Timestamp('2025-02-21 18:07:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.1400146484375,
#   'high': 603.260009765625,
#   'low': 602.969970703125,
#   'close': 603.119873046875,
#   'volume': 138991},
#  {'timestamp': Timestamp('2025-02-21 18:06:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.25,
#   'high': 603.3200073242188,
#   'low': 603.1199951171875,
#   'close': 603.1400146484375,
#   'volume': 78855},
#  {'timestamp': Timestamp('2025-02-21 18:05:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.219970703125,
#   'high': 603.4000244140625,
#   'low': 603.0999755859375,
#   'close': 603.260009765625,
#   'volume': 188763},
#  {'timestamp': Timestamp('2025-02-21 18:04:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.25,
#   'high': 603.2899780273438,
#   'low': 603.10498046875,
#   'close': 603.22998046875,
#   'volume': 186299},
#  {'timestamp': Timestamp('2025-02-21 18:03:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.3800048828125,
#   'high': 603.4299926757812,
#   'low': 603.0900268554688,
#   'close': 603.2650146484375,
#   'volume': 195349},
#  {'timestamp': Timestamp('2025-02-21 18:02:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.6400146484375,
#   'high': 603.6500244140625,
#   'low': 603.3300170898438,
#   'close': 603.4000244140625,
#   'volume': 188860},
#  {'timestamp': Timestamp('2025-02-21 18:01:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.6699829101562,
#   'high': 603.7000122070312,
#   'low': 603.5150146484375,
#   'close': 603.6300048828125,
#   'volume': 121803},
#  {'timestamp': Timestamp('2025-02-21 18:00:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.8300170898438,
#   'high': 603.8493041992188,
#   'low': 603.6500244140625,
#   'close': 603.6900024414062,
#   'volume': 80630},
#  {'timestamp': Timestamp('2025-02-21 17:59:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.8400268554688,
#   'high': 603.9500122070312,
#   'low': 603.75,
#   'close': 603.8200073242188,
#   'volume': 80710},
#  {'timestamp': Timestamp('2025-02-21 17:58:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.780029296875,
#   'high': 603.9400024414062,
#   'low': 603.719970703125,
#   'close': 603.8599853515625,
#   'volume': 1479151},
#  {'timestamp': Timestamp('2025-02-21 17:57:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.8200073242188,
#   'high': 603.8499755859375,
#   'low': 603.6199951171875,
#   'close': 603.780029296875,
#   'volume': 140480},
#  {'timestamp': Timestamp('2025-02-21 17:56:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.14990234375,
#   'high': 604.2000122070312,
#   'low': 603.719970703125,
#   'close': 603.8400268554688,
#   'volume': 189675},
#  {'timestamp': Timestamp('2025-02-21 17:55:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.27001953125,
#   'high': 604.4450073242188,
#   'low': 604.1300048828125,
#   'close': 604.1300048828125,
#   'volume': 78837},
#  {'timestamp': Timestamp('2025-02-21 17:54:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.3599853515625,
#   'high': 604.5399780273438,
#   'low': 604.25341796875,
#   'close': 604.27001953125,
#   'volume': 57454},
#  {'timestamp': Timestamp('2025-02-21 17:53:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.419921875,
#   'high': 604.4199829101562,
#   'low': 604.280029296875,
#   'close': 604.3740844726562,
#   'volume': 58391},
#  {'timestamp': Timestamp('2025-02-21 17:52:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.530029296875,
#   'high': 604.5650024414062,
#   'low': 604.4099731445312,
#   'close': 604.4099731445312,
#   'volume': 61531},
#  {'timestamp': Timestamp('2025-02-21 17:51:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.489990234375,
#   'high': 604.5408935546875,
#   'low': 604.27001953125,
#   'close': 604.5399780273438,
#   'volume': 176739},
#  {'timestamp': Timestamp('2025-02-21 17:50:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.510009765625,
#   'high': 604.6900024414062,
#   'low': 604.4400024414062,
#   'close': 604.510009765625,
#   'volume': 90017},
#  {'timestamp': Timestamp('2025-02-21 17:49:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.8200073242188,
#   'high': 604.9088745117188,
#   'low': 604.5809936523438,
#   'close': 604.6199951171875,
#   'volume': 62228},
#  {'timestamp': Timestamp('2025-02-21 17:48:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.8400268554688,
#   'high': 604.9099731445312,
#   'low': 604.77001953125,
#   'close': 604.8099975585938,
#   'volume': 36212},
#  {'timestamp': Timestamp('2025-02-21 17:47:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.77001953125,
#   'high': 604.905029296875,
#   'low': 604.739990234375,
#   'close': 604.8699951171875,
#   'volume': 47269},
#  {'timestamp': Timestamp('2025-02-21 17:46:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.719970703125,
#   'high': 604.7899780273438,
#   'low': 604.5797729492188,
#   'close': 604.7849731445312,
#   'volume': 62469},
#  {'timestamp': Timestamp('2025-02-21 17:45:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.0700073242188,
#   'high': 605.0800170898438,
#   'low': 604.6900024414062,
#   'close': 604.7349853515625,
#   'volume': 54975},
#  {'timestamp': Timestamp('2025-02-21 17:44:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.0899047851562,
#   'high': 605.1699829101562,
#   'low': 605.0401000976562,
#   'close': 605.0700073242188,
#   'volume': 69595},
#  {'timestamp': Timestamp('2025-02-21 17:43:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.8499755859375,
#   'high': 605.0800170898438,
#   'low': 604.8300170898438,
#   'close': 605.0700073242188,
#   'volume': 215649},
#  {'timestamp': Timestamp('2025-02-21 17:42:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.8200073242188,
#   'high': 604.8900146484375,
#   'low': 604.7130126953125,
#   'close': 604.8800048828125,
#   'volume': 42060},
#  {'timestamp': Timestamp('2025-02-21 17:41:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.8300170898438,
#   'high': 604.8400268554688,
#   'low': 604.6300048828125,
#   'close': 604.8300170898438,
#   'volume': 114187},
#  {'timestamp': Timestamp('2025-02-21 17:40:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.75,
#   'high': 604.869873046875,
#   'low': 604.5900268554688,
#   'close': 604.6900024414062,
#   'volume': 70301},
#  {'timestamp': Timestamp('2025-02-21 17:39:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.739990234375,
#   'high': 604.7999877929688,
#   'low': 604.5900268554688,
#   'close': 604.739990234375,
#   'volume': 108408},
#  {'timestamp': Timestamp('2025-02-21 17:38:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.5999755859375,
#   'high': 604.8699951171875,
#   'low': 604.5900268554688,
#   'close': 604.6900024414062,
#   'volume': 286021},
#  {'timestamp': Timestamp('2025-02-21 17:37:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.1599731445312,
#   'high': 605.1699829101562,
#   'low': 604.5399780273438,
#   'close': 604.594970703125,
#   'volume': 266959},
#  {'timestamp': Timestamp('2025-02-21 17:36:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.2694091796875,
#   'high': 605.3099975585938,
#   'low': 605.0800170898438,
#   'close': 605.155029296875,
#   'volume': 53065},
#  {'timestamp': Timestamp('2025-02-21 17:35:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.2899780273438,
#   'high': 605.530029296875,
#   'low': 605.2100219726562,
#   'close': 605.2698974609375,
#   'volume': 385488},
#  {'timestamp': Timestamp('2025-02-21 17:34:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.344970703125,
#   'high': 605.4299926757812,
#   'low': 605.280029296875,
#   'close': 605.280029296875,
#   'volume': 67347},
#  {'timestamp': Timestamp('2025-02-21 17:33:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.4099731445312,
#   'high': 605.4600219726562,
#   'low': 605.3200073242188,
#   'close': 605.3300170898438,
#   'volume': 35992},
#  {'timestamp': Timestamp('2025-02-21 17:32:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.5399780273438,
#   'high': 605.5999755859375,
#   'low': 605.4000244140625,
#   'close': 605.4093017578125,
#   'volume': 32099},
#  {'timestamp': Timestamp('2025-02-21 17:31:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.6099853515625,
#   'high': 605.6099853515625,
#   'low': 605.4400024414062,
#   'close': 605.5,
#   'volume': 22257},
#  {'timestamp': Timestamp('2025-02-21 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.7550048828125,
#   'high': 605.7899780273438,
#   'low': 605.5,
#   'close': 605.5900268554688,
#   'volume': 167671},
#  {'timestamp': Timestamp('2025-02-21 17:29:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.6400146484375,
#   'high': 605.72998046875,
#   'low': 605.5800170898438,
#   'close': 605.7199096679688,
#   'volume': 38761},
#  {'timestamp': Timestamp('2025-02-21 17:28:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.739990234375,
#   'high': 605.8300170898438,
#   'low': 605.674072265625,
#   'close': 605.6806030273438,
#   'volume': 42452},
#  {'timestamp': Timestamp('2025-02-21 17:27:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.739990234375,
#   'high': 605.8300170898438,
#   'low': 605.693603515625,
#   'close': 605.719970703125,
#   'volume': 29946},
#  {'timestamp': Timestamp('2025-02-21 17:26:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.8800048828125,
#   'high': 605.8800048828125,
#   'low': 605.6599731445312,
#   'close': 605.719970703125,
#   'volume': 30483},
#  {'timestamp': Timestamp('2025-02-21 17:25:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.8599853515625,
#   'high': 605.8599853515625,
#   'low': 605.8599853515625,
#   'close': 605.8599853515625,
#   'volume': 46389},
#  {'timestamp': Timestamp('2025-02-21 17:24:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.6400146484375,
#   'high': 605.7100219726562,
#   'low': 605.5170288085938,
#   'close': 605.5999755859375,
#   'volume': 55330},
#  {'timestamp': Timestamp('2025-02-21 17:23:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.5399780273438,
#   'high': 605.7999877929688,
#   'low': 605.5399780273438,
#   'close': 605.6300048828125,
#   'volume': 77361},
#  {'timestamp': Timestamp('2025-02-21 17:22:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.4450073242188,
# ...
#   'open': 611.6699829101562,
#   'high': 611.9400024414062,
#   'low': 611.6699829101562,
#   'close': 611.8900146484375,
#   'volume': 53071},
#  {'timestamp': Timestamp('2025-02-19 18:29:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.6500244140625,
#   'high': 611.6799926757812,
#   'low': 611.6300048828125,
#   'close': 611.6599731445312,
#   'volume': 15236},
#  {'timestamp': Timestamp('2025-02-19 18:28:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.5800170898438,
#   'high': 611.6500244140625,
#   'low': 611.5800170898438,
#   'close': 611.6400146484375,
#   'volume': 17830},
#  {'timestamp': Timestamp('2025-02-19 18:27:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.594970703125,
#   'high': 611.60498046875,
#   'low': 611.4500122070312,
#   'close': 611.5800170898438,
#   'volume': 41449},
#  {'timestamp': Timestamp('2025-02-19 18:26:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.6375122070312,
#   'high': 611.7000122070312,
#   'low': 611.5599975585938,
#   'close': 611.5969848632812,
#   'volume': 32934},
#  {'timestamp': Timestamp('2025-02-19 18:25:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.52001953125,
#   'high': 611.639892578125,
#   'low': 611.52001953125,
#   'close': 611.639892578125,
#   'volume': 19048},
#  {'timestamp': Timestamp('2025-02-19 18:24:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.59130859375,
#   'high': 611.59130859375,
#   'low': 611.489990234375,
#   'close': 611.5,
#   'volume': 34515},
#  {'timestamp': Timestamp('2025-02-19 18:23:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.60498046875,
#   'high': 611.6199951171875,
#   'low': 611.5800170898438,
#   'close': 611.5999755859375,
#   'volume': 18731},
#  {'timestamp': Timestamp('2025-02-19 18:22:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.5499877929688,
#   'high': 611.6199951171875,
#   'low': 611.5452880859375,
#   'close': 611.5999755859375,
#   'volume': 18775},
#  {'timestamp': Timestamp('2025-02-19 18:21:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.4949951171875,
#   'high': 611.5700073242188,
#   'low': 611.45068359375,
#   'close': 611.5590209960938,
#   'volume': 12872},
#  {'timestamp': Timestamp('2025-02-19 18:20:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.5399780273438,
#   'high': 611.5800170898438,
#   'low': 611.4400024414062,
#   'close': 611.5050048828125,
#   'volume': 37675},
#  {'timestamp': Timestamp('2025-02-19 18:19:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.3800048828125,
#   'high': 611.530029296875,
#   'low': 611.3800048828125,
#   'close': 611.52001953125,
#   'volume': 26282},
#  {'timestamp': Timestamp('2025-02-19 18:18:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.4400024414062,
#   'high': 611.469970703125,
#   'low': 611.3806762695312,
#   'close': 611.389892578125,
#   'volume': 13696},
#  {'timestamp': Timestamp('2025-02-19 18:17:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.3099975585938,
#   'high': 611.4600219726562,
#   'low': 611.3049926757812,
#   'close': 611.4199829101562,
#   'volume': 42245},
#  {'timestamp': Timestamp('2025-02-19 18:16:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.1702270507812,
#   'high': 611.2999877929688,
#   'low': 611.16650390625,
#   'close': 611.2899780273438,
#   'volume': 39000},
#  {'timestamp': Timestamp('2025-02-19 18:15:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 610.9299926757812,
#   'high': 611.1699829101562,
#   'low': 610.9299926757812,
#   'close': 611.1699829101562,
#   'volume': 33555},
#  {'timestamp': Timestamp('2025-02-19 18:14:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 610.9398803710938,
#   'high': 611.0800170898438,
#   'low': 610.9398193359375,
#   'close': 610.9500122070312,
#   'volume': 84026},
#  {'timestamp': Timestamp('2025-02-19 18:13:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 610.85498046875,
#   'high': 610.9299926757812,
#   'low': 610.781005859375,
#   'close': 610.9199829101562,
#   'volume': 30679},
#  {'timestamp': Timestamp('2025-02-19 18:12:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 610.9000244140625,
#   'high': 610.9099731445312,
#   'low': 610.6500244140625,
#   'close': 610.8400268554688,
#   'volume': 46544},
#  {'timestamp': Timestamp('2025-02-19 18:11:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 610.9600219726562,
#   'high': 611.02001953125,
#   'low': 610.8690185546875,
#   'close': 610.9099731445312,
#   'volume': 35360},
#  {'timestamp': Timestamp('2025-02-19 18:10:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.0999755859375,
#   'high': 611.1099853515625,
#   'low': 610.9401245117188,
#   'close': 610.97998046875,
#   'volume': 20844},
#  {'timestamp': Timestamp('2025-02-19 18:09:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.2000122070312,
#   'high': 611.260009765625,
#   'low': 611.0399780273438,
#   'close': 611.094970703125,
#   'volume': 36478},
#  {'timestamp': Timestamp('2025-02-19 18:08:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.3099975585938,
#   'high': 611.3300170898438,
#   'low': 611.2050170898438,
#   'close': 611.2050170898438,
#   'volume': 146014},
#  {'timestamp': Timestamp('2025-02-19 18:07:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.3450927734375,
#   'high': 611.3450927734375,
#   'low': 611.25,
#   'close': 611.3099975585938,
#   'volume': 21615},
#  {'timestamp': Timestamp('2025-02-19 18:06:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.3300170898438,
#   'high': 611.415283203125,
#   'low': 611.2999877929688,
#   'close': 611.3400268554688,
#   'volume': 20917},
#  {'timestamp': Timestamp('2025-02-19 18:05:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.4299926757812,
#   'high': 611.4299926757812,
#   'low': 611.3200073242188,
#   'close': 611.3220825195312,
#   'volume': 14677},
#  {'timestamp': Timestamp('2025-02-19 18:04:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.451171875,
#   'high': 611.4797973632812,
#   'low': 611.4099731445312,
#   'close': 611.4151000976562,
#   'volume': 17809},
#  {'timestamp': Timestamp('2025-02-19 18:03:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.4299926757812,
#   'high': 611.4791259765625,
#   'low': 611.4017944335938,
#   'close': 611.4329833984375,
#   'volume': 15513},
#  {'timestamp': Timestamp('2025-02-19 18:02:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.4334106445312,
#   'high': 611.5599975585938,
#   'low': 611.3699951171875,
#   'close': 611.4334106445312,
#   'volume': 42948},
#  {'timestamp': Timestamp('2025-02-19 18:01:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.5499877929688,
#   'high': 611.5499877929688,
#   'low': 611.5499877929688,
#   'close': 611.5499877929688,
#   'volume': 35176},
#  {'timestamp': Timestamp('2025-02-19 18:00:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.5599975585938,
#   'high': 611.5900268554688,
#   'low': 611.510009765625,
#   'close': 611.5599975585938,
#   'volume': 42170},
#  {'timestamp': Timestamp('2025-02-19 17:59:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.6500244140625,
#   'high': 611.6799926757812,
#   'low': 611.5499877929688,
#   'close': 611.5599975585938,
#   'volume': 25578},
#  {'timestamp': Timestamp('2025-02-19 17:58:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.77001953125,
#   'high': 611.8200073242188,
#   'low': 611.6400146484375,
#   'close': 611.6599731445312,
#   'volume': 26051},
#  {'timestamp': Timestamp('2025-02-19 17:57:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.6699829101562,
#   'high': 611.7999877929688,
#   'low': 611.6599731445312,
#   'close': 611.77001953125,
#   'volume': 157352},
#  {'timestamp': Timestamp('2025-02-19 17:56:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.6749877929688,
#   'high': 611.7100219726562,
#   'low': 611.635009765625,
#   'close': 611.6599731445312,
#   'volume': 46578},
#  {'timestamp': Timestamp('2025-02-19 17:55:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.7249755859375,
#   'high': 611.72998046875,
#   'low': 611.64501953125,
#   'close': 611.6699829101562,
#   'volume': 39218},
#  {'timestamp': Timestamp('2025-02-19 17:54:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.72998046875,
#   'high': 611.8200073242188,
#   'low': 611.6600952148438,
#   'close': 611.719970703125,
#   'volume': 70152},
#  {'timestamp': Timestamp('2025-02-19 17:53:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.5999755859375,
#   'high': 611.75,
#   'low': 611.5900268554688,
#   'close': 611.7249755859375,
#   'volume': 37573},
#  {'timestamp': Timestamp('2025-02-19 17:52:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.52001953125,
#   'high': 611.638671875,
#   'low': 611.489990234375,
#   'close': 611.5999755859375,
#   'volume': 30473},
#  {'timestamp': Timestamp('2025-02-19 17:51:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.489990234375,
#   'high': 611.510009765625,
#   'low': 611.47998046875,
#   'close': 611.510009765625,
#   'volume': 8771},
#  {'timestamp': Timestamp('2025-02-19 17:50:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.4199829101562,
#   'high': 611.5377807617188,
#   'low': 611.4199829101562,
#   'close': 611.4600219726562,
#   'volume': 22980},
#  {'timestamp': Timestamp('2025-02-19 17:49:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.3499755859375,
#   'high': 611.4199829101562,
#   'low': 611.3499755859375,
#   'close': 611.4047241210938,
#   'volume': 12326},
#  {'timestamp': Timestamp('2025-02-19 17:48:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.4099731445312,
#   'high': 611.4199829101562,
#   'low': 611.3099975585938,
#   'close': 611.3499755859375,
#   'volume': 13206},
#  {'timestamp': Timestamp('2025-02-19 17:47:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.2650146484375,
#   'high': 611.4199829101562,
#   'low': 611.25,
#   'close': 611.405029296875,
#   'volume': 16414},
#  {'timestamp': Timestamp('2025-02-19 17:46:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.25,
#   'high': 611.260009765625,
#   'low': 611.1900024414062,
#   'close': 611.260009765625,
#   'volume': 16184},
#  {'timestamp': Timestamp('2025-02-19 17:45:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.27001953125,
#   'high': 611.3099975585938,
#   'low': 611.239990234375,
#   'close': 611.239990234375,
#   'volume': 17462},
#  {'timestamp': Timestamp('2025-02-19 17:44:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.3148803710938,
#   'high': 611.31982421875,
#   'low': 611.27001953125,
#   'close': 611.280029296875,
#   'volume': 26020},
#  {'timestamp': Timestamp('2025-02-19 17:43:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.1599731445312,
#   'high': 611.3400268554688,
#   'low': 611.1500244140625,
#   'close': 611.3200073242188,
#   'volume': 32155},
#  {'timestamp': Timestamp('2025-02-19 17:42:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.1599731445312,
#   'high': 611.1964721679688,
#   'low': 611.0499877929688,
#   'close': 611.1500244140625,
#   'volume': 16389},
#  {'timestamp': Timestamp('2025-02-19 17:41:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.1400146484375,
#   'high': 611.1900024414062,
#   'low': 611.1218872070312,
#   'close': 611.1300048828125,
#   'volume': 19644},
#  {'timestamp': Timestamp('2025-02-19 17:40:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.1300048828125,
#   'high': 611.1400146484375,
#   'low': 611.0598754882812,
#   'close': 611.1190185546875,
#   'volume': 14775},
#  {'timestamp': Timestamp('2025-02-19 17:39:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.1300048828125,
#   'high': 611.1400146484375,
#   'low': 611.030029296875,
#   'close': 611.1300048828125,
#   'volume': 22673},
#  {'timestamp': Timestamp('2025-02-19 17:38:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.1500244140625,
#   'high': 611.1900024414062,
#   'low': 611.0999755859375,
#   'close': 611.1400146484375,
#   'volume': 40830},
#  {'timestamp': Timestamp('2025-02-19 17:37:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.1491088867188,
#   'high': 611.1900024414062,
#   'low': 611.1199951171875,
#   'close': 611.1500244140625,
#   'volume': 28109},
#  {'timestamp': Timestamp('2025-02-19 17:36:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.0499877929688,
#   'high': 611.1500244140625,
#   'low': 611.0499877929688,
#   'close': 611.1300048828125,
#   'volume': 39860},
#  {'timestamp': Timestamp('2025-02-19 17:35:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 610.9400024414062,
#   'high': 611.0800170898438,
#   'low': 610.9149780273438,
#   'close': 611.0399780273438,
#   'volume': 52686},
#  {'timestamp': Timestamp('2025-02-19 17:34:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 610.9400024414062,
#   'high': 611.0,
#   'low': 610.889892578125,
#   'close': 610.9400024414062,
#   'volume': 45233},
#  {'timestamp': Timestamp('2025-02-19 17:33:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 610.9199829101562,
#   'high': 610.9299926757812,
#   'low': 610.8599853515625,
#   'close': 610.9000854492188,
#   'volume': 25439},
#  {'timestamp': Timestamp('2025-02-19 17:32:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 610.9450073242188,
#   'high': 610.97998046875,
#   'low': 610.9000244140625,
#   'close': 610.9373779296875,
#   'volume': 21042},
#  {'timestamp': Timestamp('2025-02-19 17:31:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.0399780273438,
#   'high': 611.0399780273438,
#   'low': 610.8900146484375,
#   'close': 610.9450073242188,
#   'volume': 40979},
#  {'timestamp': Timestamp('2025-02-19 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.0599975585938,
#   'high': 611.114990234375,
#   'low': 611.0399780273438,
#   'close': 611.0399780273438,
#   'volume': 146429},
#  {'timestamp': Timestamp('2025-02-19 17:29:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.1500244140625,
#   'high': 611.1500244140625,
#   'low': 611.0443115234375,
#   'close': 611.0499877929688,
#   'volume': 16075},
#  {'timestamp': Timestamp('2025-02-19 17:28:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.07861328125,
#   'high': 611.1799926757812,
#   'low': 611.0399780273438,
#   'close': 611.1500244140625,
#   'volume': 297187},
#  {'timestamp': Timestamp('2025-02-19 17:27:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.0900268554688,
#   'high': 611.0999755859375,
#   'low': 611.010009765625,
#   'close': 611.0899047851562,
#   'volume': 25541},
#  {'timestamp': Timestamp('2025-02-19 17:26:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.1300048828125,
#   'high': 611.139892578125,
#   'low': 611.030029296875,
#   'close': 611.0800170898438,
#   'volume': 54857},
#  {'timestamp': Timestamp('2025-02-19 17:25:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.1199951171875,
#   'high': 611.22998046875,
#   'low': 611.0900268554688,
#   'close': 611.1400146484375,
#   'volume': 24557},
#  {'timestamp': Timestamp('2025-02-19 17:24:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.2349853515625,
#   'high': 611.260009765625,
#   'low': 611.1300048828125,
#   'close': 611.1306762695312,
#   'volume': 48089},
#  {'timestamp': Timestamp('2025-02-19 17:23:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.280029296875,
#   'high': 611.3300170898438,
#   'low': 611.1799926757812,
#   'close': 611.22998046875,
#   'volume': 22872},
#  {'timestamp': Timestamp('2025-02-19 17:22:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.2501220703125,
#   'high': 611.3798828125,
#   'low': 611.25,
#   'close': 611.2501220703125,
#   'volume': 20493},
#  {'timestamp': Timestamp('2025-02-19 17:21:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.4099731445312,
#   'high': 611.4099731445312,
#   'low': 611.2899780273438,
#   'close': 611.3200073242188,
#   'volume': 35802},
#  {'timestamp': Timestamp('2025-02-19 17:20:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.4500122070312,
#   'high': 611.5,
#   'low': 611.3599853515625,
#   'close': 611.4199829101562,
#   'volume': 23000},
#  {'timestamp': Timestamp('2025-02-19 17:19:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.52001953125,
#   'high': 611.5399780273438,
#   'low': 611.4500122070312,
#   'close': 611.4500122070312,
#   'volume': 170066},
#  {'timestamp': Timestamp('2025-02-19 17:18:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 611.5,
#   'high': 611.530029296875,
#   'low': 611.489990234375,
#   'close': 611.530029296875,
#   'volume': 17962},
#  ...]

# %%
def insert_market_data(db, df):
    """
    Inserts the transformed DataFrame into the MongoDB time-series collection `yfinanceMarketData`.
    
    Parameters:
        - db (pymongo.database.Database): The MongoDB database object.
        - df (pd.DataFrame): The transformed DataFrame containing market data.
    
    Returns:
    - dict: MongoDB insert result.
    """
    # Confirm timestamp is aware and in UTC
    if df['timestamp'].dt.tz is None:
        # If timestamp is naive, localize to UTC
        df['timestamp'] = pd.to_datetime(df['timestamp']).dt.tz_localize('UTC')
    else:
        # If timestamp is aware, convert to UTC
        df['timestamp'] = df['timestamp'].dt.tz_convert('UTC')
    
    # Convert timestamp to Python datetime object (ensuring stored as ISODate)
    df['timestamp'] = df['timestamp'].apply(lambda x: x.to_pydatetime())
    
    # Convert DataFrame to list of dictionaries
    records = df.to_dict(orient="records")
    
    # Insert data into the collection
    result = db.yfinanceMarketData.insert_many(records)
    
    return {"inserted_count": len(result.inserted_ids)}

# %%
print("Inserting SPY market data...")
inserted_count = insert_market_data(db=db, df=df_spy)
print(f"Inserted {inserted_count} documents.")

print("Inserting QQQ market data...")
inserted_count = insert_market_data(db=db, df=df_qqq)
print(f"Inserted {inserted_count} documents.")

print("Inserting EEM market data...")
inserted_count = insert_market_data(db=db, df=df_eem)
print(f"Inserted {inserted_count} documents.")

print("Inserting XLE market data...")
inserted_count = insert_market_data(db=db, df=df_xle)
print(f"Inserted {inserted_count} documents.")

print("Inserting TLT market data...")
inserted_count = insert_market_data(db=db, df=df_tlt)
print(f"Inserted {inserted_count} documents.")

print("Inserting LQD market data...")
inserted_count = insert_market_data(db=db, df=df_lqd)
print(f"Inserted {inserted_count} documents.")

print("Inserting HYG market data...")
inserted_count = insert_market_data(db=db, df=df_hyg)
print(f"Inserted {inserted_count} documents.")

print("Inserting GLD market data...")
inserted_count = insert_market_data(db=db, df=df_gld)
print(f"Inserted {inserted_count} documents.")

print("Inserting USO market data...")
inserted_count = insert_market_data(db=db, df=df_uso)
print(f"Inserted {inserted_count} documents.")

print("Inserting VIX market data...")
inserted_count = insert_market_data(db=db, df=df_vix)
print(f"Inserted {inserted_count} documents.")
# Out:
# Inserting SPY market data...
# Inserted {'inserted_count': 1557} documents.
# Inserting QQQ market data...
# Inserted {'inserted_count': 1557} documents.
# Inserting EEM market data...
# Inserted {'inserted_count': 1557} documents.
# Inserting XLE market data...
# Inserted {'inserted_count': 1557} documents.
# Inserting TLT market data...
# Inserted {'inserted_count': 1556} documents.
# Inserting LQD market data...
# Inserted {'inserted_count': 1554} documents.
# Inserting HYG market data...
# Inserted {'inserted_count': 1555} documents.
# Inserting GLD market data...
# Inserted {'inserted_count': 1557} documents.
# Inserting USO market data...
# Inserted {'inserted_count': 1522} documents.
# Inserting VIX market data...
# Inserted {'inserted_count': 3561} documents.

# %%
from pprint import pprint

# Query and sort data by timestamp in descending order
cursor = db.yfinanceMarketData.find({"symbol": "SPY-USD"}).sort("timestamp", -1)

# Pretty-print the results
for document in cursor:
    pprint(document)
# Out:
# {'_id': ObjectId('67bc532a75c878a341a44460'),
#  'close': 600.0,
#  'high': 600.114990234375,
#  'low': 599.52001953125,
#  'open': 599.989990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 59, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 1648981}
# {'_id': ObjectId('67bc532a75c878a341a44461'),
#  'close': 599.97998046875,
#  'high': 600.0449829101562,
#  'low': 599.7899780273438,
#  'open': 599.8200073242188,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 58, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 534184}
# {'_id': ObjectId('67bc532a75c878a341a44462'),
#  'close': 599.8400268554688,
#  'high': 599.9500122070312,
#  'low': 599.6599731445312,
#  'open': 599.7999877929688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 57, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 750453}
# {'_id': ObjectId('67bc532a75c878a341a44463'),
#  'close': 599.7999877929688,
#  'high': 600.239013671875,
#  'low': 599.5,
#  'open': 600.1799926757812,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 56, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 468964}
# {'_id': ObjectId('67bc532a75c878a341a44464'),
#  'close': 600.1699829101562,
#  'high': 600.489990234375,
#  'low': 600.1400146484375,
#  'open': 600.3599853515625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 522217}
# {'_id': ObjectId('67bc532a75c878a341a44465'),
#  'close': 600.3699951171875,
#  'high': 600.4299926757812,
#  'low': 599.9400024414062,
#  'open': 600.02001953125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 54, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 363190}
# {'_id': ObjectId('67bc532a75c878a341a44466'),
#  'close': 600.0150146484375,
#  'high': 600.2999877929688,
#  'low': 599.969970703125,
#  'open': 600.239990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 53, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 304306}
# {'_id': ObjectId('67bc532a75c878a341a44467'),
#  'close': 600.25,
#  'high': 600.4299926757812,
#  'low': 600.1099853515625,
#  'open': 600.3800048828125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 52, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 446204}
# {'_id': ObjectId('67bc532a75c878a341a44468'),
#  'close': 600.3800048828125,
#  'high': 600.3900146484375,
#  'low': 600.0599975585938,
#  'open': 600.1500244140625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 51, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 541824}
# {'_id': ObjectId('67bc532a75c878a341a44469'),
#  'close': 600.1699829101562,
#  'high': 600.5399780273438,
#  'low': 600.1300048828125,
#  'open': 600.1699829101562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 282292}
# {'_id': ObjectId('67bc532a75c878a341a4446a'),
#  'close': 600.1799926757812,
#  'high': 600.3400268554688,
#  'low': 600.0,
#  'open': 600.0700073242188,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 49, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 316901}
# {'_id': ObjectId('67bc532a75c878a341a4446b'),
#  'close': 600.0640258789062,
#  'high': 600.1099853515625,
#  'low': 599.8599853515625,
#  'open': 599.8900146484375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 48, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 374513}
# {'_id': ObjectId('67bc532a75c878a341a4446c'),
#  'close': 599.8900146484375,
#  'high': 599.9500122070312,
#  'low': 599.780029296875,
#  'open': 599.780029296875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 47, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 323456}
# {'_id': ObjectId('67bc532a75c878a341a4446d'),
#  'close': 599.7899780273438,
#  'high': 600.02001953125,
#  'low': 599.7100219726562,
#  'open': 599.9600219726562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 46, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 263789}
# {'_id': ObjectId('67bc532a75c878a341a4446e'),
#  'close': 599.9550170898438,
#  'high': 600.0700073242188,
#  'low': 599.7999877929688,
#  'open': 600.0599975585938,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 332241}
# {'_id': ObjectId('67bc532a75c878a341a4446f'),
#  'close': 600.0399780273438,
#  'high': 600.510009765625,
#  'low': 600.0349731445312,
#  'open': 600.4591064453125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 44, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 580507}
# {'_id': ObjectId('67bc532a75c878a341a44470'),
#  'close': 600.4400024414062,
#  'high': 600.4600219726562,
#  'low': 600.0700073242188,
#  'open': 600.4400024414062,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 43, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 243765}
# {'_id': ObjectId('67bc532a75c878a341a44471'),
#  'close': 600.0750122070312,
#  'high': 600.3400268554688,
#  'low': 600.0700073242188,
#  'open': 600.3200073242188,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 42, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 394448}
# {'_id': ObjectId('67bc532a75c878a341a44472'),
#  'close': 600.3300170898438,
#  'high': 600.4650268554688,
#  'low': 600.1599731445312,
#  'open': 600.4650268554688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 41, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 232625}
# {'_id': ObjectId('67bc532a75c878a341a44473'),
#  'close': 600.469970703125,
#  'high': 600.6900024414062,
#  'low': 600.4600219726562,
#  'open': 600.5900268554688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 112230}
# {'_id': ObjectId('67bc532a75c878a341a44474'),
#  'close': 600.5900268554688,
#  'high': 600.6599731445312,
#  'low': 600.4550170898438,
#  'open': 600.5700073242188,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 39, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 144623}
# {'_id': ObjectId('67bc532a75c878a341a44475'),
#  'close': 600.5700073242188,
#  'high': 600.6099243164062,
#  'low': 600.3707885742188,
#  'open': 600.489990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 38, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 101666}
# {'_id': ObjectId('67bc532a75c878a341a44476'),
#  'close': 600.489990234375,
#  'high': 600.489990234375,
#  'low': 600.2507934570312,
#  'open': 600.489990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 37, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 304382}
# {'_id': ObjectId('67bc532a75c878a341a44477'),
#  'close': 600.494384765625,
#  'high': 600.6500244140625,
#  'low': 600.494384765625,
#  'open': 600.52001953125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 36, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 124185}
# {'_id': ObjectId('67bc532a75c878a341a44478'),
#  'close': 600.510009765625,
#  'high': 600.739990234375,
#  'low': 600.469970703125,
#  'open': 600.6599731445312,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 119553}
# {'_id': ObjectId('67bc532a75c878a341a44479'),
#  'close': 600.6699829101562,
#  'high': 600.760009765625,
#  'low': 600.5999755859375,
#  'open': 600.6599731445312,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 34, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 171839}
# {'_id': ObjectId('67bc532a75c878a341a4447a'),
#  'close': 600.6300048828125,
#  'high': 600.7999877929688,
#  'low': 600.5900268554688,
#  'open': 600.72998046875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 33, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 126159}
# {'_id': ObjectId('67bc532a75c878a341a4447b'),
#  'close': 600.719970703125,
#  'high': 600.739990234375,
#  'low': 600.4099731445312,
#  'open': 600.4199829101562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 32, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 145336}
# {'_id': ObjectId('67bc532a75c878a341a4447c'),
#  'close': 600.419921875,
#  'high': 600.9099731445312,
#  'low': 600.3699951171875,
#  'open': 600.8200073242188,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 31, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 169144}
# {'_id': ObjectId('67bc532a75c878a341a4447d'),
#  'close': 600.8900146484375,
#  'high': 600.9000244140625,
#  'low': 600.4600219726562,
#  'open': 600.5800170898438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 199799}
# {'_id': ObjectId('67bc532a75c878a341a4447e'),
#  'close': 600.5599975585938,
#  'high': 600.6199951171875,
#  'low': 600.430908203125,
#  'open': 600.5,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 29, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 116280}
# {'_id': ObjectId('67bc532a75c878a341a4447f'),
#  'close': 600.489990234375,
#  'high': 600.6400146484375,
#  'low': 600.4299926757812,
#  'open': 600.489990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 28, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 112729}
# {'_id': ObjectId('67bc532a75c878a341a44480'),
#  'close': 600.4400024414062,
#  'high': 600.5999755859375,
#  'low': 600.3049926757812,
#  'open': 600.47998046875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 27, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 149572}
# {'_id': ObjectId('67bc532a75c878a341a44481'),
#  'close': 600.489990234375,
#  'high': 600.5599975585938,
#  'low': 600.3400268554688,
#  'open': 600.489990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 26, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 95291}
# {'_id': ObjectId('67bc532a75c878a341a44482'),
#  'close': 600.47998046875,
#  'high': 600.6300048828125,
#  'low': 600.2899780273438,
#  'open': 600.6099853515625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 25, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 119057}
# {'_id': ObjectId('67bc532a75c878a341a44483'),
#  'close': 600.5900268554688,
#  'high': 600.6400146484375,
#  'low': 600.47998046875,
#  'open': 600.47998046875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 24, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 211458}
# {'_id': ObjectId('67bc532a75c878a341a44484'),
#  'close': 600.4699096679688,
#  'high': 600.47998046875,
#  'low': 600.1400756835938,
#  'open': 600.2999877929688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 23, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 85986}
# {'_id': ObjectId('67bc532a75c878a341a44485'),
#  'close': 600.3300170898438,
#  'high': 600.389892578125,
#  'low': 600.2000122070312,
#  'open': 600.3599853515625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 22, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 113416}
# {'_id': ObjectId('67bc532a75c878a341a44486'),
#  'close': 600.3400268554688,
#  'high': 600.3800048828125,
#  'low': 600.0999755859375,
#  'open': 600.239990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 21, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 73693}
# {'_id': ObjectId('67bc532a75c878a341a44487'),
#  'close': 600.2301025390625,
#  'high': 600.2999877929688,
#  'low': 600.0900268554688,
#  'open': 600.260009765625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 20, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 93433}
# {'_id': ObjectId('67bc532a75c878a341a44488'),
#  'close': 600.27001953125,
#  'high': 600.27001953125,
#  'low': 600.27001953125,
#  'open': 600.27001953125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 19, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 1135781}
# {'_id': ObjectId('67bc532a75c878a341a44489'),
#  'close': 600.0700073242188,
#  'high': 600.1599731445312,
#  'low': 599.9000244140625,
#  'open': 600.02490234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 18, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 231274}
# {'_id': ObjectId('67bc532a75c878a341a4448a'),
#  'close': 600.02001953125,
#  'high': 600.2100219726562,
#  'low': 599.8685302734375,
#  'open': 600.02001953125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 17, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 161352}
# {'_id': ObjectId('67bc532a75c878a341a4448b'),
#  'close': 600.1500244140625,
#  'high': 600.2890014648438,
#  'low': 600.0599975585938,
#  'open': 600.2890014648438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 16, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 310874}
# {'_id': ObjectId('67bc532a75c878a341a4448c'),
#  'close': 600.22998046875,
#  'high': 600.2899780273438,
#  'low': 600.1199951171875,
#  'open': 600.1400146484375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 15, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 29247}
# {'_id': ObjectId('67bc532a75c878a341a4448d'),
#  'close': 600.1500244140625,
#  'high': 600.280029296875,
#  'low': 600.0900268554688,
#  'open': 600.1500244140625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 14, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 167958}
# {'_id': ObjectId('67bc532a75c878a341a4448e'),
#  'close': 600.2899780273438,
#  'high': 600.47998046875,
#  'low': 600.1514282226562,
#  'open': 600.4000244140625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 13, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 200988}
# {'_id': ObjectId('67bc532a75c878a341a4448f'),
#  'close': 600.4000244140625,
#  'high': 600.4400024414062,
#  'low': 599.9000244140625,
#  'open': 599.9000244140625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 12, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 176936}
# {'_id': ObjectId('67bc532a75c878a341a44490'),
#  'close': 599.8900146484375,
#  'high': 599.9500122070312,
#  'low': 599.719970703125,
#  'open': 599.7449951171875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 11, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 358346}
# {'_id': ObjectId('67bc532a75c878a341a44491'),
#  'close': 599.7650146484375,
#  'high': 599.97998046875,
#  'low': 599.6599731445312,
#  'open': 599.9600219726562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 10, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 138038}
# {'_id': ObjectId('67bc532a75c878a341a44492'),
#  'close': 599.9299926757812,
#  'high': 599.9749755859375,
#  'low': 599.8800048828125,
#  'open': 599.9149780273438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 9, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 54532}
# {'_id': ObjectId('67bc532a75c878a341a44493'),
#  'close': 599.9400024414062,
#  'high': 600.1099853515625,
#  'low': 599.8800048828125,
#  'open': 600.0900268554688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 8, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 67159}
# {'_id': ObjectId('67bc532a75c878a341a44494'),
#  'close': 600.0999755859375,
#  'high': 600.25,
#  'low': 600.0150146484375,
#  'open': 600.1500244140625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 7, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 50622}
# {'_id': ObjectId('67bc532a75c878a341a44495'),
#  'close': 600.135009765625,
#  'high': 600.239990234375,
#  'low': 600.0200805664062,
#  'open': 600.030029296875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 6, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 70169}
# {'_id': ObjectId('67bc532a75c878a341a44496'),
#  'close': 600.030029296875,
#  'high': 600.1500244140625,
#  'low': 599.9299926757812,
#  'open': 600.0250244140625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 5, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 66433}
# {'_id': ObjectId('67bc532a75c878a341a44497'),
#  'close': 600.02001953125,
#  'high': 600.02001953125,
#  'low': 600.02001953125,
#  'open': 600.02001953125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 4, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 68653}
# {'_id': ObjectId('67bc532a75c878a341a44498'),
#  'close': 600.0599975585938,
#  'high': 600.1400146484375,
#  'low': 599.77001953125,
#  'open': 599.8900146484375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 3, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 55768}
# {'_id': ObjectId('67bc532a75c878a341a44499'),
#  'close': 599.8699951171875,
#  'high': 599.9299926757812,
#  'low': 599.760009765625,
#  'open': 599.8200073242188,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 2, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 100119}
# {'_id': ObjectId('67bc532a75c878a341a4449a'),
#  'close': 599.8336791992188,
#  'high': 600.4199829101562,
#  'low': 599.7899780273438,
#  'open': 600.22998046875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 1, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 126588}
# {'_id': ObjectId('67bc532a75c878a341a4449b'),
#  'close': 600.22998046875,
#  'high': 600.260009765625,
#  'low': 599.760009765625,
#  'open': 600.030029296875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 151599}
# {'_id': ObjectId('67bc532a75c878a341a4449c'),
#  'close': 600.0349731445312,
#  'high': 600.2849731445312,
#  'low': 600.0,
#  'open': 600.280029296875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 59, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 150950}
# {'_id': ObjectId('67bc532a75c878a341a4449d'),
#  'close': 600.2650146484375,
#  'high': 600.4400024414062,
#  'low': 600.1799926757812,
#  'open': 600.2899780273438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 58, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 116792}
# {'_id': ObjectId('67bc532a75c878a341a4449e'),
#  'close': 600.27001953125,
#  'high': 600.6099853515625,
#  'low': 600.27001953125,
#  'open': 600.4949951171875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 57, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 96602}
# {'_id': ObjectId('67bc532a75c878a341a4449f'),
#  'close': 600.510009765625,
#  'high': 600.5650024414062,
#  'low': 600.4099731445312,
#  'open': 600.469970703125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 56, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 501330}
# {'_id': ObjectId('67bc532a75c878a341a444a0'),
#  'close': 600.4600219726562,
#  'high': 600.4600219726562,
#  'low': 600.0899047851562,
#  'open': 600.4600219726562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 120516}
# {'_id': ObjectId('67bc532a75c878a341a444a1'),
#  'close': 600.0999755859375,
#  'high': 600.4349975585938,
#  'low': 599.989990234375,
#  'open': 600.4349975585938,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 54, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 145391}
# {'_id': ObjectId('67bc532a75c878a341a444a2'),
#  'close': 600.4450073242188,
#  'high': 600.6599731445312,
#  'low': 600.3300170898438,
#  'open': 600.6099853515625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 53, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 120728}
# {'_id': ObjectId('67bc532a75c878a341a444a3'),
#  'close': 600.6300048828125,
#  'high': 600.6400146484375,
#  'low': 600.4000244140625,
#  'open': 600.4000244140625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 52, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 133432}
# {'_id': ObjectId('67bc532a75c878a341a444a4'),
#  'close': 600.4000244140625,
#  'high': 600.5399780273438,
#  'low': 600.3599853515625,
#  'open': 600.39501953125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 51, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 190801}
# {'_id': ObjectId('67bc532a75c878a341a444a5'),
#  'close': 600.3900146484375,
#  'high': 600.4000244140625,
#  'low': 599.9349975585938,
#  'open': 599.9500122070312,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 152119}
# {'_id': ObjectId('67bc532a75c878a341a444a6'),
#  'close': 599.9400024414062,
#  'high': 600.1699829101562,
#  'low': 599.9000244140625,
#  'open': 599.9500122070312,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 49, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 137515}
# {'_id': ObjectId('67bc532a75c878a341a444a7'),
#  'close': 599.9500122070312,
#  'high': 600.0189819335938,
#  'low': 599.719970703125,
#  'open': 599.8200073242188,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 48, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 130422}
# {'_id': ObjectId('67bc532a75c878a341a444a8'),
#  'close': 599.7999877929688,
#  'high': 599.989990234375,
#  'low': 599.7000122070312,
#  'open': 599.9000244140625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 47, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 79047}
# {'_id': ObjectId('67bc532a75c878a341a444a9'),
#  'close': 599.9000244140625,
#  'high': 600.0654907226562,
#  'low': 599.7899780273438,
#  'open': 599.8599853515625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 46, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 267064}
# {'_id': ObjectId('67bc532a75c878a341a444aa'),
#  'close': 599.8499755859375,
#  'high': 600.2000122070312,
#  'low': 599.8499755859375,
#  'open': 600.0700073242188,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 230814}
# {'_id': ObjectId('67bc532a75c878a341a444ab'),
#  'close': 600.0900268554688,
#  'high': 600.1400146484375,
#  'low': 599.7899780273438,
#  'open': 599.9500122070312,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 44, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 156669}
# {'_id': ObjectId('67bc532a75c878a341a444ac'),
#  'close': 599.9500122070312,
#  'high': 599.989990234375,
#  'low': 599.6099853515625,
#  'open': 599.6099853515625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 43, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 151759}
# {'_id': ObjectId('67bc532a75c878a341a444ad'),
#  'close': 599.5999755859375,
#  'high': 599.7000122070312,
#  'low': 599.469970703125,
#  'open': 599.5800170898438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 42, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 135640}
# {'_id': ObjectId('67bc532a75c878a341a444ae'),
#  'close': 599.6199951171875,
#  'high': 599.760009765625,
#  'low': 599.530029296875,
#  'open': 599.719970703125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 41, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 104415}
# {'_id': ObjectId('67bc532a75c878a341a444af'),
#  'close': 599.7249755859375,
#  'high': 599.9099731445312,
#  'low': 599.6900024414062,
#  'open': 599.8099975585938,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 90119}
# {'_id': ObjectId('67bc532a75c878a341a444b0'),
#  'close': 599.780029296875,
#  'high': 599.9199829101562,
#  'low': 599.655029296875,
#  'open': 599.739990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 39, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 79365}
# {'_id': ObjectId('67bc532a75c878a341a444b1'),
#  'close': 599.7498779296875,
#  'high': 600.1199951171875,
#  'low': 599.6199951171875,
#  'open': 600.0999755859375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 38, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 105969}
# {'_id': ObjectId('67bc532a75c878a341a444b2'),
#  'close': 600.0800170898438,
#  'high': 600.0900268554688,
#  'low': 599.739990234375,
#  'open': 599.989990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 37, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 95528}
# {'_id': ObjectId('67bc532a75c878a341a444b3'),
#  'close': 600.0,
#  'high': 600.0,
#  'low': 600.0,
#  'open': 600.0,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 36, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 39283}
# {'_id': ObjectId('67bc532a75c878a341a444b4'),
#  'close': 600.0499877929688,
#  'high': 600.2899780273438,
#  'low': 599.9650268554688,
#  'open': 600.1500244140625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 78548}
# {'_id': ObjectId('67bc532a75c878a341a444b5'),
#  'close': 600.1500244140625,
#  'high': 600.4600219726562,
#  'low': 600.1099853515625,
#  'open': 600.4600219726562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 34, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 88763}
# {'_id': ObjectId('67bc532a75c878a341a444b6'),
#  'close': 600.4598999023438,
#  'high': 600.64501953125,
#  'low': 600.3699951171875,
#  'open': 600.3699951171875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 33, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 102084}
# {'_id': ObjectId('67bc532a75c878a341a444b7'),
#  'close': 600.3599853515625,
#  'high': 600.52001953125,
#  'low': 600.2050170898438,
#  'open': 600.2050170898438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 32, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 106016}
# {'_id': ObjectId('67bc532a75c878a341a444b8'),
#  'close': 600.2100219726562,
#  'high': 600.52001953125,
#  'low': 600.094970703125,
#  'open': 600.3900146484375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 31, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 311390}
# {'_id': ObjectId('67bc532a75c878a341a444b9'),
#  'close': 600.3800048828125,
#  'high': 600.4000244140625,
#  'low': 599.8101196289062,
#  'open': 599.909912109375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 184897}
# {'_id': ObjectId('67bc532a75c878a341a444ba'),
#  'close': 599.9099731445312,
#  'high': 600.4299926757812,
#  'low': 599.6500244140625,
#  'open': 599.9099731445312,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 29, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 385327}
# {'_id': ObjectId('67bc532a75c878a341a444bb'),
#  'close': 600.3599853515625,
#  'high': 600.52001953125,
#  'low': 600.25,
#  'open': 600.4199829101562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 28, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 154030}
# {'_id': ObjectId('67bc532a75c878a341a444bc'),
#  'close': 600.4500122070312,
#  'high': 600.6099853515625,
#  'low': 600.1400146484375,
#  'open': 600.1732788085938,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 27, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 191241}
# {'_id': ObjectId('67bc532a75c878a341a444bd'),
#  'close': 600.1799926757812,
#  'high': 600.530029296875,
#  'low': 600.1599731445312,
#  'open': 600.5,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 26, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 77487}
# {'_id': ObjectId('67bc532a75c878a341a444be'),
#  'close': 600.5,
#  'high': 600.7100219726562,
#  'low': 600.4000244140625,
#  'open': 600.5,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 25, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 109205}
# {'_id': ObjectId('67bc532a75c878a341a444bf'),
#  'close': 600.6699829101562,
#  'high': 600.6900024414062,
#  'low': 600.4500122070312,
#  'open': 600.5900268554688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 24, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 226947}
# {'_id': ObjectId('67bc532a75c878a341a444c0'),
#  'close': 600.5999755859375,
#  'high': 600.8400268554688,
#  'low': 600.5499877929688,
#  'open': 600.7100219726562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 23, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 75547}
# {'_id': ObjectId('67bc532a75c878a341a444c1'),
#  'close': 600.77001953125,
#  'high': 600.8499755859375,
#  'low': 600.6589965820312,
#  'open': 600.760009765625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 22, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 112335}
# {'_id': ObjectId('67bc532a75c878a341a444c2'),
#  'close': 600.75,
#  'high': 601.030029296875,
#  'low': 600.72998046875,
#  'open': 600.969970703125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 21, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 132250}
# {'_id': ObjectId('67bc532a75c878a341a444c3'),
#  'close': 600.9400024414062,
#  'high': 601.3699951171875,
#  'low': 600.9400024414062,
#  'open': 601.3300170898438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 20, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 183032}
# {'_id': ObjectId('67bc532a75c878a341a444c4'),
#  'close': 601.3699951171875,
#  'high': 601.7498779296875,
#  'low': 601.3400268554688,
#  'open': 601.6500244140625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 19, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 94731}
# {'_id': ObjectId('67bc532a75c878a341a444c5'),
#  'close': 601.6502075195312,
#  'high': 601.7100219726562,
#  'low': 601.5599975585938,
#  'open': 601.6699829101562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 18, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 188636}
# {'_id': ObjectId('67bc532a75c878a341a444c6'),
#  'close': 601.669921875,
#  'high': 601.77001953125,
#  'low': 601.5999755859375,
#  'open': 601.5999755859375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 17, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 83458}
# {'_id': ObjectId('67bc532a75c878a341a444c7'),
#  'close': 601.6199951171875,
#  'high': 601.9249877929688,
#  'low': 601.530029296875,
#  'open': 601.6199951171875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 16, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 80457}
# {'_id': ObjectId('67bc532a75c878a341a444c8'),
#  'close': 601.9349975585938,
#  'high': 602.14501953125,
#  'low': 601.9299926757812,
#  'open': 602.14501953125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 15, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 74876}
# {'_id': ObjectId('67bc532a75c878a341a444c9'),
#  'close': 602.1400146484375,
#  'high': 602.3300170898438,
#  'low': 601.969970703125,
#  'open': 601.9824829101562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 14, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 118232}
# {'_id': ObjectId('67bc532a75c878a341a444ca'),
#  'close': 601.989990234375,
#  'high': 602.02001953125,
#  'low': 601.7999877929688,
#  'open': 601.7999877929688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 13, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 110587}
# {'_id': ObjectId('67bc532a75c878a341a444cb'),
#  'close': 601.7899780273438,
#  'high': 601.7971801757812,
#  'low': 601.5050048828125,
#  'open': 601.5250244140625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 12, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 84099}
# {'_id': ObjectId('67bc532a75c878a341a444cc'),
#  'close': 601.5250244140625,
#  'high': 601.8699951171875,
#  'low': 601.4299926757812,
#  'open': 601.7999877929688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 11, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 163515}
# {'_id': ObjectId('67bc532a75c878a341a444cd'),
#  'close': 601.780029296875,
#  'high': 601.7999877929688,
#  'low': 601.6212158203125,
#  'open': 601.760009765625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 10, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 100566}
# {'_id': ObjectId('67bc532a75c878a341a444ce'),
#  'close': 601.75,
#  'high': 601.75,
#  'low': 601.530029296875,
#  'open': 601.5399780273438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 9, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 131411}
# {'_id': ObjectId('67bc532a75c878a341a444cf'),
#  'close': 601.530029296875,
#  'high': 601.6900024414062,
#  'low': 601.4099731445312,
#  'open': 601.489990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 8, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 70142}
# {'_id': ObjectId('67bc532a75c878a341a444d0'),
#  'close': 601.469970703125,
#  'high': 601.530029296875,
#  'low': 601.3800048828125,
#  'open': 601.4400024414062,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 7, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 185950}
# {'_id': ObjectId('67bc532a75c878a341a444d1'),
#  'close': 601.4299926757812,
#  'high': 601.5999755859375,
#  'low': 601.3400268554688,
#  'open': 601.3400268554688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 6, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 97733}
# {'_id': ObjectId('67bc532a75c878a341a444d2'),
#  'close': 601.3499755859375,
#  'high': 601.47998046875,
#  'low': 601.25,
#  'open': 601.3499755859375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 5, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 107910}
# {'_id': ObjectId('67bc532a75c878a341a444d3'),
#  'close': 601.364990234375,
#  'high': 601.417724609375,
#  'low': 601.22998046875,
#  'open': 601.3800048828125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 4, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 138405}
# {'_id': ObjectId('67bc532a75c878a341a444d4'),
#  'close': 601.3699951171875,
#  'high': 601.4600219726562,
#  'low': 601.3250122070312,
#  'open': 601.3400268554688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 3, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 282011}
# {'_id': ObjectId('67bc532a75c878a341a444d5'),
#  'close': 601.3400268554688,
#  'high': 601.5900268554688,
#  'low': 601.3400268554688,
#  'open': 601.489990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 2, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 103399}
# {'_id': ObjectId('67bc532a75c878a341a444d6'),
#  'close': 601.47998046875,
#  'high': 601.8150024414062,
#  'low': 601.22998046875,
#  'open': 601.7849731445312,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 1, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 208987}
# {'_id': ObjectId('67bc532a75c878a341a444d7'),
#  'close': 601.77001953125,
#  'high': 601.9099731445312,
#  'low': 601.6828002929688,
#  'open': 601.760009765625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 51534}
# {'_id': ObjectId('67bc532a75c878a341a444d8'),
#  'close': 601.7534790039062,
#  'high': 601.780029296875,
#  'low': 601.5700073242188,
#  'open': 601.6199951171875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 59, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 87624}
# {'_id': ObjectId('67bc532a75c878a341a444d9'),
#  'close': 601.6599731445312,
#  'high': 601.8699951171875,
#  'low': 601.6400146484375,
#  'open': 601.8599853515625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 58, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 69644}
# {'_id': ObjectId('67bc532a75c878a341a444da'),
#  'close': 601.8400268554688,
#  'high': 602.0599975585938,
#  'low': 601.719970703125,
#  'open': 602.0499877929688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 57, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 144499}
# {'_id': ObjectId('67bc532a75c878a341a444db'),
#  'close': 602.0704956054688,
#  'high': 602.1900024414062,
#  'low': 601.969970703125,
#  'open': 602.0900268554688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 56, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 65628}
# {'_id': ObjectId('67bc532a75c878a341a444dc'),
#  'close': 602.10498046875,
#  'high': 602.2100219726562,
#  'low': 602.0399780273438,
#  'open': 602.1900024414062,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 161467}
# {'_id': ObjectId('67bc532a75c878a341a444dd'),
#  'close': 602.2100219726562,
#  'high': 602.219970703125,
#  'low': 602.0408935546875,
#  'open': 602.0408935546875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 54, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 72527}
# {'_id': ObjectId('67bc532a75c878a341a444de'),
#  'close': 602.0700073242188,
#  'high': 602.22998046875,
#  'low': 601.8099975585938,
#  'open': 601.9349975585938,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 53, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 85442}
# {'_id': ObjectId('67bc532a75c878a341a444df'),
#  'close': 601.9349975585938,
#  'high': 602.0897216796875,
#  'low': 601.9099731445312,
#  'open': 601.989990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 52, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 32546}
# {'_id': ObjectId('67bc532a75c878a341a444e0'),
#  'close': 602.0599975585938,
#  'high': 602.1199951171875,
#  'low': 601.9099731445312,
#  'open': 601.969970703125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 51, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 51464}
# {'_id': ObjectId('67bc532a75c878a341a444e1'),
#  'close': 601.9605102539062,
#  'high': 602.2000122070312,
#  'low': 601.8800048828125,
#  'open': 601.8800048828125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 90602}
# {'_id': ObjectId('67bc532a75c878a341a444e2'),
#  'close': 601.9099731445312,
#  'high': 601.989990234375,
#  'low': 601.780029296875,
#  'open': 601.9099731445312,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 49, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 114926}
# {'_id': ObjectId('67bc532a75c878a341a444e3'),
#  'close': 601.9099731445312,
#  'high': 602.010009765625,
#  'low': 601.8099975585938,
#  'open': 601.9099731445312,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 48, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 304982}
# {'_id': ObjectId('67bc532a75c878a341a444e4'),
#  'close': 601.9500122070312,
#  'high': 602.0499877929688,
#  'low': 601.780029296875,
#  'open': 601.9500122070312,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 47, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 192497}
# {'_id': ObjectId('67bc532a75c878a341a444e5'),
#  'close': 601.8200073242188,
#  'high': 601.9199829101562,
#  'low': 601.739990234375,
#  'open': 601.9000244140625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 46, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 163590}
# {'_id': ObjectId('67bc532a75c878a341a444e6'),
#  'close': 601.8800048828125,
#  'high': 601.9500122070312,
#  'low': 601.77001953125,
#  'open': 601.8300170898438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 76845}
# {'_id': ObjectId('67bc532a75c878a341a444e7'),
#  'close': 601.8399047851562,
#  'high': 602.1199951171875,
#  'low': 601.8200073242188,
#  'open': 602.0499877929688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 44, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 78176}
# {'_id': ObjectId('67bc532a75c878a341a444e8'),
#  'close': 602.0435180664062,
#  'high': 602.3499755859375,
#  'low': 602.030029296875,
#  'open': 602.280029296875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 43, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 48597}
# {'_id': ObjectId('67bc532a75c878a341a444e9'),
#  'close': 602.27001953125,
#  'high': 602.3400268554688,
#  'low': 602.010009765625,
#  'open': 602.052490234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 42, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 80710}
# {'_id': ObjectId('67bc532a75c878a341a444ea'),
#  'close': 602.0599975585938,
#  'high': 602.4550170898438,
#  'low': 602.0599975585938,
#  'open': 602.3800048828125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 41, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 73522}
# {'_id': ObjectId('67bc532a75c878a341a444eb'),
#  'close': 602.4349975585938,
#  'high': 602.7100219726562,
#  'low': 602.4199829101562,
#  'open': 602.4199829101562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 67417}
# {'_id': ObjectId('67bc532a75c878a341a444ec'),
#  'close': 602.3887329101562,
#  'high': 602.8400268554688,
#  'low': 602.3499755859375,
#  'open': 602.8300170898438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 39, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 98159}
# {'_id': ObjectId('67bc532a75c878a341a444ed'),
#  'close': 602.8499755859375,
#  'high': 603.2249755859375,
#  'low': 602.7550048828125,
#  'open': 602.989990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 38, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 236312}
# {'_id': ObjectId('67bc532a75c878a341a444ee'),
#  'close': 602.9600219726562,
#  'high': 602.9777221679688,
#  'low': 602.5,
#  'open': 602.5599975585938,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 37, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 140738}
# {'_id': ObjectId('67bc532a75c878a341a444ef'),
#  'close': 602.530029296875,
#  'high': 602.5850219726562,
#  'low': 602.1950073242188,
#  'open': 602.2297973632812,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 36, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 219967}
# {'_id': ObjectId('67bc532a75c878a341a444f0'),
#  'close': 602.2550048828125,
#  'high': 602.3599853515625,
#  'low': 602.010009765625,
#  'open': 602.0599975585938,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 239320}
# {'_id': ObjectId('67bc532a75c878a341a444f1'),
#  'close': 602.0499877929688,
#  'high': 602.1599731445312,
#  'low': 601.844970703125,
#  'open': 601.9718017578125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 34, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 782212}
# {'_id': ObjectId('67bc532a75c878a341a444f2'),
#  'close': 601.9749755859375,
#  'high': 602.0599975585938,
#  'low': 601.739990234375,
#  'open': 601.739990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 33, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 103547}
# {'_id': ObjectId('67bc532a75c878a341a444f3'),
#  'close': 601.7999877929688,
#  'high': 601.8699951171875,
#  'low': 601.5900268554688,
#  'open': 601.6900024414062,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 32, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 129459}
# {'_id': ObjectId('67bc532a75c878a341a444f4'),
#  'close': 601.7100219726562,
#  'high': 602.0399780273438,
#  'low': 601.6710205078125,
#  'open': 602.02001953125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 31, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 135496}
# {'_id': ObjectId('67bc532a75c878a341a444f5'),
#  'close': 602.030029296875,
#  'high': 602.1900024414062,
#  'low': 601.8599853515625,
#  'open': 602.14501953125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 180075}
# {'_id': ObjectId('67bc532a75c878a341a444f6'),
#  'close': 602.1599731445312,
#  'high': 602.510009765625,
#  'low': 602.10009765625,
#  'open': 602.5,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 29, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 113116}
# {'_id': ObjectId('67bc532a75c878a341a444f7'),
#  'close': 602.530029296875,
#  'high': 602.6199951171875,
#  'low': 602.39501953125,
#  'open': 602.6199951171875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 28, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 135323}
# {'_id': ObjectId('67bc532a75c878a341a444f8'),
#  'close': 602.6199951171875,
#  'high': 602.8099975585938,
#  'low': 602.530029296875,
#  'open': 602.7999877929688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 27, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 105285}
# {'_id': ObjectId('67bc532a75c878a341a444f9'),
#  'close': 602.8499755859375,
#  'high': 603.0499877929688,
#  'low': 602.7899780273438,
#  'open': 602.969970703125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 26, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 65448}
# {'_id': ObjectId('67bc532a75c878a341a444fa'),
#  'close': 602.951171875,
#  'high': 603.0,
#  'low': 602.60498046875,
#  'open': 602.65869140625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 25, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 69766}
# {'_id': ObjectId('67bc532a75c878a341a444fb'),
#  'close': 602.6900024414062,
#  'high': 602.7899780273438,
#  'low': 602.5399780273438,
#  'open': 602.6900024414062,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 24, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 86309}
# {'_id': ObjectId('67bc532a75c878a341a444fc'),
#  'close': 602.7750244140625,
#  'high': 603.010009765625,
#  'low': 602.6099853515625,
#  'open': 602.6199951171875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 23, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 123288}
# {'_id': ObjectId('67bc532a75c878a341a444fd'),
#  'close': 602.6500244140625,
#  'high': 602.6987915039062,
#  'low': 602.5599975585938,
#  'open': 602.5999755859375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 22, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 114966}
# {'_id': ObjectId('67bc532a75c878a341a444fe'),
#  'close': 602.6199951171875,
#  'high': 602.780029296875,
#  'low': 602.530029296875,
#  'open': 602.760009765625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 21, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 130416}
# {'_id': ObjectId('67bc532a75c878a341a444ff'),
#  'close': 602.77001953125,
#  'high': 602.97998046875,
#  'low': 602.719970703125,
#  'open': 602.8599243164062,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 21, 18, 20, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 61325}
# {'_id': ObjectId('67bc532a75c878a341a44500'),
#  'close': 602.8499755859375,
# ...
#  'open': 609.7999877929688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 23, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 155042}
# {'_id': ObjectId('67bc532a75c878a341a44a40'),
#  'close': 609.780029296875,
#  'high': 609.8599853515625,
#  'low': 609.72998046875,
#  'open': 609.760009765625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 22, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 78155}
# {'_id': ObjectId('67bc532a75c878a341a44a41'),
#  'close': 609.7938232421875,
#  'high': 609.8699951171875,
#  'low': 609.6799926757812,
#  'open': 609.8499755859375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 21, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 54900}
# {'_id': ObjectId('67bc532a75c878a341a44a42'),
#  'close': 609.8499755859375,
#  'high': 609.8569946289062,
#  'low': 609.489990234375,
#  'open': 609.8499755859375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 20, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 52375}
# {'_id': ObjectId('67bc532a75c878a341a44a43'),
#  'close': 609.5499877929688,
#  'high': 609.8099975585938,
#  'low': 609.469970703125,
#  'open': 609.760009765625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 19, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 115459}
# {'_id': ObjectId('67bc532a75c878a341a44a44'),
#  'close': 609.7899780273438,
#  'high': 609.8699951171875,
#  'low': 609.6699829101562,
#  'open': 609.6699829101562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 18, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 37188}
# {'_id': ObjectId('67bc532a75c878a341a44a45'),
#  'close': 609.669921875,
#  'high': 609.7999877929688,
#  'low': 609.5748901367188,
#  'open': 609.6500244140625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 17, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 50950}
# {'_id': ObjectId('67bc532a75c878a341a44a46'),
#  'close': 609.6799926757812,
#  'high': 609.989990234375,
#  'low': 609.6799926757812,
#  'open': 609.969970703125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 16, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 53806}
# {'_id': ObjectId('67bc532a75c878a341a44a47'),
#  'close': 609.969970703125,
#  'high': 610.2000122070312,
#  'low': 609.89501953125,
#  'open': 610.1500244140625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 15, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 43816}
# {'_id': ObjectId('67bc532a75c878a341a44a48'),
#  'close': 610.1400146484375,
#  'high': 610.2127685546875,
#  'low': 610.1099853515625,
#  'open': 610.2100219726562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 14, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 52219}
# {'_id': ObjectId('67bc532a75c878a341a44a49'),
#  'close': 610.2100219726562,
#  'high': 610.3098754882812,
#  'low': 610.0900268554688,
#  'open': 610.0900268554688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 13, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 66142}
# {'_id': ObjectId('67bc532a75c878a341a44a4a'),
#  'close': 610.0599975585938,
#  'high': 610.0599975585938,
#  'low': 609.8499755859375,
#  'open': 609.9199829101562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 12, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 31827}
# {'_id': ObjectId('67bc532a75c878a341a44a4b'),
#  'close': 609.89990234375,
#  'high': 609.98681640625,
#  'low': 609.7000122070312,
#  'open': 609.739990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 11, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 26960}
# {'_id': ObjectId('67bc532a75c878a341a44a4c'),
#  'close': 609.7249755859375,
#  'high': 609.9099731445312,
#  'low': 609.6599731445312,
#  'open': 609.9099731445312,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 10, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 59474}
# {'_id': ObjectId('67bc532a75c878a341a44a4d'),
#  'close': 609.9199829101562,
#  'high': 610.0,
#  'low': 609.8599853515625,
#  'open': 610.0,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 9, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 54592}
# {'_id': ObjectId('67bc532a75c878a341a44a4e'),
#  'close': 610.02001953125,
#  'high': 610.02001953125,
#  'low': 609.860107421875,
#  'open': 610.010009765625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 8, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 40222}
# {'_id': ObjectId('67bc532a75c878a341a44a4f'),
#  'close': 610.0098266601562,
#  'high': 610.030029296875,
#  'low': 609.9102172851562,
#  'open': 609.9299926757812,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 7, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 29859}
# {'_id': ObjectId('67bc532a75c878a341a44a50'),
#  'close': 609.9199829101562,
#  'high': 609.97998046875,
#  'low': 609.7100219726562,
#  'open': 609.7899780273438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 6, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 69017}
# {'_id': ObjectId('67bc532a75c878a341a44a51'),
#  'close': 609.780029296875,
#  'high': 609.9000244140625,
#  'low': 609.6199951171875,
#  'open': 609.8499755859375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 5, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 65590}
# {'_id': ObjectId('67bc532a75c878a341a44a52'),
#  'close': 609.844970703125,
#  'high': 609.9000244140625,
#  'low': 609.6500244140625,
#  'open': 609.75,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 4, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 39108}
# {'_id': ObjectId('67bc532a75c878a341a44a53'),
#  'close': 609.719970703125,
#  'high': 609.7835083007812,
#  'low': 609.4600219726562,
#  'open': 609.5499877929688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 3, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 61697}
# {'_id': ObjectId('67bc532a75c878a341a44a54'),
#  'close': 609.5599975585938,
#  'high': 609.7449951171875,
#  'low': 609.3300170898438,
#  'open': 609.5,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 2, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 161265}
# {'_id': ObjectId('67bc532a75c878a341a44a55'),
#  'close': 609.489990234375,
#  'high': 609.489990234375,
#  'low': 609.489990234375,
#  'open': 609.489990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 1, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 152278}
# {'_id': ObjectId('67bc532a75c878a341a44a56'),
#  'close': 609.8350219726562,
#  'high': 610.155029296875,
#  'low': 609.77001953125,
#  'open': 609.8350219726562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 152082}
# {'_id': ObjectId('67bc532a75c878a341a44a57'),
#  'close': 610.1099853515625,
#  'high': 610.3699951171875,
#  'low': 610.0737915039062,
#  'open': 610.3699951171875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 59, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 80085}
# {'_id': ObjectId('67bc532a75c878a341a44a58'),
#  'close': 610.3900146484375,
#  'high': 610.5449829101562,
#  'low': 610.3900146484375,
#  'open': 610.4749755859375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 58, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 54122}
# {'_id': ObjectId('67bc532a75c878a341a44a59'),
#  'close': 610.4749755859375,
#  'high': 610.6300048828125,
#  'low': 610.4600219726562,
#  'open': 610.6300048828125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 57, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 48260}
# {'_id': ObjectId('67bc532a75c878a341a44a5a'),
#  'close': 610.6099853515625,
#  'high': 610.6300048828125,
#  'low': 610.4600219726562,
#  'open': 610.510009765625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 56, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 56442}
# {'_id': ObjectId('67bc532a75c878a341a44a5b'),
#  'close': 610.5399780273438,
#  'high': 610.5399780273438,
#  'low': 610.4000244140625,
#  'open': 610.4000244140625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 85276}
# {'_id': ObjectId('67bc532a75c878a341a44a5c'),
#  'close': 610.419921875,
#  'high': 610.6099853515625,
#  'low': 610.39501953125,
#  'open': 610.5399780273438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 54, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 69969}
# {'_id': ObjectId('67bc532a75c878a341a44a5d'),
#  'close': 610.5499877929688,
#  'high': 610.6199951171875,
#  'low': 610.47998046875,
#  'open': 610.47998046875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 53, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 77336}
# {'_id': ObjectId('67bc532a75c878a341a44a5e'),
#  'close': 610.4199829101562,
#  'high': 610.47998046875,
#  'low': 610.219970703125,
#  'open': 610.2506713867188,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 52, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 71883}
# {'_id': ObjectId('67bc532a75c878a341a44a5f'),
#  'close': 610.25,
#  'high': 610.2689819335938,
#  'low': 610.030029296875,
#  'open': 610.0599975585938,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 51, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 62263}
# {'_id': ObjectId('67bc532a75c878a341a44a60'),
#  'close': 610.0650024414062,
#  'high': 610.3099975585938,
#  'low': 609.9500122070312,
#  'open': 610.25,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 75115}
# {'_id': ObjectId('67bc532a75c878a341a44a61'),
#  'close': 610.2698974609375,
#  'high': 610.3699951171875,
#  'low': 610.219970703125,
#  'open': 610.2999877929688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 49, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 60436}
# {'_id': ObjectId('67bc532a75c878a341a44a62'),
#  'close': 610.280029296875,
#  'high': 610.3300170898438,
#  'low': 610.0438232421875,
#  'open': 610.0438232421875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 48, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 100997}
# {'_id': ObjectId('67bc532a75c878a341a44a63'),
#  'close': 610.0399169921875,
#  'high': 610.1998901367188,
#  'low': 609.9600219726562,
#  'open': 610.1799926757812,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 47, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 81853}
# {'_id': ObjectId('67bc532a75c878a341a44a64'),
#  'close': 610.2000122070312,
#  'high': 610.4600219726562,
#  'low': 610.1099853515625,
#  'open': 610.2000122070312,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 46, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 72192}
# {'_id': ObjectId('67bc532a75c878a341a44a65'),
#  'close': 610.1900024414062,
#  'high': 610.4149780273438,
#  'low': 610.1699829101562,
#  'open': 610.1849975585938,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 129269}
# {'_id': ObjectId('67bc532a75c878a341a44a66'),
#  'close': 610.1801147460938,
#  'high': 610.5800170898438,
#  'low': 610.0999755859375,
#  'open': 610.489990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 44, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 101647}
# {'_id': ObjectId('67bc532a75c878a341a44a67'),
#  'close': 610.5098876953125,
#  'high': 610.6099853515625,
#  'low': 610.469970703125,
#  'open': 610.5399780273438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 43, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 80958}
# {'_id': ObjectId('67bc532a75c878a341a44a68'),
#  'close': 610.56298828125,
#  'high': 610.7291259765625,
#  'low': 610.530029296875,
#  'open': 610.6400146484375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 42, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 45173}
# {'_id': ObjectId('67bc532a75c878a341a44a69'),
#  'close': 610.6298828125,
#  'high': 610.6599731445312,
#  'low': 610.47998046875,
#  'open': 610.5900268554688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 41, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 63679}
# {'_id': ObjectId('67bc532a75c878a341a44a6a'),
#  'close': 610.6190185546875,
#  'high': 610.8015747070312,
#  'low': 610.5900268554688,
#  'open': 610.75,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 61119}
# {'_id': ObjectId('67bc532a75c878a341a44a6b'),
#  'close': 610.760009765625,
#  'high': 610.760009765625,
#  'low': 610.622802734375,
#  'open': 610.6900024414062,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 39, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 49130}
# {'_id': ObjectId('67bc532a75c878a341a44a6c'),
#  'close': 610.7000122070312,
#  'high': 610.8499755859375,
#  'low': 610.5999755859375,
#  'open': 610.6801147460938,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 38, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 95724}
# {'_id': ObjectId('67bc532a75c878a341a44a6d'),
#  'close': 610.7000122070312,
#  'high': 610.70751953125,
#  'low': 610.2899780273438,
#  'open': 610.539794921875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 37, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 98946}
# {'_id': ObjectId('67bc532a75c878a341a44a6e'),
#  'close': 610.5449829101562,
#  'high': 610.7100219726562,
#  'low': 610.5,
#  'open': 610.6500244140625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 36, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 56562}
# {'_id': ObjectId('67bc532a75c878a341a44a6f'),
#  'close': 610.655029296875,
#  'high': 610.739990234375,
#  'low': 610.6099853515625,
#  'open': 610.6799926757812,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 79603}
# {'_id': ObjectId('67bc532a75c878a341a44a70'),
#  'close': 610.6597290039062,
#  'high': 610.760009765625,
#  'low': 610.5549926757812,
#  'open': 610.7000122070312,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 34, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 77008}
# {'_id': ObjectId('67bc532a75c878a341a44a71'),
#  'close': 610.7000122070312,
#  'high': 610.8400268554688,
#  'low': 610.6500244140625,
#  'open': 610.7050170898438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 33, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 89924}
# {'_id': ObjectId('67bc532a75c878a341a44a72'),
#  'close': 610.7100219726562,
#  'high': 610.780029296875,
#  'low': 610.4000244140625,
#  'open': 610.4500122070312,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 32, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 133589}
# {'_id': ObjectId('67bc532a75c878a341a44a73'),
#  'close': 610.4650268554688,
#  'high': 610.9249877929688,
#  'low': 610.3800048828125,
#  'open': 610.8900146484375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 31, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 169403}
# {'_id': ObjectId('67bc532a75c878a341a44a74'),
#  'close': 610.8723754882812,
#  'high': 611.0,
#  'low': 610.594970703125,
#  'open': 610.8800048828125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 924797}

# %% [markdown]
# ### Data Aggregation

# %%
# Aggregate the data by hour
# Hourly aggregation to get high, low, open, and close values
hourly_aggregation = db.yfinanceMarketData.aggregate([
    {
        "$match": { "symbol": "SPY-USD" }
    },
    {
        "$group": {
            "_id": {
                "symbol": "$symbol",
                "time": {
                    "$dateTrunc": {
                        "date": "$timestamp",
                        "unit": "hour",
                        "binSize": 1
                    }
                }
            },
            "high": { "$max": "$high" },
            "low": { "$min": "$low" },
            "open": { "$first": "$open" },
            "close": { "$last": "$close" }
        }
    },
    {
        "$sort": { "_id.time": 1 }
    }
])

# Store the aggregation result in a list
hourly_results = list(hourly_aggregation)

# Pretty-print the results
for document in hourly_results:
    pprint(document)

# Count the number of documents in the results
print(f"Total documents: {len(hourly_results)}")
# Out:
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.1099853515625,
#  'high': 611.0,
#  'low': 609.9500122070312,
#  'open': 610.8800048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.6099853515625,
#  'high': 610.6199951171875,
#  'low': 609.3300170898438,
#  'open': 609.8350219726562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.25,
#  'high': 610.85498046875,
#  'low': 609.760009765625,
#  'open': 610.60498046875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.3499755859375,
#  'high': 610.5449829101562,
#  'low': 609.780029296875,
#  'open': 610.239990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.6599731445312,
#  'high': 610.65869140625,
#  'low': 609.451904296875,
#  'open': 610.3400268554688}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.8499755859375,
#  'high': 610.0399780273438,
#  'low': 608.3800048828125,
#  'open': 609.655029296875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.3499755859375,
#  'high': 611.3800048828125,
#  'low': 609.6300048828125,
#  'open': 609.8699951171875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.9199829101562,
#  'high': 610.27001953125,
#  'low': 609.6845092773438,
#  'open': 610.0800170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.1400146484375,
#  'high': 610.8900146484375,
#  'low': 609.5599975585938,
#  'open': 609.9199829101562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.7000122070312,
#  'high': 611.77001953125,
#  'low': 610.1400146484375,
#  'open': 610.1400146484375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.5599975585938,
#  'high': 611.9600219726562,
#  'low': 610.8599853515625,
#  'open': 611.6599731445312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.489990234375,
#  'high': 612.0399780273438,
#  'low': 610.6500244140625,
#  'open': 611.5599975585938}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 613.1099853515625,
#  'high': 613.22998046875,
#  'low': 611.4000244140625,
#  'open': 611.52001953125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 612.9000244140625,
#  'high': 613.0999755859375,
#  'low': 611.7999877929688,
#  'open': 613.0800170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 608.3825073242188,
#  'high': 611.6840209960938,
#  'low': 608.3099975585938,
#  'open': 611.5399780273438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 607.3499755859375,
#  'high': 609.52001953125,
#  'low': 607.02001953125,
#  'open': 608.4000244140625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 607.4600219726562,
#  'high': 608.4500122070312,
#  'low': 607.0999755859375,
#  'open': 607.739990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 608.030029296875,
#  'high': 609.0999145507812,
#  'low': 607.280029296875,
#  'open': 607.4500122070312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 608.5999755859375,
#  'high': 608.760009765625,
#  'low': 607.6400146484375,
#  'open': 608.030029296875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.8599853515625,
#  'high': 610.0999755859375,
#  'low': 608.5,
#  'open': 608.5999755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.3900146484375,
#  'high': 610.7000122070312,
#  'low': 609.260009765625,
#  'open': 609.864990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 608.4700927734375,
#  'high': 610.2999877929688,
#  'low': 608.239990234375,
#  'open': 610.1599731445312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 606.8399047851562,
#  'high': 608.6500244140625,
#  'low': 605.7659912109375,
#  'open': 608.5}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 606.8049926757812,
#  'high': 607.5,
#  'low': 606.1799926757812,
#  'open': 607.1199951171875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 603.8200073242188,
#  'high': 607.1292114257812,
#  'low': 603.6199951171875,
#  'open': 606.7999877929688}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 601.7534790039062,
#  'high': 603.8493041992188,
#  'low': 601.5700073242188,
#  'open': 603.8300170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.0349731445312,
#  'high': 602.3300170898438,
#  'low': 599.469970703125,
#  'open': 601.760009765625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.0,
#  'high': 600.9099731445312,
#  'low': 599.5,
#  'open': 600.030029296875}
# Total documents: 28

# %% [markdown]
# ### Calculating Moving Average (MA) - Granulatity unit: hour / binSize: 1 (1 hour)

# %%
# Second step: Calculate Moving Average (MA3) from the hourly aggregated data
aggr_with_ma = db.yfinanceMarketData.aggregate([
    {
        "$match": { "symbol": "SPY-USD" }
    },
    {
        "$group": {
            "_id": {
                "symbol": "$symbol",
                "time": {
                    "$dateTrunc": {
                        "date": "$timestamp",
                        "unit": "hour",
                        "binSize": 1
                    }
                }
            },
            "high": { "$max": "$high" },
            "low": { "$min": "$low" },
            "open": { "$first": "$open" },
            "close": { "$last": "$close" }
        }
    },
    {
        "$sort": { "_id.time": 1 }
    },
    {
        "$setWindowFields": {
            "partitionBy": "$_id.symbol",  # Partition by symbol
            "sortBy": { "_id.time": 1 },  # Sort by time (ascending)
            "output": {
                "ma3": {
                    "$avg": "$close",  # Calculate the average of 'close' field
                    "window": { "documents": [-2, 0] }  # Look at the previous 2 documents and current document
                }
            }
        }
    }
])

# Store the aggregation result in a list
aggr_with_ma_results = list(aggr_with_ma)

# Pretty-print the results with moving average
for document in aggr_with_ma_results:
    pprint(document)

# Count the number of documents in the results
print(f"Total documents: {len(aggr_with_ma_results)}")
# Out:
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.1099853515625,
#  'high': 611.0,
#  'low': 609.9500122070312,
#  'ma3': 610.1099853515625,
#  'open': 610.8800048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.6099853515625,
#  'high': 610.6199951171875,
#  'low': 609.3300170898438,
#  'ma3': 610.3599853515625,
#  'open': 609.8350219726562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.25,
#  'high': 610.85498046875,
#  'low': 609.760009765625,
#  'ma3': 610.3233235677084,
#  'open': 610.60498046875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.3499755859375,
#  'high': 610.5449829101562,
#  'low': 609.780029296875,
#  'ma3': 610.4033203125,
#  'open': 610.239990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.6599731445312,
#  'high': 610.65869140625,
#  'low': 609.451904296875,
#  'ma3': 610.0866495768229,
#  'open': 610.3400268554688}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.8499755859375,
#  'high': 610.0399780273438,
#  'low': 608.3800048828125,
#  'ma3': 609.9533081054688,
#  'open': 609.655029296875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.3499755859375,
#  'high': 611.3800048828125,
#  'low': 609.6300048828125,
#  'ma3': 610.2866414388021,
#  'open': 609.8699951171875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.9199829101562,
#  'high': 610.27001953125,
#  'low': 609.6845092773438,
#  'ma3': 610.3733113606771,
#  'open': 610.0800170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.1400146484375,
#  'high': 610.8900146484375,
#  'low': 609.5599975585938,
#  'ma3': 610.4699910481771,
#  'open': 609.9199829101562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.7000122070312,
#  'high': 611.77001953125,
#  'low': 610.1400146484375,
#  'ma3': 610.586669921875,
#  'open': 610.1400146484375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.5599975585938,
#  'high': 611.9600219726562,
#  'low': 610.8599853515625,
#  'ma3': 611.1333414713541,
#  'open': 611.6599731445312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.489990234375,
#  'high': 612.0399780273438,
#  'low': 610.6500244140625,
#  'ma3': 611.5833333333334,
#  'open': 611.5599975585938}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 613.1099853515625,
#  'high': 613.22998046875,
#  'low': 611.4000244140625,
#  'ma3': 612.0533243815104,
#  'open': 611.52001953125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 612.9000244140625,
#  'high': 613.0999755859375,
#  'low': 611.7999877929688,
#  'ma3': 612.5,
#  'open': 613.0800170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 608.3825073242188,
#  'high': 611.6840209960938,
#  'low': 608.3099975585938,
#  'ma3': 611.4641723632812,
#  'open': 611.5399780273438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 607.3499755859375,
#  'high': 609.52001953125,
#  'low': 607.02001953125,
#  'ma3': 609.5441691080729,
#  'open': 608.4000244140625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 607.4600219726562,
#  'high': 608.4500122070312,
#  'low': 607.0999755859375,
#  'ma3': 607.7308349609375,
#  'open': 607.739990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 608.030029296875,
#  'high': 609.0999145507812,
#  'low': 607.280029296875,
#  'ma3': 607.6133422851562,
#  'open': 607.4500122070312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 608.5999755859375,
#  'high': 608.760009765625,
#  'low': 607.6400146484375,
#  'ma3': 608.0300089518229,
#  'open': 608.030029296875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.8599853515625,
#  'high': 610.0999755859375,
#  'low': 608.5,
#  'ma3': 608.8299967447916,
#  'open': 608.5999755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.3900146484375,
#  'high': 610.7000122070312,
#  'low': 609.260009765625,
#  'ma3': 609.6166585286459,
#  'open': 609.864990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 608.4700927734375,
#  'high': 610.2999877929688,
#  'low': 608.239990234375,
#  'ma3': 609.5733642578125,
#  'open': 610.1599731445312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 606.8399047851562,
#  'high': 608.6500244140625,
#  'low': 605.7659912109375,
#  'ma3': 608.5666707356771,
#  'open': 608.5}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 606.8049926757812,
#  'high': 607.5,
#  'low': 606.1799926757812,
#  'ma3': 607.3716634114584,
#  'open': 607.1199951171875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 603.8200073242188,
#  'high': 607.1292114257812,
#  'low': 603.6199951171875,
#  'ma3': 605.8216349283854,
#  'open': 606.7999877929688}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 601.7534790039062,
#  'high': 603.8493041992188,
#  'low': 601.5700073242188,
#  'ma3': 604.1261596679688,
#  'open': 603.8300170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.0349731445312,
#  'high': 602.3300170898438,
#  'low': 599.469970703125,
#  'ma3': 601.8694864908854,
#  'open': 601.760009765625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.0,
#  'high': 600.9099731445312,
#  'low': 599.5,
#  'ma3': 600.5961507161459,
#  'open': 600.030029296875}
# Total documents: 28

# %% [markdown]
# ### Calculating Moving Average (MA) - Granulatity unit: minute / binSize: 5 (5 minutes)

# %%
# Second step: Calculate Moving Average (MA3) from the hourly aggregated data
aggr_with_ma = db.yfinanceMarketData.aggregate([
    {
        "$match": { "symbol": "SPY-USD" }
    },
    {
        "$group": {
            "_id": {
                "symbol": "$symbol",
                "time": {
                    "$dateTrunc": {
                        "date": "$timestamp",
                        "unit": "minute",
                        "binSize": 5
                    }
                }
            },
            "high": { "$max": "$high" },
            "low": { "$min": "$low" },
            "open": { "$first": "$open" },
            "close": { "$last": "$close" }
        }
    },
    {
        "$sort": { "_id.time": 1 }
    },
    {
        "$setWindowFields": {
            "partitionBy": "$_id.symbol",  # Partition by symbol
            "sortBy": { "_id.time": 1 },  # Sort by time (ascending)
            "output": {
                "ma3": {
                    "$avg": "$close",  # Calculate the average of 'close' field
                    "window": { "documents": [-2, 0] }  # Look at the previous 2 documents and current document
                }
            }
        }
    }
])

# Store the aggregation result in a list
aggr_with_ma_results = list(aggr_with_ma)

# Pretty-print the results with moving average
for document in aggr_with_ma_results:
    pprint(document)

# Count the number of documents in the results
print(f"Total documents: {len(aggr_with_ma_results)}")
# Out:
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.6597290039062,
#  'high': 611.0,
#  'low': 610.3800048828125,
#  'ma3': 610.6597290039062,
#  'open': 610.8800048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 14, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.760009765625,
#  'high': 610.8499755859375,
#  'low': 610.2899780273438,
#  'ma3': 610.7098693847656,
#  'open': 610.6799926757812}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 14, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.1801147460938,
#  'high': 610.8015747070312,
#  'low': 610.0999755859375,
#  'ma3': 610.5332845052084,
#  'open': 610.75}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 14, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.2698974609375,
#  'high': 610.4600219726562,
#  'low': 609.9600219726562,
#  'ma3': 610.4033406575521,
#  'open': 610.1849975585938}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 14, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.419921875,
#  'high': 610.6199951171875,
#  'low': 609.9500122070312,
#  'ma3': 610.2899780273438,
#  'open': 610.25}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 14, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.1099853515625,
#  'high': 610.6300048828125,
#  'low': 610.0737915039062,
#  'ma3': 610.2666015625,
#  'open': 610.4000244140625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.844970703125,
#  'high': 610.155029296875,
#  'low': 609.3300170898438,
#  'ma3': 610.1249593098959,
#  'open': 609.8350219726562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 15, 5, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.9199829101562,
#  'high': 610.030029296875,
#  'low': 609.6199951171875,
#  'ma3': 609.9583129882812,
#  'open': 609.8499755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 15, 10, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.1400146484375,
#  'high': 610.3098754882812,
#  'low': 609.6599731445312,
#  'ma3': 609.9683227539062,
#  'open': 609.9099731445312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 15, 15, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.5499877929688,
#  'high': 610.2000122070312,
#  'low': 609.469970703125,
#  'ma3': 609.8699951171875,
#  'open': 610.1500244140625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 15, 20, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.8099975585938,
#  'high': 610.030029296875,
#  'low': 609.489990234375,
#  'ma3': 609.8333333333334,
#  'open': 609.8499755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 15, 25, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.6300048828125,
#  'high': 609.9600219726562,
#  'low': 609.4199829101562,
#  'ma3': 609.663330078125,
#  'open': 609.85498046875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.6699829101562,
#  'high': 609.864990234375,
#  'low': 609.4000244140625,
#  'ma3': 609.7033284505209,
#  'open': 609.6400146484375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 15, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.0349731445312,
#  'high': 610.1900024414062,
#  'low': 609.6600952148438,
#  'ma3': 609.7783203125,
#  'open': 609.6600952148438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 15, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.1799926757812,
#  'high': 610.22998046875,
#  'low': 609.9299926757812,
#  'ma3': 609.9616495768229,
#  'open': 610.0399780273438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 15, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.9500122070312,
#  'high': 610.2000122070312,
#  'low': 609.6900024414062,
#  'ma3': 610.0549926757812,
#  'open': 610.1699829101562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 15, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.510009765625,
#  'high': 610.510009765625,
#  'low': 609.8499755859375,
#  'ma3': 610.2133382161459,
#  'open': 609.9400024414062}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 15, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.6099853515625,
#  'high': 610.6199951171875,
#  'low': 610.3400268554688,
#  'ma3': 610.3566691080729,
#  'open': 610.52001953125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.489990234375,
#  'high': 610.6099853515625,
#  'low': 610.47998046875,
#  'ma3': 610.5366617838541,
#  'open': 610.60498046875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 16, 5, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.5700073242188,
#  'high': 610.5999755859375,
#  'low': 610.3200073242188,
#  'ma3': 610.5566609700521,
#  'open': 610.3499755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 16, 10, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.4000244140625,
#  'high': 610.739990234375,
#  'low': 610.3699951171875,
#  'ma3': 610.4866739908854,
#  'open': 610.5607299804688}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 16, 15, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.3800048828125,
#  'high': 610.52001953125,
#  'low': 610.3499755859375,
#  'ma3': 610.4500122070312,
#  'open': 610.4027709960938}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 16, 20, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.960205078125,
#  'high': 610.3900146484375,
#  'low': 609.760009765625,
#  'ma3': 610.2467447916666,
#  'open': 610.3698120117188}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 16, 25, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.4099731445312,
#  'high': 610.5,
#  'low': 609.9099731445312,
#  'ma3': 610.2500610351562,
#  'open': 609.989990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.2000122070312,
#  'high': 610.4099731445312,
#  'low': 610.0700073242188,
#  'ma3': 610.1900634765625,
#  'open': 610.2899169921875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 16, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.3900146484375,
#  'high': 610.4299926757812,
#  'low': 610.0900268554688,
#  'ma3': 610.3333333333334,
#  'open': 610.2050170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 16, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.25,
#  'high': 610.3800048828125,
#  'low': 610.1400146484375,
#  'ma3': 610.2800089518229,
#  'open': 610.3800048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 16, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.7000122070312,
#  'high': 610.7100219726562,
#  'low': 610.239990234375,
#  'ma3': 610.4466756184896,
#  'open': 610.239990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 16, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.739990234375,
#  'high': 610.85498046875,
#  'low': 610.6599731445312,
#  'ma3': 610.5633341471354,
#  'open': 610.7000122070312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 16, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.25,
#  'high': 610.77001953125,
#  'low': 610.1799926757812,
#  'ma3': 610.5633341471354,
#  'open': 610.72998046875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.2498779296875,
#  'high': 610.2501220703125,
#  'low': 610.0599975585938,
#  'ma3': 610.4132893880209,
#  'open': 610.239990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 17, 5, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.0198974609375,
#  'high': 610.3200073242188,
#  'low': 609.8699951171875,
#  'ma3': 610.1732584635416,
#  'open': 610.239990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 17, 10, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.2000122070312,
#  'high': 610.280029296875,
#  'low': 609.780029296875,
#  'ma3': 610.1565958658854,
#  'open': 609.9099731445312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 17, 15, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.9500122070312,
#  'high': 610.1900024414062,
#  'low': 609.8201293945312,
#  'ma3': 610.056640625,
#  'open': 610.1900024414062}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 17, 20, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.9299926757812,
#  'high': 610.02001953125,
#  'low': 609.780029296875,
#  'ma3': 610.0266723632812,
#  'open': 609.9500122070312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 17, 25, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.0349731445312,
#  'high': 610.0800170898438,
#  'low': 609.9099731445312,
#  'ma3': 609.9716593424479,
#  'open': 609.9100952148438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.0750122070312,
#  'high': 610.31689453125,
#  'low': 610.0402221679688,
#  'ma3': 610.0133260091146,
#  'open': 610.0402221679688}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 17, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.239990234375,
#  'high': 610.3099975585938,
#  'low': 610.052978515625,
#  'ma3': 610.1166585286459,
#  'open': 610.0700073242188}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 17, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.2000122070312,
#  'high': 610.3900146484375,
#  'low': 610.1300048828125,
#  'ma3': 610.1716715494791,
#  'open': 610.260009765625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 17, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.2100219726562,
#  'high': 610.2999877929688,
#  'low': 610.1099853515625,
#  'ma3': 610.2166748046875,
#  'open': 610.1900024414062}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 17, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.4600219726562,
#  'high': 610.5449829101562,
#  'low': 610.2000122070312,
#  'ma3': 610.2900187174479,
#  'open': 610.2100219726562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 17, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.3499755859375,
#  'high': 610.489990234375,
#  'low': 610.2847290039062,
#  'ma3': 610.3400065104166,
#  'open': 610.4500122070312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.614990234375,
#  'high': 610.65869140625,
#  'low': 610.3099975585938,
#  'ma3': 610.4749959309896,
#  'open': 610.3400268554688}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 18, 5, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.2498779296875,
#  'high': 610.6500244140625,
#  'low': 610.1599731445312,
#  'ma3': 610.4049479166666,
#  'open': 610.614990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 18, 10, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.1199951171875,
#  'high': 610.260009765625,
#  'low': 609.969970703125,
#  'ma3': 610.3282877604166,
#  'open': 610.2449951171875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 18, 15, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.8599853515625,
#  'high': 610.1599731445312,
#  'low': 609.8599853515625,
#  'ma3': 610.0766194661459,
#  'open': 610.1300048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 18, 20, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.8800048828125,
#  'high': 609.9600219726562,
#  'low': 609.52001953125,
#  'ma3': 609.9533284505209,
#  'open': 609.8599243164062}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 18, 25, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.8900146484375,
#  'high': 610.0700073242188,
#  'low': 609.8400268554688,
#  'ma3': 609.8766682942709,
#  'open': 609.8800048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.719970703125,
#  'high': 609.8800048828125,
#  'low': 609.5599975585938,
#  'ma3': 609.8299967447916,
#  'open': 609.8800048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 18, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.6400146484375,
#  'high': 609.780029296875,
#  'low': 609.510009765625,
#  'ma3': 609.75,
#  'open': 609.719970703125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 18, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.530029296875,
#  'high': 609.6300048828125,
#  'low': 609.451904296875,
#  'ma3': 609.6300048828125,
#  'open': 609.6199951171875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 18, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.7899780273438,
#  'high': 609.8099975585938,
#  'low': 609.469970703125,
#  'ma3': 609.6533406575521,
#  'open': 609.52001953125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 18, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.8099975585938,
#  'high': 609.9299926757812,
#  'low': 609.6699829101562,
#  'ma3': 609.7100016276041,
#  'open': 609.7800903320312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 18, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.6599731445312,
#  'high': 609.9050903320312,
#  'low': 609.6199951171875,
#  'ma3': 609.7533162434896,
#  'open': 609.8200073242188}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.6599731445312,
#  'high': 609.8300170898438,
#  'low': 609.6400146484375,
#  'ma3': 609.7099812825521,
#  'open': 609.655029296875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 19, 5, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 608.760009765625,
#  'high': 609.780029296875,
#  'low': 608.4099731445312,
#  'ma3': 609.3599853515625,
#  'open': 609.6799926757812}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 19, 10, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 608.8300170898438,
#  'high': 609.0999755859375,
#  'low': 608.6699829101562,
#  'ma3': 609.0833333333334,
#  'open': 608.760009765625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 19, 15, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 608.600830078125,
#  'high': 608.8900146484375,
#  'low': 608.530029296875,
#  'ma3': 608.7302856445312,
#  'open': 608.8300170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 19, 20, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.4400024414062,
#  'high': 609.6099853515625,
#  'low': 608.3800048828125,
#  'ma3': 608.9569498697916,
#  'open': 608.5999755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 19, 25, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.218994140625,
#  'high': 609.489990234375,
#  'low': 609.1600952148438,
#  'ma3': 609.0866088867188,
#  'open': 609.4400024414062}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.5,
#  'high': 609.5,
#  'low': 609.1099853515625,
#  'ma3': 609.3863321940104,
#  'open': 609.219970703125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 19, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.1300048828125,
#  'high': 609.5700073242188,
#  'low': 609.1201782226562,
#  'ma3': 609.2829996744791,
#  'open': 609.489990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 19, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.3900146484375,
#  'high': 609.469970703125,
#  'low': 609.1300048828125,
#  'ma3': 609.3400065104166,
#  'open': 609.1400146484375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 19, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.719970703125,
#  'high': 609.75,
#  'low': 609.35498046875,
#  'ma3': 609.413330078125,
#  'open': 609.3900146484375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 19, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.89501953125,
#  'high': 610.030029296875,
#  'low': 609.625,
#  'ma3': 609.6683349609375,
#  'open': 609.72998046875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 19, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.8499755859375,
#  'high': 610.0399780273438,
#  'low': 609.7899780273438,
#  'ma3': 609.8216552734375,
#  'open': 609.89501953125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.8200073242188,
#  'high': 609.9000244140625,
#  'low': 609.719970703125,
#  'ma3': 609.8550008138021,
#  'open': 609.8699951171875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 20, 5, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.75,
#  'high': 609.8698120117188,
#  'low': 609.6801147460938,
#  'ma3': 609.8066609700521,
#  'open': 609.8099975585938}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 20, 10, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.875,
#  'high': 609.9199829101562,
#  'low': 609.6400146484375,
#  'ma3': 609.8150024414062,
#  'open': 609.751220703125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 20, 15, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.739990234375,
#  'high': 609.8900146484375,
#  'low': 609.6300048828125,
#  'ma3': 609.788330078125,
#  'open': 609.8499755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 20, 20, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.8699951171875,
#  'high': 609.8699951171875,
#  'low': 609.6322021484375,
#  'ma3': 609.8283284505209,
#  'open': 609.719970703125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 20, 25, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.780029296875,
#  'high': 609.9600219726562,
#  'low': 609.7150268554688,
#  'ma3': 609.7966715494791,
#  'open': 609.8599853515625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.8599853515625,
#  'high': 610.0599975585938,
#  'low': 609.760009765625,
#  'ma3': 609.836669921875,
#  'open': 609.77001953125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 20, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.780029296875,
#  'high': 609.9199829101562,
#  'low': 609.6900024414062,
#  'ma3': 609.8066813151041,
#  'open': 609.8599853515625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 20, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.77978515625,
#  'high': 610.030029296875,
#  'low': 609.6400146484375,
#  'ma3': 609.8065999348959,
#  'open': 609.780029296875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 20, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.760009765625,
#  'high': 609.9400024414062,
#  'low': 609.6300048828125,
#  'ma3': 609.7732747395834,
#  'open': 609.760009765625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 20, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.1300048828125,
#  'high': 610.25,
#  'low': 609.719970703125,
#  'ma3': 609.8899332682291,
#  'open': 609.760009765625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 20, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.3499755859375,
#  'high': 611.3800048828125,
#  'low': 610.1099853515625,
#  'ma3': 610.413330078125,
#  'open': 610.1199951171875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.1574096679688,
#  'high': 610.19873046875,
#  'low': 609.75,
#  'ma3': 610.5457967122396,
#  'open': 610.0800170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 14, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.9871215820312,
#  'high': 610.27001953125,
#  'low': 609.9500122070312,
#  'ma3': 610.4981689453125,
#  'open': 610.1500244140625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 14, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.0399780273438,
#  'high': 610.2100219726562,
#  'low': 609.9099731445312,
#  'ma3': 610.0615030924479,
#  'open': 609.969970703125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 14, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.818115234375,
#  'high': 610.22998046875,
#  'low': 609.6845092773438,
#  'ma3': 609.9484049479166,
#  'open': 610.0399780273438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 14, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.0999755859375,
#  'high': 610.1799926757812,
#  'low': 609.739990234375,
#  'ma3': 609.9860229492188,
#  'open': 609.7999877929688}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 14, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.9199829101562,
#  'high': 610.1199951171875,
#  'low': 609.8502807617188,
#  'ma3': 609.9460245768229,
#  'open': 610.0650024414062}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.7000122070312,
#  'high': 610.2349853515625,
#  'low': 609.5706787109375,
#  'ma3': 609.9066569010416,
#  'open': 609.9199829101562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 15, 5, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.7200927734375,
#  'high': 610.0,
#  'low': 609.5599975585938,
#  'ma3': 609.780029296875,
#  'open': 609.7100219726562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 15, 10, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.6900024414062,
#  'high': 609.8400268554688,
#  'low': 609.5900268554688,
#  'ma3': 609.703369140625,
#  'open': 609.739990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 15, 15, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.9401245117188,
#  'high': 610.1500244140625,
#  'low': 609.6002197265625,
#  'ma3': 609.7834065755209,
#  'open': 609.6649780273438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 15, 20, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.9600219726562,
#  'high': 610.0599975585938,
#  'low': 609.72998046875,
#  'ma3': 609.8633829752604,
#  'open': 609.9600219726562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 15, 25, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.0599975585938,
#  'high': 610.1749877929688,
#  'low': 609.8900146484375,
#  'ma3': 609.9867146809896,
#  'open': 609.969970703125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.469970703125,
#  'high': 610.8900146484375,
#  'low': 610.02001953125,
#  'ma3': 610.163330078125,
#  'open': 610.0599975585938}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 15, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.3800048828125,
#  'high': 610.5900268554688,
#  'low': 610.27001953125,
#  'ma3': 610.3033243815104,
#  'open': 610.4749755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 15, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.530029296875,
#  'high': 610.5399780273438,
#  'low': 610.3200073242188,
#  'ma3': 610.4600016276041,
#  'open': 610.3800048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 15, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.5,
#  'high': 610.6500244140625,
#  'low': 610.4100952148438,
#  'ma3': 610.4700113932291,
#  'open': 610.5499877929688}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 15, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.4000244140625,
#  'high': 610.5,
#  'low': 610.3300170898438,
#  'ma3': 610.4766845703125,
#  'open': 610.489990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 15, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.1400146484375,
#  'high': 610.39501953125,
#  'low': 609.8200073242188,
#  'ma3': 610.3466796875,
#  'open': 610.39501953125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.5700073242188,
#  'high': 610.7100219726562,
#  'low': 610.1400146484375,
#  'ma3': 610.3700154622396,
#  'open': 610.1400146484375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 16, 5, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.75,
#  'high': 610.780029296875,
#  'low': 610.5499877929688,
#  'ma3': 610.4866739908854,
#  'open': 610.5750122070312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 16, 10, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.2327880859375,
#  'high': 611.25,
#  'low': 610.6599731445312,
#  'ma3': 610.8509318033854,
#  'open': 610.719970703125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 16, 15, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.1400146484375,
#  'high': 611.260009765625,
#  'low': 611.0,
#  'ma3': 611.0409342447916,
#  'open': 611.1901245117188}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 16, 20, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.0999755859375,
#  'high': 611.1799926757812,
#  'low': 610.9600219726562,
#  'ma3': 611.1575927734375,
#  'open': 611.135009765625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 16, 25, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.1799926757812,
#  'high': 611.25,
#  'low': 611.0900268554688,
#  'ma3': 611.1399943033854,
#  'open': 611.114990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.239990234375,
#  'high': 611.27587890625,
#  'low': 610.97998046875,
#  'ma3': 611.1733194986979,
#  'open': 611.1699829101562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 16, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.1500244140625,
#  'high': 611.2899780273438,
#  'low': 611.0800170898438,
#  'ma3': 611.1900024414062,
#  'open': 611.22998046875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 16, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.6751098632812,
#  'high': 611.6751098632812,
#  'low': 611.1500854492188,
#  'ma3': 611.3550415039062,
#  'open': 611.1500854492188}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 16, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.469970703125,
#  'high': 611.77001953125,
#  'low': 611.4600219726562,
#  'ma3': 611.4317016601562,
#  'open': 611.6900024414062}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 16, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.7000122070312,
#  'high': 611.711669921875,
#  'low': 611.469970703125,
#  'ma3': 611.6150309244791,
#  'open': 611.47998046875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 16, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.7000122070312,
#  'high': 611.75,
#  'low': 611.5999755859375,
#  'ma3': 611.6233317057291,
#  'open': 611.6907958984375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.8300170898438,
#  'high': 611.9600219726562,
#  'low': 611.6199951171875,
#  'ma3': 611.7433471679688,
#  'open': 611.6599731445312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 17, 5, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.8184814453125,
#  'high': 611.8400268554688,
#  'low': 611.739990234375,
#  'ma3': 611.7828369140625,
#  'open': 611.8200073242188}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 17, 10, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.5900268554688,
#  'high': 611.83349609375,
#  'low': 611.4224853515625,
#  'ma3': 611.7461751302084,
#  'open': 611.75}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 17, 15, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.4500122070312,
#  'high': 611.5999755859375,
#  'low': 611.3900146484375,
#  'ma3': 611.6195068359375,
#  'open': 611.5800170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 17, 20, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.1306762695312,
#  'high': 611.5,
#  'low': 611.1300048828125,
#  'ma3': 611.3902384440104,
#  'open': 611.4500122070312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 17, 25, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.0499877929688,
#  'high': 611.22998046875,
#  'low': 611.010009765625,
#  'ma3': 611.2102254231771,
#  'open': 611.1199951171875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.9400024414062,
#  'high': 611.114990234375,
#  'low': 610.8599853515625,
#  'ma3': 611.0402221679688,
#  'open': 611.0599975585938}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 17, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.1300048828125,
#  'high': 611.1900024414062,
#  'low': 610.9149780273438,
#  'ma3': 611.0399983723959,
#  'open': 610.9400024414062}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 17, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.280029296875,
#  'high': 611.3400268554688,
#  'low': 611.0499877929688,
#  'ma3': 611.1166788736979,
#  'open': 611.1300048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 17, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.4047241210938,
#  'high': 611.4199829101562,
#  'low': 611.1900024414062,
#  'ma3': 611.2715861002604,
#  'open': 611.27001953125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 17, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.719970703125,
#  'high': 611.8200073242188,
#  'low': 611.4199829101562,
#  'ma3': 611.4682413736979,
#  'open': 611.4199829101562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 17, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.5599975585938,
#  'high': 611.8200073242188,
#  'low': 611.5499877929688,
#  'ma3': 611.5615641276041,
#  'open': 611.7249755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.4151000976562,
#  'high': 611.5900268554688,
#  'low': 611.3699951171875,
#  'ma3': 611.5650227864584,
#  'open': 611.5599975585938}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 18, 5, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.094970703125,
#  'high': 611.4299926757812,
#  'low': 611.0399780273438,
#  'ma3': 611.356689453125,
#  'open': 611.4299926757812}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 18, 10, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.9500122070312,
#  'high': 611.1099853515625,
#  'low': 610.6500244140625,
#  'ma3': 611.1533610026041,
#  'open': 611.0999755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 18, 15, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.52001953125,
#  'high': 611.530029296875,
#  'low': 610.9299926757812,
#  'ma3': 611.1883341471354,
#  'open': 610.9299926757812}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 18, 20, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.5,
#  'high': 611.6199951171875,
#  'low': 611.4400024414062,
#  'ma3': 611.3233439127604,
#  'open': 611.5399780273438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 18, 25, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.6599731445312,
#  'high': 611.7000122070312,
#  'low': 611.4500122070312,
#  'ma3': 611.5599975585938,
#  'open': 611.52001953125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.8599243164062,
#  'high': 611.9400024414062,
#  'low': 611.6699829101562,
#  'ma3': 611.6732991536459,
#  'open': 611.6699829101562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 18, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.89501953125,
#  'high': 611.969970703125,
#  'low': 611.8300170898438,
#  'ma3': 611.8049723307291,
#  'open': 611.8499755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 18, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.8599853515625,
#  'high': 612.0399780273438,
#  'low': 611.7999877929688,
#  'ma3': 611.8716430664062,
#  'open': 611.9400024414062}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 18, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.7249755859375,
#  'high': 611.9199829101562,
#  'low': 611.6950073242188,
#  'ma3': 611.82666015625,
#  'open': 611.8699951171875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 18, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.5900268554688,
#  'high': 611.72998046875,
#  'low': 611.5150146484375,
#  'ma3': 611.7249959309896,
#  'open': 611.719970703125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 18, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.489990234375,
#  'high': 611.7000122070312,
#  'low': 611.47998046875,
#  'ma3': 611.6016642252604,
#  'open': 611.594970703125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.5499877929688,
#  'high': 611.909912109375,
#  'low': 611.4000244140625,
#  'ma3': 611.5433349609375,
#  'open': 611.52001953125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 19, 5, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.719970703125,
#  'high': 611.7999877929688,
#  'low': 611.5399780273438,
#  'ma3': 611.5866495768229,
#  'open': 611.5399780273438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 19, 10, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 612.5800170898438,
#  'high': 612.5880126953125,
#  'low': 611.72998046875,
#  'ma3': 611.9499918619791,
#  'open': 611.72998046875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 19, 15, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 612.75,
#  'high': 612.8900146484375,
#  'low': 612.5499877929688,
#  'ma3': 612.3499959309896,
#  'open': 612.5900268554688}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 19, 20, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 612.9299926757812,
#  'high': 613.0800170898438,
#  'low': 612.739990234375,
#  'ma3': 612.7533365885416,
#  'open': 612.7449951171875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 19, 25, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 612.8201293945312,
#  'high': 612.9650268554688,
#  'low': 612.5800170898438,
#  'ma3': 612.8333740234375,
#  'open': 612.9199829101562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 612.8305053710938,
#  'high': 612.875,
#  'low': 612.6203002929688,
#  'ma3': 612.8602091471354,
#  'open': 612.8200073242188}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 19, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 612.8699951171875,
#  'high': 612.9600219726562,
#  'low': 612.8099975585938,
#  'ma3': 612.8402099609375,
#  'open': 612.8300170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 19, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 612.8350219726562,
#  'high': 613.010009765625,
#  'low': 612.7000122070312,
#  'ma3': 612.8451741536459,
#  'open': 612.8599853515625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 19, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 612.8499755859375,
#  'high': 612.8576049804688,
#  'low': 612.66162109375,
#  'ma3': 612.8516642252604,
#  'open': 612.8300170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 19, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 613.1400146484375,
#  'high': 613.22998046875,
#  'low': 612.8400268554688,
#  'ma3': 612.9416707356771,
#  'open': 612.8599853515625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 19, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 613.1099853515625,
#  'high': 613.1599731445312,
#  'low': 612.9609985351562,
#  'ma3': 613.0333251953125,
#  'open': 613.14501953125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 612.8400268554688,
#  'high': 613.0999755859375,
#  'low': 612.8200073242188,
#  'ma3': 613.0300089518229,
#  'open': 613.0800170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 20, 5, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 612.480224609375,
#  'high': 612.9149780273438,
#  'low': 612.4492797851562,
#  'ma3': 612.8100789388021,
#  'open': 612.8499755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 20, 10, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 612.6300048828125,
#  'high': 612.6699829101562,
#  'low': 612.4500122070312,
#  'ma3': 612.6500854492188,
#  'open': 612.486572265625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 20, 15, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 612.6799926757812,
#  'high': 612.969970703125,
#  'low': 612.6199951171875,
#  'ma3': 612.5967407226562,
#  'open': 612.6458129882812}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 20, 20, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 612.75,
#  'high': 612.7899780273438,
#  'low': 612.5599975585938,
#  'ma3': 612.6866658528646,
#  'open': 612.6749877929688}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 20, 25, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 612.0999145507812,
#  'high': 612.75,
#  'low': 611.7999877929688,
#  'ma3': 612.5099690755209,
#  'open': 612.75}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 612.5499877929688,
#  'high': 612.7899780273438,
#  'low': 612.0800170898438,
#  'ma3': 612.4666341145834,
#  'open': 612.1099853515625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 20, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 612.4500122070312,
#  'high': 612.6699829101562,
#  'low': 612.22998046875,
#  'ma3': 612.3666381835938,
#  'open': 612.5399780273438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 20, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 612.3300170898438,
#  'high': 612.6500244140625,
#  'low': 612.260009765625,
#  'ma3': 612.4433390299479,
#  'open': 612.4299926757812}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 20, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 612.3599853515625,
#  'high': 612.5,
#  'low': 612.1799926757812,
#  'ma3': 612.3800048828125,
#  'open': 612.3400268554688}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 20, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 612.530029296875,
#  'high': 612.7999877929688,
#  'low': 612.3499755859375,
#  'ma3': 612.4066772460938,
#  'open': 612.3800048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 20, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 612.9000244140625,
#  'high': 613.0599975585938,
#  'low': 612.47998046875,
#  'ma3': 612.5966796875,
#  'open': 612.52001953125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.260009765625,
#  'high': 611.6840209960938,
#  'low': 611.1500244140625,
#  'ma3': 612.2300211588541,
#  'open': 611.5399780273438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 14, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.3900146484375,
#  'high': 611.4299926757812,
#  'low': 611.1500244140625,
#  'ma3': 611.8500162760416,
#  'open': 611.2050170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 14, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.5449829101562,
#  'high': 611.3900146484375,
#  'low': 610.530029296875,
#  'ma3': 611.0650024414062,
#  'open': 611.364990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 14, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.3900146484375,
#  'high': 610.6500244140625,
#  'low': 610.135009765625,
#  'ma3': 610.7750040690104,
#  'open': 610.5449829101562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 14, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.4400024414062,
#  'high': 610.3900146484375,
#  'low': 609.02001953125,
#  'ma3': 610.125,
#  'open': 610.380126953125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 14, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 608.3825073242188,
#  'high': 609.5599975585938,
#  'low': 608.3099975585938,
#  'ma3': 609.4041748046875,
#  'open': 609.4047241210938}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 608.2899780273438,
#  'high': 608.4400024414062,
#  'low': 607.02001953125,
#  'ma3': 608.7041625976562,
#  'open': 608.4000244140625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 15, 5, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 607.8400268554688,
#  'high': 608.7000122070312,
#  'low': 607.6400146484375,
#  'ma3': 608.1708374023438,
#  'open': 608.3099975585938}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 15, 10, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 608.4299926757812,
#  'high': 608.8300170898438,
#  'low': 607.6199951171875,
#  'ma3': 608.1866658528646,
#  'open': 607.75}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 15, 15, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 608.97998046875,
#  'high': 609.22998046875,
#  'low': 608.4299926757812,
#  'ma3': 608.4166666666666,
#  'open': 608.4299926757812}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 15, 20, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 608.969970703125,
#  'high': 609.3599853515625,
#  'low': 608.6799926757812,
#  'ma3': 608.7933146158854,
#  'open': 608.989990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 15, 25, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.1099853515625,
#  'high': 609.1699829101562,
#  'low': 608.8099975585938,
#  'ma3': 609.0199788411459,
#  'open': 608.9849853515625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.1199951171875,
#  'high': 609.52001953125,
#  'low': 609.02587890625,
#  'ma3': 609.066650390625,
#  'open': 609.0999755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 15, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 608.72998046875,
#  'high': 608.9199829101562,
#  'low': 608.4199829101562,
#  'ma3': 608.9866536458334,
#  'open': 608.6801147460938}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 15, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 608.510009765625,
#  'high': 608.7899780273438,
#  'low': 608.3400268554688,
#  'ma3': 608.7866617838541,
#  'open': 608.6799926757812}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 15, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 607.8699951171875,
#  'high': 608.5999755859375,
#  'low': 607.7999877929688,
#  'ma3': 608.3699951171875,
#  'open': 608.5}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 15, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 607.489990234375,
#  'high': 607.9000244140625,
#  'low': 607.4299926757812,
#  'ma3': 607.9566650390625,
#  'open': 607.8599853515625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 15, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 607.3499755859375,
#  'high': 607.79541015625,
#  'low': 607.0800170898438,
#  'ma3': 607.5699869791666,
#  'open': 607.52001953125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 607.4199829101562,
#  'high': 607.8699951171875,
#  'low': 607.22998046875,
#  'ma3': 607.4199829101562,
#  'open': 607.739990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 16, 5, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 608.1300048828125,
#  'high': 608.2000122070312,
# ...
#  'high': 606.853271484375,
#  'low': 606.3709106445312,
#  'ma3': 606.6416422526041,
#  'open': 606.530029296875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 16, 10, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 607.1400146484375,
#  'high': 607.1400146484375,
#  'low': 606.1799926757812,
#  'ma3': 606.7416788736979,
#  'open': 606.530029296875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 16, 15, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 607.1950073242188,
#  'high': 607.3499755859375,
#  'low': 606.72998046875,
#  'ma3': 606.9666748046875,
#  'open': 607.1500244140625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 16, 20, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 607.344970703125,
#  'high': 607.47998046875,
#  'low': 607.1900024414062,
#  'ma3': 607.2266642252604,
#  'open': 607.2000122070312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 16, 25, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 606.9400024414062,
#  'high': 607.3599853515625,
#  'low': 606.7100219726562,
#  'ma3': 607.1599934895834,
#  'open': 607.2410888671875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 607.2199096679688,
#  'high': 607.3599853515625,
#  'low': 606.7050170898438,
#  'ma3': 607.1682942708334,
#  'open': 606.9500122070312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 16, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 607.3699951171875,
#  'high': 607.5,
#  'low': 607.010009765625,
#  'ma3': 607.1766357421875,
#  'open': 607.2000122070312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 16, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 606.8892822265625,
#  'high': 607.4600219726562,
#  'low': 606.8200073242188,
#  'ma3': 607.1597290039062,
#  'open': 607.3800048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 16, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 606.77001953125,
#  'high': 606.9799194335938,
#  'low': 606.5399780273438,
#  'ma3': 607.009765625,
#  'open': 606.8699951171875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 16, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 606.4400024414062,
#  'high': 606.760009765625,
#  'low': 606.3099975585938,
#  'ma3': 606.6997680664062,
#  'open': 606.75}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 16, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 606.8049926757812,
#  'high': 607.1199951171875,
#  'low': 606.4249877929688,
#  'ma3': 606.6716715494791,
#  'open': 606.4500122070312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 607.02001953125,
#  'high': 607.1292114257812,
#  'low': 606.739990234375,
#  'ma3': 606.7550048828125,
#  'open': 606.7999877929688}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 17, 5, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 606.5900268554688,
#  'high': 607.0974731445312,
#  'low': 606.5599975585938,
#  'ma3': 606.8050130208334,
#  'open': 607.0307006835938}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 17, 10, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 606.405029296875,
#  'high': 606.6500244140625,
#  'low': 606.260009765625,
#  'ma3': 606.6716918945312,
#  'open': 606.6099853515625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 17, 15, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 605.7000122070312,
#  'high': 606.4400024414062,
#  'low': 605.5999755859375,
#  'ma3': 606.231689453125,
#  'open': 606.4000244140625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 17, 20, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 605.5999755859375,
#  'high': 605.7999877929688,
#  'low': 605.1599731445312,
#  'ma3': 605.9016723632812,
#  'open': 605.6699829101562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 17, 25, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 605.7199096679688,
#  'high': 605.8800048828125,
#  'low': 605.5800170898438,
#  'ma3': 605.6732991536459,
#  'open': 605.8599853515625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 605.280029296875,
#  'high': 605.7899780273438,
#  'low': 605.280029296875,
#  'ma3': 605.5333048502604,
#  'open': 605.7550048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 17, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 604.739990234375,
#  'high': 605.530029296875,
#  'low': 604.5399780273438,
#  'ma3': 605.2466430664062,
#  'open': 605.2899780273438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 17, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 605.0700073242188,
#  'high': 605.1699829101562,
#  'low': 604.5900268554688,
#  'ma3': 605.0300089518229,
#  'open': 604.75}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 17, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 604.6199951171875,
#  'high': 605.0800170898438,
#  'low': 604.5797729492188,
#  'ma3': 604.8099975585938,
#  'open': 605.0700073242188}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 17, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 604.27001953125,
#  'high': 604.6900024414062,
#  'low': 604.25341796875,
#  'ma3': 604.6533406575521,
#  'open': 604.510009765625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 17, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 603.8200073242188,
#  'high': 604.4450073242188,
#  'low': 603.6199951171875,
#  'ma3': 604.2366739908854,
#  'open': 604.27001953125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 603.22998046875,
#  'high': 603.8493041992188,
#  'low': 603.0900268554688,
#  'ma3': 603.7733357747396,
#  'open': 603.8300170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 18, 5, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 602.7899780273438,
#  'high': 603.4000244140625,
#  'low': 602.719970703125,
#  'ma3': 603.2799886067709,
#  'open': 603.219970703125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 18, 10, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 602.9500122070312,
#  'high': 602.9600219726562,
#  'low': 602.2100219726562,
#  'ma3': 602.989990234375,
#  'open': 602.7999877929688}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 18, 15, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 602.8499755859375,
#  'high': 603.539794921875,
#  'low': 602.7509155273438,
#  'ma3': 602.8633219401041,
#  'open': 602.9299926757812}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 18, 20, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 602.6900024414062,
#  'high': 603.010009765625,
#  'low': 602.530029296875,
#  'ma3': 602.8299967447916,
#  'open': 602.8599243164062}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 18, 25, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 602.1599731445312,
#  'high': 603.0499877929688,
#  'low': 602.10009765625,
#  'ma3': 602.566650390625,
#  'open': 602.65869140625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 602.0499877929688,
#  'high': 602.1900024414062,
#  'low': 601.5900268554688,
#  'ma3': 602.2999877929688,
#  'open': 602.14501953125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 18, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 602.3887329101562,
#  'high': 603.2249755859375,
#  'low': 602.010009765625,
#  'ma3': 602.1995646158854,
#  'open': 602.0599975585938}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 18, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 601.8399047851562,
#  'high': 602.7100219726562,
#  'low': 601.8200073242188,
#  'ma3': 602.0928751627604,
#  'open': 602.4199829101562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 18, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 601.9099731445312,
#  'high': 602.0499877929688,
#  'low': 601.739990234375,
#  'ma3': 602.0462036132812,
#  'open': 601.8300170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 18, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 602.2100219726562,
#  'high': 602.22998046875,
#  'low': 601.8099975585938,
#  'ma3': 601.9866333007812,
#  'open': 601.8800048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 18, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 601.7534790039062,
#  'high': 602.2100219726562,
#  'low': 601.5700073242188,
#  'ma3': 601.9578247070312,
#  'open': 602.1900024414062}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 601.364990234375,
#  'high': 601.9099731445312,
#  'low': 601.22998046875,
#  'ma3': 601.7761637369791,
#  'open': 601.760009765625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 19, 5, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 601.75,
#  'high': 601.75,
#  'low': 601.25,
#  'ma3': 601.6228230794271,
#  'open': 601.3499755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 19, 10, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 602.1400146484375,
#  'high': 602.3300170898438,
#  'low': 601.4299926757812,
#  'ma3': 601.7516682942709,
#  'open': 601.760009765625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 19, 15, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 601.3699951171875,
#  'high': 602.14501953125,
#  'low': 601.3400268554688,
#  'ma3': 601.7533365885416,
#  'open': 602.14501953125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 19, 20, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.6699829101562,
#  'high': 601.3699951171875,
#  'low': 600.4500122070312,
#  'ma3': 601.3933308919271,
#  'open': 601.3300170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 19, 25, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 599.9099731445312,
#  'high': 600.7100219726562,
#  'low': 599.6500244140625,
#  'ma3': 600.6499837239584,
#  'open': 600.5}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.1500244140625,
#  'high': 600.64501953125,
#  'low': 599.8101196289062,
#  'ma3': 600.2433268229166,
#  'open': 599.909912109375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 19, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 599.780029296875,
#  'high': 600.2899780273438,
#  'low': 599.6199951171875,
#  'ma3': 599.9466756184896,
#  'open': 600.1500244140625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 19, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.0900268554688,
#  'high': 600.1400146484375,
#  'low': 599.469970703125,
#  'ma3': 600.0066935221354,
#  'open': 599.8099975585938}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 19, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 599.9400024414062,
#  'high': 600.2000122070312,
#  'low': 599.7000122070312,
#  'ma3': 599.9366861979166,
#  'open': 600.0700073242188}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 19, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.0999755859375,
#  'high': 600.6599731445312,
#  'low': 599.9349975585938,
#  'ma3': 600.0433349609375,
#  'open': 599.9500122070312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 19, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.0349731445312,
#  'high': 600.6099853515625,
#  'low': 600.0,
#  'ma3': 600.0249837239584,
#  'open': 600.4600219726562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.02001953125,
#  'high': 600.4199829101562,
#  'low': 599.760009765625,
#  'ma3': 600.0516560872396,
#  'open': 600.030029296875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 20, 5, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 599.9299926757812,
#  'high': 600.25,
#  'low': 599.8800048828125,
#  'ma3': 599.9949951171875,
#  'open': 600.0250244140625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 20, 10, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.1500244140625,
#  'high': 600.47998046875,
#  'low': 599.6599731445312,
#  'ma3': 600.0333455403646,
#  'open': 599.9600219726562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 20, 15, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.27001953125,
#  'high': 600.2899780273438,
#  'low': 599.8685302734375,
#  'ma3': 600.1166788736979,
#  'open': 600.1400146484375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 20, 20, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.5900268554688,
#  'high': 600.6400146484375,
#  'low': 600.0900268554688,
#  'ma3': 600.3366902669271,
#  'open': 600.260009765625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 20, 25, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.5599975585938,
#  'high': 600.6400146484375,
#  'low': 600.2899780273438,
#  'ma3': 600.4733479817709,
#  'open': 600.6099853515625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.6699829101562,
#  'high': 600.9099731445312,
#  'low': 600.3699951171875,
#  'ma3': 600.6066691080729,
#  'open': 600.5800170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 20, 35, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.5900268554688,
#  'high': 600.739990234375,
#  'low': 600.2507934570312,
#  'ma3': 600.6066691080729,
#  'open': 600.6599731445312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 20, 40, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.0399780273438,
#  'high': 600.6900024414062,
#  'low': 600.0349731445312,
#  'ma3': 600.4333292643229,
#  'open': 600.5900268554688}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 20, 45, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.1799926757812,
#  'high': 600.3400268554688,
#  'low': 599.7100219726562,
#  'ma3': 600.2699991861979,
#  'open': 600.0599975585938}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 20, 50, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.3699951171875,
#  'high': 600.5399780273438,
#  'low': 599.9400024414062,
#  'ma3': 600.1966552734375,
#  'open': 600.1699829101562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 20, 55, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.0,
#  'high': 600.489990234375,
#  'low': 599.5,
#  'ma3': 600.1833292643229,
#  'open': 600.3599853515625}
# Total documents: 312

# %% [markdown]
# ### Financial Analyst note
#
# I'm not a financial expert, but I think that financial analyts use different parametersfor the Moving Average calculation
#
# mostly I saw that they use 200 days of moving average and if the current price is a bit higher than 200 days moving average, then it could be potentially a sell signal
#
# because it's really high, maybe it's overbought, maybe it's time to sell.

# %% [markdown]
# ### Checking hourly results

# %%
# Pretty-print the results
for document in hourly_results:
    pprint(document)

# Count the number of documents in the results
print(f"Total documents: {len(hourly_results)}")
# Out:
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.1099853515625,
#  'high': 611.0,
#  'low': 609.9500122070312,
#  'open': 610.8800048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.6099853515625,
#  'high': 610.6199951171875,
#  'low': 609.3300170898438,
#  'open': 609.8350219726562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.25,
#  'high': 610.85498046875,
#  'low': 609.760009765625,
#  'open': 610.60498046875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.3499755859375,
#  'high': 610.5449829101562,
#  'low': 609.780029296875,
#  'open': 610.239990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.6599731445312,
#  'high': 610.65869140625,
#  'low': 609.451904296875,
#  'open': 610.3400268554688}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.8499755859375,
#  'high': 610.0399780273438,
#  'low': 608.3800048828125,
#  'open': 609.655029296875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 18, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.3499755859375,
#  'high': 611.3800048828125,
#  'low': 609.6300048828125,
#  'open': 609.8699951171875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.9199829101562,
#  'high': 610.27001953125,
#  'low': 609.6845092773438,
#  'open': 610.0800170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.1400146484375,
#  'high': 610.8900146484375,
#  'low': 609.5599975585938,
#  'open': 609.9199829101562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.7000122070312,
#  'high': 611.77001953125,
#  'low': 610.1400146484375,
#  'open': 610.1400146484375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.5599975585938,
#  'high': 611.9600219726562,
#  'low': 610.8599853515625,
#  'open': 611.6599731445312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 611.489990234375,
#  'high': 612.0399780273438,
#  'low': 610.6500244140625,
#  'open': 611.5599975585938}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 613.1099853515625,
#  'high': 613.22998046875,
#  'low': 611.4000244140625,
#  'open': 611.52001953125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 19, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 612.9000244140625,
#  'high': 613.0999755859375,
#  'low': 611.7999877929688,
#  'open': 613.0800170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 608.3825073242188,
#  'high': 611.6840209960938,
#  'low': 608.3099975585938,
#  'open': 611.5399780273438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 607.3499755859375,
#  'high': 609.52001953125,
#  'low': 607.02001953125,
#  'open': 608.4000244140625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 607.4600219726562,
#  'high': 608.4500122070312,
#  'low': 607.0999755859375,
#  'open': 607.739990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 608.030029296875,
#  'high': 609.0999145507812,
#  'low': 607.280029296875,
#  'open': 607.4500122070312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 608.5999755859375,
#  'high': 608.760009765625,
#  'low': 607.6400146484375,
#  'open': 608.030029296875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.8599853515625,
#  'high': 610.0999755859375,
#  'low': 608.5,
#  'open': 608.5999755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 20, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.3900146484375,
#  'high': 610.7000122070312,
#  'low': 609.260009765625,
#  'open': 609.864990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 608.4700927734375,
#  'high': 610.2999877929688,
#  'low': 608.239990234375,
#  'open': 610.1599731445312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 606.8399047851562,
#  'high': 608.6500244140625,
#  'low': 605.7659912109375,
#  'open': 608.5}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 606.8049926757812,
#  'high': 607.5,
#  'low': 606.1799926757812,
#  'open': 607.1199951171875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 603.8200073242188,
#  'high': 607.1292114257812,
#  'low': 603.6199951171875,
#  'open': 606.7999877929688}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 601.7534790039062,
#  'high': 603.8493041992188,
#  'low': 601.5700073242188,
#  'open': 603.8300170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.0349731445312,
#  'high': 602.3300170898438,
#  'low': 599.469970703125,
#  'open': 601.760009765625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 21, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.0,
#  'high': 600.9099731445312,
#  'low': 599.5,
#  'open': 600.030029296875}
# Total documents: 28

# %% [markdown]
# ### Create Time Series Collection for Candlestick Chart

# %%
# Check if the 'yfinanceCandlestickData' collection exists
if "yfinanceCandlestickData" in db.list_collection_names():
    db.yfinanceCandlestickData.drop()  # ⚠️ This will delete all data!

from bson.codec_options import CodecOptions
from bson.datetime_ms import DatetimeConversion

# For more information on datetime conversion options, see:
# https://www.mongodb.com/docs/languages/python/pymongo-driver/current/data-formats/dates-and-times/
codec_options = CodecOptions(datetime_conversion=DatetimeConversion.DATETIME_AUTO)

# Check if the 'yfinanceCandlestickData' collection exists
if "yfinanceCandlestickData" not in db.list_collection_names():
    # Create the collection with a time-series configuration
    db.create_collection(
        "yfinanceCandlestickData",
        timeseries={
            "timeField": "timestamp",
            "metaField": "symbol",
            "granularity": "hours"
        },
        codec_options=codec_options
        # expireAfterSeconds=604800  # Document expires 7 days (604800 seconds)
    )
    
    # Create an index on the `symbol` and `timestamp` fields
    db.yfinanceCandlestickData.create_index(
        [("symbol", ASCENDING), ("timestamp", ASCENDING)]
    )
    
    print("Collection and index created successfully.")
else:
    print("The 'yfinanceCandlestickData' collection already exists.")
# Out:
# Collection and index created successfully.

# %%
CANDLESTICK_COLLECTION_NAME = "yfinanceCandlestickData"

# Function to store aggregated data
def store_candlestick_data(db, data):
    """
    Store the aggregated candlestick data into a MongoDB collection.
    Parameters:
        - db (pymongo.database.Database): The MongoDB database object.
        - data (list): List of aggregated candlestick data.
    Returns:
        - dict: MongoDB insert result.
    """
    collection = db[CANDLESTICK_COLLECTION_NAME]
    formatted_data = [{
        "symbol": record['_id']['symbol'],
        "timestamp": record['_id']['time'],
        "open": record['open'],
        "high": record['high'],
        "low": record['low'],
        "close": record['close']
    } for record in data]
    result = collection.insert_many(formatted_data)
    return {"inserted_count": len(result.inserted_ids)}

# %%
inserted_count = store_candlestick_data(db=db, data=hourly_results)
print(f"Ingesting Candlestick Data...")
print(f"Inserted {inserted_count} documents.")
# Out:
# Ingesting Candlestick Data...
# Inserted {'inserted_count': 28} documents.

# %%
# Define the query with ISODate equivalent in Python
start_date = datetime(2025, 2, 18, 0, 0)
end_date = datetime(2025, 2, 18, 23, 59)

# Perform the query
result_cursor = db.yfinanceCandlestickData.find(
    {
        "timestamp": {
            "$gte": start_date,
            "$lte": end_date
        }
    }
).sort("timestamp", -1).limit(24)

# Convert cursor to list (if desired) and print results
results = list(result_cursor)

print(f"Total documents: {len(results)}")

for document in results:
    pprint(document)
# Out:
# Total documents: 7
# {'_id': ObjectId('67bc532f75c878a341a488e3'),
#  'close': 611.3499755859375,
#  'high': 611.3800048828125,
#  'low': 609.6300048828125,
#  'open': 609.8699951171875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))}
# {'_id': ObjectId('67bc532f75c878a341a488e2'),
#  'close': 609.8499755859375,
#  'high': 610.0399780273438,
#  'low': 608.3800048828125,
#  'open': 609.655029296875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))}
# {'_id': ObjectId('67bc532f75c878a341a488e1'),
#  'close': 609.6599731445312,
#  'high': 610.65869140625,
#  'low': 609.451904296875,
#  'open': 610.3400268554688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))}
# {'_id': ObjectId('67bc532f75c878a341a488e0'),
#  'close': 610.3499755859375,
#  'high': 610.5449829101562,
#  'low': 609.780029296875,
#  'open': 610.239990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))}
# {'_id': ObjectId('67bc532f75c878a341a488df'),
#  'close': 610.25,
#  'high': 610.85498046875,
#  'low': 609.760009765625,
#  'open': 610.60498046875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))}
# {'_id': ObjectId('67bc532f75c878a341a488de'),
#  'close': 610.6099853515625,
#  'high': 610.6199951171875,
#  'low': 609.3300170898438,
#  'open': 609.8350219726562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))}
# {'_id': ObjectId('67bc532f75c878a341a488dd'),
#  'close': 610.1099853515625,
#  'high': 611.0,
#  'low': 609.9500122070312,
#  'open': 610.8800048828125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 18, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))}
