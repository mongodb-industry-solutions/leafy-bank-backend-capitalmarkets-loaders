# %% [markdown]
# # Capital Markets Workflow (Simplified)

# %%
# 02/24/2025 12:08:00

# starting date with 1m data
# 2025-02-18 09:30:00-05:00

# %%
# Install packages
# %pip install -U --quiet yfinance pandas 
# %pip install -U --quiet langgraph langchain-community langchain-aws langchain-mongodb
# %pip install -U --quiet pymongo
# %pip install -U --quiet python-dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Set environment variables

# %%
from dotenv import load_dotenv
import os

# Load environment variables
load_dotenv()

# Set environment variables
MONGODB_URI = os.getenv("MONGODB_URI")
AWS_REGION = os.getenv("AWS_REGION")
AWS_ACCESS_KEY_ID = os.getenv("AWS_ACCESS_KEY_ID")
AWS_SECRET_ACCESS_KEY = os.getenv("AWS_SECRET_ACCESS_KEY")

# Set database name
DATABASE_NAME = "agentic_capital_markets"

# %% [markdown]
# ## Getting Market Data from yfinance
#
# ### yfinance documentation
# https://ranaroussi.github.io/yfinance/reference/
#
# Yahoo!, Y!Finance, and Yahoo! finance are registered trademarks of Yahoo, Inc.
#
# yfinance is not affiliated, endorsed, or vetted by Yahoo, Inc. It’s an open-source tool that uses Yahoo’s publicly available APIs, and is intended for research and educational purposes.
#
# You should refer to Yahoo!’s terms of use (here), (here), and (here) for details on your rights to use the actual data downloaded. Remember - the Yahoo! finance API is intended for personal use only.

# %% [markdown]
# ## Important note
#
# ### $SPY: possibly delisted; no price data found  (period=2y) (Yahoo error = "1m data not available for startTime=1676894054 and endTime=1739966054. Only 8 days worth of 1m granularity data are allowed to be fetched per request.")

# %%
# Import libraries
import pandas as pd
import yfinance as yf

# %% [markdown]
# https://stackoverflow.com/questions/76605981/can-not-download-6-months-tsla-with-interval-of-1-minute-in-yfinance

# %% [markdown]
# ### Getting equities data

# %%
HISTORIAL_START_DATE = "2024-01-01"
HISTORIAL_END_DATE = "2025-02-18"

# %%
EQUITIES = 'SPY QQQ EEM XLE'

equities = yf.Tickers(EQUITIES)

# period='max' equals to 1 week

spy = equities.tickers['SPY'].history(start=HISTORIAL_START_DATE, end=HISTORIAL_END_DATE, interval='1h').drop(columns=['Dividends', 'Stock Splits', 'Capital Gains'])
qqq = equities.tickers['QQQ'].history(start=HISTORIAL_START_DATE, end=HISTORIAL_END_DATE, interval='1h').drop(columns=['Dividends', 'Stock Splits', 'Capital Gains'])
eem = equities.tickers['EEM'].history(start=HISTORIAL_START_DATE, end=HISTORIAL_END_DATE, interval='1h').drop(columns=['Dividends', 'Stock Splits', 'Capital Gains'])
xle = equities.tickers['XLE'].history(start=HISTORIAL_START_DATE, end=HISTORIAL_END_DATE, interval='1h').drop(columns=['Dividends', 'Stock Splits', 'Capital Gains'])

spy.tail(5)
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2025-02-14 11:30:00-05:00  610.010010  610.294983  609.270020  609.320129
# 2025-02-14 12:30:00-05:00  609.349976  610.090027  609.070007  609.929871
# 2025-02-14 13:30:00-05:00  609.929993  610.750671  609.880005  610.130005
# 2025-02-14 14:30:00-05:00  610.150024  610.302429  609.590027  609.669983
# 2025-02-14 15:30:00-05:00  609.659973  610.289978  609.544983  609.700012
#
#                             Volume
# Datetime
# 2025-02-14 11:30:00-05:00  2764489
# 2025-02-14 12:30:00-05:00  1443250
# 2025-02-14 13:30:00-05:00  2059667
# 2025-02-14 14:30:00-05:00  2430485
# 2025-02-14 15:30:00-05:00  5528441

# %%
spy.head(5)
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2024-01-02 09:30:00-05:00  472.540009  472.799988  471.359985  471.760010
# 2024-01-02 10:30:00-05:00  471.769989  472.450012  471.299988  472.329987
# 2024-01-02 11:30:00-05:00  472.320007  473.359985  472.269989  472.975006
# 2024-01-02 12:30:00-05:00  472.954987  473.670013  472.279999  472.660492
# 2024-01-02 13:30:00-05:00  472.660004  472.959686  471.545013  471.880096
#
#                              Volume
# Datetime
# 2024-01-02 09:30:00-05:00  19608168
# 2024-01-02 10:30:00-05:00   9085308
# 2024-01-02 11:30:00-05:00   9373953
# 2024-01-02 12:30:00-05:00   7394613
# 2024-01-02 13:30:00-05:00   9946269

# %% [markdown]
# ### Getting Bonds (U.S. Treasuries) data

# %%
BONDS = 'TLT LQD HYG'

bonds = yf.Tickers(BONDS)

tlt = bonds.tickers['TLT'].history(start=HISTORIAL_START_DATE, end=HISTORIAL_END_DATE, interval='1h').drop(columns=['Dividends', 'Stock Splits', 'Capital Gains'])
lqd = bonds.tickers['LQD'].history(start=HISTORIAL_START_DATE, end=HISTORIAL_END_DATE, interval='1h').drop(columns=['Dividends', 'Stock Splits', 'Capital Gains'])
hyg = bonds.tickers['HYG'].history(start=HISTORIAL_START_DATE, end=HISTORIAL_END_DATE, interval='1h').drop(columns=['Dividends', 'Stock Splits', 'Capital Gains'])

tlt.tail(5)
# Out:
#                                 Open       High        Low      Close   Volume
# Datetime
# 2025-02-14 11:30:00-05:00  89.644997  89.675003  89.239998  89.245003  3003815
# 2025-02-14 12:30:00-05:00  89.260002  89.339996  89.129997  89.129997  3241408
# 2025-02-14 13:30:00-05:00  89.135201  89.264999  89.120003  89.230003  1887286
# 2025-02-14 14:30:00-05:00  89.230003  89.309998  89.152802  89.195000  1860117
# 2025-02-14 15:30:00-05:00  89.195000  89.195099  89.129997  89.160004  3086403

# %% [markdown]
# ### Getting Commodities data (Gold, Oil, etc.)

# %%
COMMODITIES = 'GLD USO'

commodities = yf.Tickers(COMMODITIES)

gld = commodities.tickers['GLD'].history(start=HISTORIAL_START_DATE, end=HISTORIAL_END_DATE, interval='1h').drop(columns=['Dividends', 'Stock Splits', 'Capital Gains'])
uso = commodities.tickers['USO'].history(start=HISTORIAL_START_DATE, end=HISTORIAL_END_DATE, interval='1h').drop(columns=['Dividends', 'Stock Splits', 'Capital Gains'])

gld.tail(5)
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2025-02-14 11:30:00-05:00  266.920013  267.320007  266.529999  266.959991
# 2025-02-14 12:30:00-05:00  266.970001  267.015015  266.040009  266.260010
# 2025-02-14 13:30:00-05:00  266.290009  266.309998  265.894989  265.989990
# 2025-02-14 14:30:00-05:00  265.989990  266.000000  265.589996  265.931305
# 2025-02-14 15:30:00-05:00  265.929993  266.359985  265.450012  266.239990
#
#                             Volume
# Datetime
# 2025-02-14 11:30:00-05:00   885116
# 2025-02-14 12:30:00-05:00   927519
# 2025-02-14 13:30:00-05:00   660845
# 2025-02-14 14:30:00-05:00  1392299
# 2025-02-14 15:30:00-05:00  2726240

# %% [markdown]
# ### Getting Market Volatility Index data

# %%
MARKET_VOLATILITY = '^VIX'

market_volatility = yf.Tickers(MARKET_VOLATILITY)

vix = market_volatility.tickers['^VIX'].history(start=HISTORIAL_START_DATE, end=HISTORIAL_END_DATE, interval='1h').drop(columns=['Dividends', 'Stock Splits'])

vix.tail(5)
# Out:
#                             Open   High    Low  Close  Volume
# Datetime
# 2025-02-17 06:00:00-06:00  15.44  15.47  15.37  15.44       0
# 2025-02-17 07:00:00-06:00  15.42  15.44  15.37  15.41       0
# 2025-02-17 08:00:00-06:00  15.41  15.57  15.39  15.52       0
# 2025-02-17 09:00:00-06:00  15.45  15.57  15.41  15.44       0
# 2025-02-17 10:00:00-06:00  15.46  15.48  15.37  15.37       0

# %% [markdown]
# ## We can leverage Scheduled Triggers in MongoDB Atlas to run the script at a specific recurring time.
#
# Scheduled Triggers allow you to execute server-side logic on a regular schedule that you define. You can use scheduled Triggers to do work that happens on a periodic basis, such as updating a document every minute, generating a nightly report, or sending an automated weekly email newsletter.
#
# https://www.mongodb.com/docs/atlas/atlas-ui/triggers/scheduled-triggers/
#
# ## We can leverage Atlas Functions as well
#
# An Atlas Function is a piece of server-side JavaScript code that you write to define your app's behavior. You can call your app's Functions directly from a client app or define services that integrate and call Functions automatically.
#
# Functions can call other Functions and include a built-in client for working with data in MongoDB Atlas clusters. They also include helpful global utilities, support common Node.js built-in modules, and can import and use external packages from the npm registry.
#
# https://www.mongodb.com/docs/atlas/atlas-ui/triggers/functions/
#
# Video Tutorial: https://www.youtube.com/watch?v=3Q6J1J1JZ3A

# %% [markdown]
# ## MongoDB Database Setup

# %%
# Import libraries
from pymongo import MongoClient, ASCENDING

# %%
def get_mongo_client(mongo_uri):
    """Establish connection to the MongoDB and ping the database."""

    # gateway to interacting with a MongoDB database cluster
    client = MongoClient(mongo_uri, appname="ist.demo.agentic_capital_markets.python", tz_aware=True)

    # Ping the database to ensure the connection is successful
    try:
        client.admin.command("ping")
        print("Connection to MongoDB successful")
    except Exception as e:
        print(f"Error connecting to MongoDB: {e}")
        return None

    return client


if not MONGODB_URI:
    print("MONGO_URI not set in environment variables")

mongo_client = get_mongo_client(MONGODB_URI)

if mongo_client:
    # Pymongo client of database
    db = mongo_client.get_database(DATABASE_NAME)
else:
    print("Failed to connect to MongoDB. Exiting...")
    exit(1)
# Out:
# Connection to MongoDB successful

# %% [markdown]
# ### Create Timeseries Collection

# %%
# Check if the 'yfinanceMarketHistoricalData' collection exists
if "yfinanceMarketHistoricalData" in db.list_collection_names():
    db.yfinanceMarketHistoricalData.drop()  # ⚠️ This will delete all data!

from bson.codec_options import CodecOptions
from bson.datetime_ms import DatetimeConversion

# For more information on datetime conversion options, see:
# https://www.mongodb.com/docs/languages/python/pymongo-driver/current/data-formats/dates-and-times/
codec_options = CodecOptions(datetime_conversion=DatetimeConversion.DATETIME_AUTO)

# Check if the 'yfinanceMarketHistoricalData' collection exists
if "yfinanceMarketHistoricalData" not in db.list_collection_names():
    # Create the collection with a time-series configuration
    db.create_collection(
        "yfinanceMarketHistoricalData",
        timeseries={
            "timeField": "timestamp",
            "metaField": "symbol",
            "granularity": "minutes"
        },
        codec_options=codec_options
        # expireAfterSeconds=604800  # Document expires 7 days (604800 seconds)
    )
    
    # Create an index on the `symbol` and `timestamp` fields
    db.yfinanceMarketHistoricalData.create_index(
        [("symbol", ASCENDING), ("timestamp", ASCENDING)]
    )
    
    print("Collection and index created successfully.")
else:
    print("The 'yfinanceMarketHistoricalData' collection already exists.")
# Out:
# Collection and index created successfully.

# %% [markdown]
# ## Data Ingestion

# %%
# Checking pandas DataFrame info
spy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1962 entries, 2024-01-02 09:30:00-05:00 to 2025-02-14 15:30:00-05:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1962 non-null   float64
#  1   High    1962 non-null   float64
#  2   Low     1962 non-null   float64
#  3   Close   1962 non-null   float64
#  4   Volume  1962 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 92.0 KB

# %% [markdown]
# ###  Transformations

# %%
from datetime import datetime
import pytz


def transform_data(symbol, df):
    """
    Transforms the given DataFrame by performing the following operations:
        - Reset the index (Datetime) and rename it to 'timestamp'.
        - Add a new column 'symbol' with the given value.
        - Convert all column names to lowercase.
        - Reorder columns as 'timestamp', 'symbol', 'open', 'high', 'low', 'close', 'volume'.
        - Convert 'timestamp' to UTC timezone if not already.
    Parameters:
        - symbol (str): The symbol name to be added in the 'symbol' column.
        - df (pd.DataFrame): The input DataFrame with 'Datetime' as the index.
    Returns:
        - pd.DataFrame: Transformed DataFrame.
    """
    # Reset index and explicitly rename 'Datetime' to 'timestamp'
    df = df.reset_index().rename(columns={'Datetime': 'timestamp'})

    # Convert timestamp to datetime if not already
    df['timestamp'] = pd.to_datetime(df['timestamp'])

    # Ensure timestamp is localized to US/Eastern only if it’s naive (has no timezone)
    if df['timestamp'].dt.tz is None:
        eastern = pytz.timezone('US/Eastern')
        df['timestamp'] = df['timestamp'].dt.tz_localize(
            eastern, ambiguous='NaT', nonexistent='shift_forward')

    # Convert 'timestamp' to UTC
    df['timestamp'] = df['timestamp'].dt.tz_convert('UTC')

    # Add the 'symbol' column
    df['symbol'] = symbol

    # Convert all column names to lowercase
    df.columns = df.columns.str.lower()

    # Reorder columns
    df = df[['timestamp', 'symbol', 'open', 'high', 'low', 'close', 'volume']]

    return df

# %%
# Equity transformation - SPY as example
df_spy = transform_data('SPY-USD', spy)
df_spy.head()
# Out:
#                   timestamp   symbol        open        high         low  \
# 0 2024-01-02 14:30:00+00:00  SPY-USD  472.540009  472.799988  471.359985
# 1 2024-01-02 15:30:00+00:00  SPY-USD  471.769989  472.450012  471.299988
# 2 2024-01-02 16:30:00+00:00  SPY-USD  472.320007  473.359985  472.269989
# 3 2024-01-02 17:30:00+00:00  SPY-USD  472.954987  473.670013  472.279999
# 4 2024-01-02 18:30:00+00:00  SPY-USD  472.660004  472.959686  471.545013
#
#         close    volume
# 0  471.760010  19608168
# 1  472.329987   9085308
# 2  472.975006   9373953
# 3  472.660492   7394613
# 4  471.880096   9946269

# %%
df_spy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1962 entries, 0 to 1961
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  1962 non-null   datetime64[ns, UTC]
#  1   symbol     1962 non-null   object
#  2   open       1962 non-null   float64
#  3   high       1962 non-null   float64
#  4   low        1962 non-null   float64
#  5   close      1962 non-null   float64
#  6   volume     1962 non-null   int64
# dtypes: datetime64[ns, UTC](1), float64(4), int64(1), object(1)
# memory usage: 107.4+ KB

# %%
# Equity transformations
df_qqq = transform_data('QQQ-USD', qqq)
df_eem = transform_data('EEM-USD', eem)
df_xle = transform_data('XLE-USD', xle)

# Bonds transformations
df_tlt = transform_data('TLT-USD', tlt)
df_lqd = transform_data('LQD-USD', lqd)
df_hyg = transform_data('HYG-USD', hyg)

# Commodities transformations
df_gld = transform_data('GLD-USD', gld)
df_uso = transform_data('USO-USD', uso)

# Market Volatility transformations
df_vix = transform_data('VIX-USD', vix)

# %%
df_uso.sort_index(ascending=False).head()
# Out:
#                      timestamp   symbol       open       high        low  \
# 1961 2025-02-14 20:30:00+00:00  USO-USD  75.750000  75.860001  75.709999
# 1960 2025-02-14 19:30:00+00:00  USO-USD  75.794800  75.875000  75.709999
# 1959 2025-02-14 18:30:00+00:00  USO-USD  75.860001  76.029999  75.629997
# 1958 2025-02-14 17:30:00+00:00  USO-USD  75.884903  76.010002  75.784401
# 1957 2025-02-14 16:30:00+00:00  USO-USD  75.860001  76.099998  75.809998
#
#           close  volume
# 1961  75.830002  279120
# 1960  75.750000  315061
# 1959  75.800003  342881
# 1958  75.845001  284468
# 1957  75.959999  277052

# %% [markdown]
# ### Clean Data

# %%
# Ensure that the collection is empty by deleting all documents
db.yfinanceMarketHistoricalData.delete_many({})

print("The 'yfinanceMarketHistoricalData' collection is now empty.")
# Out:
# The 'yfinanceMarketHistoricalData' collection is now empty.

# %% [markdown]
# ### Insert data into MongoDB time series collection

# %%
# df_spy sort by timestamp in ascending order
df_spy = df_spy.sort_index(ascending=True)
df_spy.tail(20)
# Out:
#                      timestamp   symbol        open        high         low  \
# 1942 2025-02-12 15:30:00+00:00  SPY-USD  601.443970  603.320007  600.169983
# 1943 2025-02-12 16:30:00+00:00  SPY-USD  600.630005  603.989990  600.599976
# 1944 2025-02-12 17:30:00+00:00  SPY-USD  603.780029  604.549988  603.090027
# 1945 2025-02-12 18:30:00+00:00  SPY-USD  603.589905  603.759888  602.530029
# 1946 2025-02-12 19:30:00+00:00  SPY-USD  603.113525  604.229980  603.059998
# 1947 2025-02-12 20:30:00+00:00  SPY-USD  603.325012  603.590027  602.570007
# 1948 2025-02-13 14:30:00+00:00  SPY-USD  604.479980  606.419922  603.200012
# 1949 2025-02-13 15:30:00+00:00  SPY-USD  606.084900  607.489990  606.000000
# 1950 2025-02-13 16:30:00+00:00  SPY-USD  606.700012  606.960022  605.719971
# 1951 2025-02-13 17:30:00+00:00  SPY-USD  606.539978  606.969971  604.989990
# 1952 2025-02-13 18:30:00+00:00  SPY-USD  606.200012  608.409973  605.309998
# 1953 2025-02-13 19:30:00+00:00  SPY-USD  608.280029  609.710022  608.142212
# 1954 2025-02-13 20:30:00+00:00  SPY-USD  609.570007  609.940002  609.090027
# 1955 2025-02-14 14:30:00+00:00  SPY-USD  609.940002  610.989990  609.760010
# 1956 2025-02-14 15:30:00+00:00  SPY-USD  610.239990  610.849976  609.400024
# 1957 2025-02-14 16:30:00+00:00  SPY-USD  610.010010  610.294983  609.270020
# 1958 2025-02-14 17:30:00+00:00  SPY-USD  609.349976  610.090027  609.070007
# 1959 2025-02-14 18:30:00+00:00  SPY-USD  609.929993  610.750671  609.880005
# 1960 2025-02-14 19:30:00+00:00  SPY-USD  610.150024  610.302429  609.590027
# 1961 2025-02-14 20:30:00+00:00  SPY-USD  609.659973  610.289978  609.544983
#
#            close   volume
# 1942  600.659912  3948328
# 1943  603.789978  4270148
# 1944  603.570007  2558860
# 1945  603.080017  2782930
# 1946  603.320007  4147162
# 1947  603.359985  4583717
# 1948  606.080017  7644381
# 1949  606.690002  3563509
# 1950  606.539978  2320305
# 1951  606.200012  2449362
# 1952  608.280029  5699770
# 1953  609.579895  5920998
# 1954  609.690002  8181588
# 1955  610.239990  5214577
# 1956  609.989990  3910433
# 1957  609.320129  2764489
# 1958  609.929871  1443250
# 1959  610.130005  2059667
# 1960  609.669983  2430485
# 1961  609.700012  5528441

# %%
# df_spy sort by timestamp in descending order
df_spy = df_spy.sort_index(ascending=False)
df_spy.tail(20)
# Out:
#                    timestamp   symbol        open        high         low  \
# 19 2024-01-04 19:30:00+00:00  SPY-USD  468.570007  469.040009  468.070007
# 18 2024-01-04 18:30:00+00:00  SPY-USD  469.329987  469.470001  468.509613
# 17 2024-01-04 17:30:00+00:00  SPY-USD  469.608795  469.619995  468.665009
# 16 2024-01-04 16:30:00+00:00  SPY-USD  470.660004  470.820007  469.260010
# 15 2024-01-04 15:30:00+00:00  SPY-USD  469.760010  470.959991  469.619995
# 14 2024-01-04 14:30:00+00:00  SPY-USD  468.299988  470.149994  468.109985
# 13 2024-01-03 20:30:00+00:00  SPY-USD  469.274994  469.795013  468.170013
# 12 2024-01-03 19:30:00+00:00  SPY-USD  470.950012  471.179993  468.970001
# 11 2024-01-03 18:30:00+00:00  SPY-USD  470.339996  471.190002  468.950012
# 10 2024-01-03 17:30:00+00:00  SPY-USD  469.579987  470.769989  469.420502
# 9  2024-01-03 16:30:00+00:00  SPY-USD  469.700012  469.829987  468.970001
# 8  2024-01-03 15:30:00+00:00  SPY-USD  469.489990  469.929993  468.709991
# 7  2024-01-03 14:30:00+00:00  SPY-USD  470.500000  470.959991  469.220001
# 6  2024-01-02 20:30:00+00:00  SPY-USD  470.904999  472.670013  470.670013
# 5  2024-01-02 19:30:00+00:00  SPY-USD  471.859985  472.059998  470.489990
# 4  2024-01-02 18:30:00+00:00  SPY-USD  472.660004  472.959686  471.545013
# 3  2024-01-02 17:30:00+00:00  SPY-USD  472.954987  473.670013  472.279999
# 2  2024-01-02 16:30:00+00:00  SPY-USD  472.320007  473.359985  472.269989
# 1  2024-01-02 15:30:00+00:00  SPY-USD  471.769989  472.450012  471.299988
# 0  2024-01-02 14:30:00+00:00  SPY-USD  472.540009  472.799988  471.359985
#
#          close    volume
# 19  468.269012  11836431
# 18  468.579895   7022819
# 17  469.320099   4754153
# 16  469.609985   6137719
# 15  470.649994   5975815
# 14  469.765015  12633397
# 13  468.730011  18962548
# 12  469.260010  12079010
# 11  470.940002  11787244
# 10  470.329987   6375672
# 9   469.579987   7616562
# 8   469.709991  14067856
# 7   469.500000  18908272
# 6   472.600006  24786273
# 5   470.910004  13662376
# 4   471.880096   9946269
# 3   472.660492   7394613
# 2   472.975006   9373953
# 1   472.329987   9085308
# 0   471.760010  19608168

# %%
# Pandas DataFrame to dictionary, example with SPY
spy_records = df_spy.to_dict(orient="records")
spy_records
# Out:
# [{'timestamp': Timestamp('2025-02-14 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 609.6599731445312,
#   'high': 610.2899780273438,
#   'low': 609.5449829101562,
#   'close': 609.7000122070312,
#   'volume': 5528441},
#  {'timestamp': Timestamp('2025-02-14 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 610.1500244140625,
#   'high': 610.3024291992188,
#   'low': 609.5900268554688,
#   'close': 609.6699829101562,
#   'volume': 2430485},
#  {'timestamp': Timestamp('2025-02-14 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 609.9299926757812,
#   'high': 610.7506713867188,
#   'low': 609.8800048828125,
#   'close': 610.1300048828125,
#   'volume': 2059667},
#  {'timestamp': Timestamp('2025-02-14 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 609.3499755859375,
#   'high': 610.0900268554688,
#   'low': 609.0700073242188,
#   'close': 609.9298706054688,
#   'volume': 1443250},
#  {'timestamp': Timestamp('2025-02-14 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 610.010009765625,
#   'high': 610.2949829101562,
#   'low': 609.27001953125,
#   'close': 609.3201293945312,
#   'volume': 2764489},
#  {'timestamp': Timestamp('2025-02-14 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 610.239990234375,
#   'high': 610.8499755859375,
#   'low': 609.4000244140625,
#   'close': 609.989990234375,
#   'volume': 3910433},
#  {'timestamp': Timestamp('2025-02-14 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 609.9400024414062,
#   'high': 610.989990234375,
#   'low': 609.760009765625,
#   'close': 610.239990234375,
#   'volume': 5214577},
#  {'timestamp': Timestamp('2025-02-13 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 609.5700073242188,
#   'high': 609.9400024414062,
#   'low': 609.0900268554688,
#   'close': 609.6900024414062,
#   'volume': 8181588},
#  {'timestamp': Timestamp('2025-02-13 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 608.280029296875,
#   'high': 609.7100219726562,
#   'low': 608.1422119140625,
#   'close': 609.5798950195312,
#   'volume': 5920998},
#  {'timestamp': Timestamp('2025-02-13 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 606.2000122070312,
#   'high': 608.4099731445312,
#   'low': 605.3099975585938,
#   'close': 608.280029296875,
#   'volume': 5699770},
#  {'timestamp': Timestamp('2025-02-13 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 606.5399780273438,
#   'high': 606.969970703125,
#   'low': 604.989990234375,
#   'close': 606.2000122070312,
#   'volume': 2449362},
#  {'timestamp': Timestamp('2025-02-13 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 606.7000122070312,
#   'high': 606.9600219726562,
#   'low': 605.719970703125,
#   'close': 606.5399780273438,
#   'volume': 2320305},
#  {'timestamp': Timestamp('2025-02-13 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 606.0848999023438,
#   'high': 607.489990234375,
#   'low': 606.0,
#   'close': 606.6900024414062,
#   'volume': 3563509},
#  {'timestamp': Timestamp('2025-02-13 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.47998046875,
#   'high': 606.419921875,
#   'low': 603.2000122070312,
#   'close': 606.0800170898438,
#   'volume': 7644381},
#  {'timestamp': Timestamp('2025-02-12 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.3250122070312,
#   'high': 603.5900268554688,
#   'low': 602.5700073242188,
#   'close': 603.3599853515625,
#   'volume': 4583717},
#  {'timestamp': Timestamp('2025-02-12 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.113525390625,
#   'high': 604.22998046875,
#   'low': 603.0599975585938,
#   'close': 603.3200073242188,
#   'volume': 4147162},
#  {'timestamp': Timestamp('2025-02-12 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.5899047851562,
#   'high': 603.7598876953125,
#   'low': 602.530029296875,
#   'close': 603.0800170898438,
#   'volume': 2782930},
#  {'timestamp': Timestamp('2025-02-12 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.780029296875,
#   'high': 604.5499877929688,
#   'low': 603.0900268554688,
#   'close': 603.5700073242188,
#   'volume': 2558860},
#  {'timestamp': Timestamp('2025-02-12 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.6300048828125,
#   'high': 603.989990234375,
#   'low': 600.5999755859375,
#   'close': 603.7899780273438,
#   'volume': 4270148},
#  {'timestamp': Timestamp('2025-02-12 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.4439697265625,
#   'high': 603.3200073242188,
#   'low': 600.1699829101562,
#   'close': 600.659912109375,
#   'volume': 3948328},
#  {'timestamp': Timestamp('2025-02-12 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.2000122070312,
#   'high': 602.3599853515625,
#   'low': 598.510009765625,
#   'close': 601.4349975585938,
#   'volume': 18533540},
#  {'timestamp': Timestamp('2025-02-11 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.280029296875,
#   'high': 605.5800170898438,
#   'low': 604.6099853515625,
#   'close': 605.2100219726562,
#   'volume': 5206725},
#  {'timestamp': Timestamp('2025-02-11 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.719970703125,
#   'high': 605.8599853515625,
#   'low': 604.7100219726562,
#   'close': 605.27001953125,
#   'volume': 3820622},
#  {'timestamp': Timestamp('2025-02-11 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.97998046875,
#   'high': 605.2999877929688,
#   'low': 603.9500122070312,
#   'close': 604.7216186523438,
#   'volume': 2792435},
#  {'timestamp': Timestamp('2025-02-11 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.3400268554688,
#   'high': 604.4299926757812,
#   'low': 603.5,
#   'close': 603.9691772460938,
#   'volume': 1783848},
#  {'timestamp': Timestamp('2025-02-11 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.6199951171875,
#   'high': 604.8900146484375,
#   'low': 603.0999755859375,
#   'close': 604.3200073242188,
#   'volume': 4016033},
#  {'timestamp': Timestamp('2025-02-11 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.1599731445312,
#   'high': 605.219970703125,
#   'low': 604.0,
#   'close': 604.5800170898438,
#   'volume': 3045094},
#  {'timestamp': Timestamp('2025-02-11 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.5499877929688,
#   'high': 604.260009765625,
#   'low': 602.4299926757812,
#   'close': 604.1500244140625,
#   'volume': 4597937},
#  {'timestamp': Timestamp('2025-02-10 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.8800048828125,
#   'high': 605.030029296875,
#   'low': 604.24462890625,
#   'close': 604.7899780273438,
#   'volume': 4621939},
#  {'timestamp': Timestamp('2025-02-10 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.1799926757812,
#   'high': 605.3699951171875,
#   'low': 604.719970703125,
#   'close': 604.8900146484375,
#   'volume': 2722364},
#  {'timestamp': Timestamp('2025-02-10 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.6801147460938,
#   'high': 605.4998779296875,
#   'low': 604.5599975585938,
#   'close': 605.1900024414062,
#   'volume': 1947261},
#  {'timestamp': Timestamp('2025-02-10 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.6500244140625,
#   'high': 604.989990234375,
#   'low': 603.6400146484375,
#   'close': 604.6799926757812,
#   'volume': 1584659},
#  {'timestamp': Timestamp('2025-02-10 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.3198852539062,
#   'high': 604.4874877929688,
#   'low': 603.2108154296875,
#   'close': 603.6286010742188,
#   'volume': 2268410},
#  {'timestamp': Timestamp('2025-02-10 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.739990234375,
#   'high': 605.3300170898438,
#   'low': 604.0499877929688,
#   'close': 604.3099975585938,
#   'volume': 3340580},
#  {'timestamp': Timestamp('2025-02-10 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.030029296875,
#   'high': 604.7899780273438,
#   'low': 602.739990234375,
#   'close': 604.72998046875,
#   'volume': 6518758},
#  {'timestamp': Timestamp('2025-02-07 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.3900146484375,
#   'high': 601.260009765625,
#   'low': 600.3699951171875,
#   'close': 600.77001953125,
#   'volume': 7304928},
#  {'timestamp': Timestamp('2025-02-07 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.6090698242188,
#   'high': 601.5999755859375,
#   'low': 600.0499877929688,
#   'close': 600.4000244140625,
#   'volume': 3536559},
#  {'timestamp': Timestamp('2025-02-07 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.3300170898438,
#   'high': 603.6500244140625,
#   'low': 600.5,
#   'close': 600.5892944335938,
#   'volume': 3499707},
#  {'timestamp': Timestamp('2025-02-07 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.6099853515625,
#   'high': 603.75,
#   'low': 601.2999877929688,
#   'close': 603.3142700195312,
#   'volume': 2472669},
#  {'timestamp': Timestamp('2025-02-07 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.0499877929688,
#   'high': 602.9099731445312,
#   'low': 600.6400146484375,
#   'close': 601.7000122070312,
#   'volume': 8443554},
#  {'timestamp': Timestamp('2025-02-07 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.5,
#   'high': 605.5399780273438,
#   'low': 601.1799926757812,
#   'close': 602.0004272460938,
#   'volume': 10254527},
#  {'timestamp': Timestamp('2025-02-07 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 606.8900146484375,
#   'high': 608.1300048828125,
#   'low': 603.77001953125,
#   'close': 604.5830078125,
#   'volume': 9511824},
#  {'timestamp': Timestamp('2025-02-06 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.77001953125,
#   'high': 606.4525146484375,
#   'low': 604.5800170898438,
#   'close': 606.3400268554688,
#   'volume': 6605760},
#  {'timestamp': Timestamp('2025-02-06 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.5800170898438,
#   'high': 604.8200073242188,
#   'low': 602.6300048828125,
#   'close': 604.7650146484375,
#   'volume': 5268618},
#  {'timestamp': Timestamp('2025-02-06 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.5800170898438,
#   'high': 605.7899780273438,
#   'low': 604.3599853515625,
#   'close': 604.5599975585938,
#   'volume': 2839418},
#  {'timestamp': Timestamp('2025-02-06 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.1400146484375,
#   'high': 605.989990234375,
#   'low': 604.8599853515625,
#   'close': 605.5900268554688,
#   'volume': 1936391},
#  {'timestamp': Timestamp('2025-02-06 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.5499877929688,
#   'high': 605.6300048828125,
#   'low': 604.75,
#   'close': 605.1400146484375,
#   'volume': 2002226},
#  {'timestamp': Timestamp('2025-02-06 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.9400024414062,
#   'high': 605.75,
#   'low': 604.1599731445312,
#   'close': 605.530029296875,
#   'volume': 2859219},
#  {'timestamp': Timestamp('2025-02-06 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.989990234375,
#   'high': 606.0999755859375,
#   'low': 604.8300170898438,
#   'close': 604.9400024414062,
#   'volume': 5220066},
#  {'timestamp': Timestamp('2025-02-05 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.719970703125,
#   'high': 604.3699951171875,
#   'low': 602.9099731445312,
#   'close': 604.1500244140625,
#   'volume': 5066503},
#  {'timestamp': Timestamp('2025-02-05 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.2899780273438,
#   'high': 603.969970703125,
#   'low': 602.8800048828125,
#   'close': 603.72998046875,
#   'volume': 3207870},
#  {'timestamp': Timestamp('2025-02-05 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.5599975585938,
#   'high': 603.635009765625,
#   'low': 602.3900146484375,
#   'close': 603.27001953125,
#   'volume': 1921265},
#  {'timestamp': Timestamp('2025-02-05 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.5,
#   'high': 602.9000244140625,
#   'low': 602.2100219726562,
#   'close': 602.5659790039062,
#   'volume': 1422477},
#  {'timestamp': Timestamp('2025-02-05 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.239990234375,
#   'high': 603.1699829101562,
#   'low': 601.125,
#   'close': 602.489990234375,
#   'volume': 4233551},
#  {'timestamp': Timestamp('2025-02-05 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.6199951171875,
#   'high': 601.4000244140625,
#   'low': 599.77001953125,
#   'close': 601.27001953125,
#   'volume': 2769162},
#  {'timestamp': Timestamp('2025-02-05 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.6400146484375,
#   'high': 601.0999755859375,
#   'low': 598.5800170898438,
#   'close': 600.6300048828125,
#   'volume': 6421276},
#  {'timestamp': Timestamp('2025-02-04 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.0850219726562,
#   'high': 602.27001953125,
#   'low': 600.969970703125,
#   'close': 601.7550048828125,
#   'volume': 5774958},
#  {'timestamp': Timestamp('2025-02-04 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.8800048828125,
#   'high': 602.2999877929688,
#   'low': 600.8400268554688,
#   'close': 601.0850219726562,
#   'volume': 4026723},
#  {'timestamp': Timestamp('2025-02-04 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.1199951171875,
#   'high': 602.1400146484375,
#   'low': 600.5700073242188,
#   'close': 601.8599853515625,
#   'volume': 1799422},
#  {'timestamp': Timestamp('2025-02-04 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.8200073242188,
#   'high': 601.25,
#   'low': 599.4053955078125,
#   'close': 601.1300048828125,
#   'volume': 2218369},
#  {'timestamp': Timestamp('2025-02-04 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.9600219726562,
#   'high': 602.0900268554688,
#   'low': 599.6699829101562,
#   'close': 599.760009765625,
#   'volume': 3341385},
#  {'timestamp': Timestamp('2025-02-04 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.5499877929688,
#   'high': 602.010009765625,
#   'low': 600.1099853515625,
#   'close': 601.97998046875,
#   'volume': 3564932},
#  {'timestamp': Timestamp('2025-02-04 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 597.8300170898438,
#   'high': 601.1400146484375,
#   'low': 597.280029296875,
#   'close': 600.52001953125,
#   'volume': 7413522},
#  {'timestamp': Timestamp('2025-02-03 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 598.5599975585938,
#   'high': 599.0499877929688,
#   'low': 597.3900146484375,
#   'close': 597.6400146484375,
#   'volume': 8486548},
#  {'timestamp': Timestamp('2025-02-03 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.4849853515625,
#   'high': 600.2899780273438,
#   'low': 598.4000244140625,
#   'close': 598.5499877929688,
#   'volume': 3962284},
#  {'timestamp': Timestamp('2025-02-03 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 597.8699951171875,
#   'high': 600.0,
#   'low': 597.4201049804688,
#   'close': 599.47998046875,
#   'volume': 4564312},
#  {'timestamp': Timestamp('2025-02-03 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 597.3900146484375,
#   'high': 598.260009765625,
#   'low': 595.969970703125,
#   'close': 597.7949829101562,
#   'volume': 5810092},
#  {'timestamp': Timestamp('2025-02-03 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 597.8699951171875,
#   'high': 599.010009765625,
#   'low': 596.6900024414062,
#   'close': 597.4000244140625,
#   'volume': 5408068},
#  {'timestamp': Timestamp('2025-02-03 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 596.3800048828125,
#   'high': 599.25,
#   'low': 592.4400024414062,
#   'close': 597.8699951171875,
#   'volume': 9366779},
#  {'timestamp': Timestamp('2025-02-03 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 592.6699829101562,
#   'high': 596.5999755859375,
#   'low': 590.489990234375,
#   'close': 596.3800048828125,
#   'volume': 19402094},
#  {'timestamp': Timestamp('2025-01-31 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.6699829101562,
#   'high': 603.27001953125,
#   'low': 601.0499877929688,
#   'close': 601.7999877929688,
#   'volume': 11871932},
#  {'timestamp': Timestamp('2025-01-31 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.52001953125,
#   'high': 605.1300048828125,
#   'low': 601.3699951171875,
#   'close': 601.6688842773438,
#   'volume': 10985684},
#  {'timestamp': Timestamp('2025-01-31 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 606.8200073242188,
#   'high': 607.030029296875,
#   'low': 603.2999877929688,
#   'close': 604.530029296875,
#   'volume': 10174398},
#  {'timestamp': Timestamp('2025-01-31 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 609.5449829101562,
#   'high': 609.72998046875,
#   'low': 606.6900024414062,
#   'close': 606.8483276367188,
#   'volume': 4465678},
#  {'timestamp': Timestamp('2025-01-31 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 609.0900268554688,
#   'high': 609.5499877929688,
#   'low': 608.010009765625,
#   'close': 609.5499877929688,
#   'volume': 3769483},
#  {'timestamp': Timestamp('2025-01-31 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 608.9600219726562,
#   'high': 609.9600219726562,
#   'low': 608.8499755859375,
#   'close': 609.0900268554688,
#   'volume': 4039791},
#  {'timestamp': Timestamp('2025-01-31 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 607.5,
#   'high': 609.02001953125,
#   'low': 607.0599975585938,
#   'close': 608.9598999023438,
#   'volume': 6898171},
#  {'timestamp': Timestamp('2025-01-30 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 606.2899780273438,
#   'high': 606.3200073242188,
#   'low': 601.8200073242188,
#   'close': 604.969970703125,
#   'volume': 11088596},
#  {'timestamp': Timestamp('2025-01-30 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.9500122070312,
#   'high': 606.5999755859375,
#   'low': 604.5900268554688,
#   'close': 606.3099975585938,
#   'volume': 3805957},
#  {'timestamp': Timestamp('2025-01-30 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.9849853515625,
#   'high': 605.219970703125,
#   'low': 603.9400024414062,
#   'close': 604.9567260742188,
#   'volume': 2577943},
#  {'timestamp': Timestamp('2025-01-30 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.3900146484375,
#   'high': 604.3099975585938,
#   'low': 602.1599731445312,
#   'close': 604.0,
#   'volume': 2034099},
#  {'timestamp': Timestamp('2025-01-30 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.0220947265625,
#   'high': 604.3400268554688,
#   'low': 602.0800170898438,
#   'close': 602.3699951171875,
#   'volume': 3005783},
#  {'timestamp': Timestamp('2025-01-30 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.3300170898438,
#   'high': 603.8800048828125,
#   'low': 600.7150268554688,
#   'close': 602.52001953125,
#   'volume': 4066330},
#  {'timestamp': Timestamp('2025-01-30 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.9600219726562,
#   'high': 605.97998046875,
#   'low': 602.4099731445312,
#   'close': 602.6300048828125,
#   'volume': 6657977},
#  {'timestamp': Timestamp('2025-01-29 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.3599853515625,
#   'high': 603.6599731445312,
#   'low': 600.739990234375,
#   'close': 601.7999877929688,
#   'volume': 4985317},
#  {'timestamp': Timestamp('2025-01-29 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.3900146484375,
#   'high': 603.6801147460938,
#   'low': 599.25,
#   'close': 603.3499755859375,
#   'volume': 7629951},
#  {'timestamp': Timestamp('2025-01-29 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.3300170898438,
#   'high': 602.6300048828125,
#   'low': 599.219970703125,
#   'close': 599.4000244140625,
#   'volume': 4716556},
#  {'timestamp': Timestamp('2025-01-29 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.0599975585938,
#   'high': 603.3200073242188,
#   'low': 599.6599731445312,
#   'close': 602.3099975585938,
#   'volume': 3173554},
#  {'timestamp': Timestamp('2025-01-29 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.5,
#   'high': 603.4600219726562,
#   'low': 601.9299926757812,
#   'close': 603.0549926757812,
#   'volume': 1873916},
#  {'timestamp': Timestamp('2025-01-29 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.010009765625,
#   'high': 603.5,
#   'low': 602.2100219726562,
#   'close': 602.4600219726562,
#   'volume': 2431254},
#  {'timestamp': Timestamp('2025-01-29 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.719970703125,
#   'high': 604.1300048828125,
#   'low': 602.4451293945312,
#   'close': 602.97998046875,
#   'volume': 4791744},
#  {'timestamp': Timestamp('2025-01-28 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.0700073242188,
#   'high': 605.22998046875,
#   'low': 604.3599853515625,
#   'close': 604.489990234375,
#   'volume': 7053020},
#  {'timestamp': Timestamp('2025-01-28 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.0599975585938,
#   'high': 605.3699951171875,
#   'low': 604.0599975585938,
#   'close': 605.0900268554688,
#   'volume': 3854939},
#  {'timestamp': Timestamp('2025-01-28 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 604.3599853515625,
#   'high': 604.4600219726562,
#   'low': 603.22998046875,
#   'close': 604.0399780273438,
#   'volume': 3277316},
#  {'timestamp': Timestamp('2025-01-28 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 603.7899780273438,
#   'high': 604.7899780273438,
#   'low': 603.2899780273438,
#   'close': 604.1798706054688,
#   'volume': 3259145},
#  {'timestamp': Timestamp('2025-01-28 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.3400268554688,
#   'high': 603.9199829101562,
#   'low': 600.9500122070312,
#   'close': 603.7200927734375,
#   'volume': 4072209},
#  {'timestamp': Timestamp('2025-01-28 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.489990234375,
#   'high': 603.5700073242188,
#   'low': 601.030029296875,
#   'close': 601.4199829101562,
#   'volume': 6736372},
#  {'timestamp': Timestamp('2025-01-28 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.6199951171875,
#   'high': 602.7899780273438,
#   'low': 597.25,
#   'close': 602.4600219726562,
#   'volume': 8905366},
#  {'timestamp': Timestamp('2025-01-27 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 597.4600219726562,
#   'high': 599.5700073242188,
#   'low': 597.1500244140625,
#   'close': 599.4099731445312,
#   'volume': 10318651},
#  {'timestamp': Timestamp('2025-01-27 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 598.9849853515625,
#   'high': 598.989990234375,
#   'low': 596.27001953125,
#   'close': 597.4400024414062,
#   'volume': 7700993},
#  {'timestamp': Timestamp('2025-01-27 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 596.1099853515625,
#   'high': 599.1199951171875,
#   'low': 596.0700073242188,
#   'close': 599.010009765625,
#   'volume': 4838647},
#  {'timestamp': Timestamp('2025-01-27 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 597.6417846679688,
#   'high': 598.2100219726562,
#   'low': 596.030029296875,
#   'close': 596.125,
#   'volume': 4033350},
#  {'timestamp': Timestamp('2025-01-27 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 596.5,
#   'high': 598.0399780273438,
#   'low': 596.2000122070312,
#   'close': 597.6500244140625,
#   'volume': 5497701},
#  {'timestamp': Timestamp('2025-01-27 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 598.989990234375,
#   'high': 599.6900024414062,
#   'low': 596.2899780273438,
#   'close': 596.510009765625,
#   'volume': 7647264},
#  {'timestamp': Timestamp('2025-01-27 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 594.8099975585938,
#   'high': 599.2100219726562,
#   'low': 594.6400146484375,
#   'close': 599.0,
#   'volume': 19726133},
#  {'timestamp': Timestamp('2025-01-24 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 607.0800170898438,
#   'high': 608.1500244140625,
#   'low': 606.7999877929688,
#   'close': 607.9299926757812,
#   'volume': 6412163},
#  {'timestamp': Timestamp('2025-01-24 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 607.4000244140625,
#   'high': 607.9199829101562,
#   'low': 606.9400024414062,
#   'close': 607.0700073242188,
#   'volume': 4125498},
#  {'timestamp': Timestamp('2025-01-24 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 608.4299926757812,
#   'high': 608.739990234375,
#   'low': 606.9299926757812,
#   'close': 607.4299926757812,
#   'volume': 3345671},
#  {'timestamp': Timestamp('2025-01-24 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 609.4249877929688,
#   'high': 609.6199951171875,
#   'low': 608.0800170898438,
#   'close': 608.4450073242188,
#   'volume': 3126556},
#  {'timestamp': Timestamp('2025-01-24 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 609.8800048828125,
#   'high': 610.3250122070312,
#   'low': 609.2999877929688,
#   'close': 609.4299926757812,
#   'volume': 2331694},
#  {'timestamp': Timestamp('2025-01-24 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 609.3499755859375,
#   'high': 609.8897705078125,
#   'low': 609.0599975585938,
#   'close': 609.8897705078125,
#   'volume': 3394398},
#  {'timestamp': Timestamp('2025-01-24 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 609.8099975585938,
#   'high': 610.780029296875,
#   'low': 609.25,
#   'close': 609.3499755859375,
#   'volume': 5714331},
#  {'timestamp': Timestamp('2025-01-23 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 608.0900268554688,
#   'high': 609.739990234375,
#   'low': 607.6900024414062,
#   'close': 609.7100219726562,
#   'volume': 6680471},
#  {'timestamp': Timestamp('2025-01-23 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 607.6699829101562,
#   'high': 608.27001953125,
#   'low': 607.5999755859375,
#   'close': 608.094970703125,
#   'volume': 3238089},
#  {'timestamp': Timestamp('2025-01-23 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 608.0,
#   'high': 608.25,
#   'low': 607.3099975585938,
#   'close': 607.6599731445312,
#   'volume': 2240640},
#  {'timestamp': Timestamp('2025-01-23 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 607.1699829101562,
#   'high': 608.2999877929688,
#   'low': 606.9000244140625,
#   'close': 607.9849853515625,
#   'volume': 3158231},
#  {'timestamp': Timestamp('2025-01-23 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 607.5,
#   'high': 607.8699951171875,
#   'low': 606.9400024414062,
#   'close': 607.1699829101562,
#   'volume': 5748200},
#  {'timestamp': Timestamp('2025-01-23 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.719970703125,
#   'high': 607.5499877929688,
#   'low': 605.6500244140625,
#   'close': 607.510009765625,
#   'volume': 4071470},
#  {'timestamp': Timestamp('2025-01-23 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.7999877929688,
#   'high': 606.2999877929688,
#   'low': 605.52001953125,
#   'close': 605.72998046875,
#   'volume': 4504838},
#  {'timestamp': Timestamp('2025-01-22 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 607.1199951171875,
#   'high': 607.3499755859375,
#   'low': 606.22998046875,
#   'close': 606.3400268554688,
#   'volume': 8699716},
#  {'timestamp': Timestamp('2025-01-22 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 606.9099731445312,
#   'high': 607.6199951171875,
#   'low': 606.7800903320312,
#   'close': 607.1199951171875,
#   'volume': 3100757},
#  {'timestamp': Timestamp('2025-01-22 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 607.0800170898438,
#   'high': 607.626708984375,
#   'low': 606.8300170898438,
#   'close': 606.905029296875,
#   'volume': 2324170},
#  {'timestamp': Timestamp('2025-01-22 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 607.5599975585938,
#   'high': 607.7000122070312,
#   'low': 606.9412231445312,
#   'close': 607.0662841796875,
#   'volume': 2835236},
#  {'timestamp': Timestamp('2025-01-22 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 607.2319946289062,
#   'high': 607.8200073242188,
#   'low': 607.1950073242188,
#   'close': 607.5499877929688,
#   'volume': 3346931},
#  {'timestamp': Timestamp('2025-01-22 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 606.719970703125,
#   'high': 607.239990234375,
#   'low': 606.260009765625,
#   'close': 607.2374877929688,
#   'volume': 5887257},
#  {'timestamp': Timestamp('2025-01-22 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 605.9199829101562,
#   'high': 607.0399780273438,
#   'low': 605.3599853515625,
#   'close': 606.7000122070312,
#   'volume': 8585388},
#  {'timestamp': Timestamp('2025-01-21 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.719970703125,
#   'high': 602.97998046875,
#   'low': 602.1500244140625,
#   'close': 602.9199829101562,
#   'volume': 7640038},
#  {'timestamp': Timestamp('2025-01-21 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.3800048828125,
#   'high': 602.780029296875,
#   'low': 601.6699829101562,
#   'close': 602.7100219726562,
#   'volume': 4751032},
#  {'timestamp': Timestamp('2025-01-21 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 602.5800170898438,
#   'high': 602.8200073242188,
#   'low': 601.9000244140625,
#   'close': 602.3699951171875,
#   'volume': 3368563},
#  {'timestamp': Timestamp('2025-01-21 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 601.5800170898438,
#   'high': 602.8800048828125,
#   'low': 601.54150390625,
#   'close': 602.5900268554688,
#   'volume': 3524912},
#  {'timestamp': Timestamp('2025-01-21 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.77001953125,
#   'high': 601.780029296875,
#   'low': 600.260009765625,
#   'close': 601.5800170898438,
#   'volume': 2931193},
#  {'timestamp': Timestamp('2025-01-21 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.3300170898438,
#   'high': 600.9400024414062,
#   'low': 599.4299926757812,
#   'close': 600.780029296875,
#   'volume': 3154412},
#  {'timestamp': Timestamp('2025-01-21 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 600.6699829101562,
#   'high': 601.469970703125,
#   'low': 598.6699829101562,
#   'close': 600.35498046875,
#   'volume': 8003317},
#  {'timestamp': Timestamp('2025-01-17 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 598.094970703125,
#   'high': 598.5900268554688,
#   'low': 597.3499755859375,
#   'close': 597.5499877929688,
#   'volume': 7957779},
#  {'timestamp': Timestamp('2025-01-17 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 598.47998046875,
#   'high': 598.7100219726562,
#   'low': 597.530029296875,
#   'close': 598.0999755859375,
#   'volume': 5170943},
#  {'timestamp': Timestamp('2025-01-17 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.0,
#   'high': 599.1099853515625,
#   'low': 598.0800170898438,
#   'close': 598.447021484375,
#   'volume': 5257176},
#  {'timestamp': Timestamp('2025-01-17 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.0,
#   'high': 599.3599853515625,
#   'low': 598.530029296875,
#   'close': 599.030029296875,
#   'volume': 3740085},
#  {'timestamp': Timestamp('2025-01-17 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 598.77001953125,
#   'high': 599.0399780273438,
#   'low': 597.8200073242188,
#   'close': 598.981201171875,
#   'volume': 3509840},
#  {'timestamp': Timestamp('2025-01-17 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 596.989990234375,
#   'high': 599.0999755859375,
#   'low': 596.780029296875,
#   'close': 598.77001953125,
#   'volume': 11197582},
#  {'timestamp': Timestamp('2025-01-17 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 596.9600219726562,
#   'high': 597.5399780273438,
#   'low': 595.6099853515625,
#   'close': 596.969970703125,
#   'volume': 14259852},
#  {'timestamp': Timestamp('2025-01-16 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 592.2899780273438,
#   'high': 593.2000122070312,
#   'low': 591.47998046875,
#   'close': 591.7000122070312,
#   'volume': 6725109},
#  {'timestamp': Timestamp('2025-01-16 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 592.469970703125,
#   'high': 593.3300170898438,
#   'low': 591.9400024414062,
#   'close': 592.2899780273438,
#   'volume': 4513509},
#  {'timestamp': Timestamp('2025-01-16 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 592.260009765625,
#   'high': 592.6126098632812,
#   'low': 590.9299926757812,
#   'close': 592.4650268554688,
#   'volume': 4403041},
#  {'timestamp': Timestamp('2025-01-16 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 593.780029296875,
#   'high': 593.7999877929688,
#   'low': 592.1099853515625,
#   'close': 592.260009765625,
#   'volume': 1960963},
#  {'timestamp': Timestamp('2025-01-16 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 593.3400268554688,
#   'high': 593.8099975585938,
#   'low': 591.8200073242188,
#   'close': 593.780029296875,
#   'volume': 2835661},
#  {'timestamp': Timestamp('2025-01-16 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 592.27001953125,
#   'high': 594.3499755859375,
#   'low': 591.780029296875,
#   'close': 593.360107421875,
#   'volume': 4177925},
#  {'timestamp': Timestamp('2025-01-16 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 594.1749877929688,
#   'high': 594.2999877929688,
#   'low': 591.3200073242188,
#   'close': 592.2827758789062,
#   'volume': 7680051},
#  {'timestamp': Timestamp('2025-01-15 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 593.6799926757812,
#   'high': 593.8400268554688,
#   'low': 592.6799926757812,
#   'close': 592.760009765625,
#   'volume': 10587094},
#  {'timestamp': Timestamp('2025-01-15 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 593.1199951171875,
#   'high': 593.9400024414062,
#   'low': 593.02001953125,
#   'close': 593.6900024414062,
#   'volume': 6365535},
#  {'timestamp': Timestamp('2025-01-15 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 592.2550048828125,
#   'high': 593.1400146484375,
#   'low': 591.97998046875,
#   'close': 593.0999755859375,
#   'volume': 3105598},
#  {'timestamp': Timestamp('2025-01-15 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 591.1199951171875,
#   'high': 592.27001953125,
#   'low': 590.8900146484375,
#   'close': 592.27001953125,
#   'volume': 2652355},
#  {'timestamp': Timestamp('2025-01-15 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 591.02001953125,
#   'high': 591.3800048828125,
#   'low': 589.5,
#   'close': 591.1199951171875,
#   'volume': 4001330},
#  {'timestamp': Timestamp('2025-01-15 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 592.4400024414062,
#   'high': 592.530029296875,
#   'low': 590.7100219726562,
#   'close': 591.0200805664062,
#   'volume': 4694971},
#  {'timestamp': Timestamp('2025-01-15 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 590.3250122070312,
#   'high': 592.969970703125,
#   'low': 589.1950073242188,
#   'close': 592.3300170898438,
#   'volume': 14512387},
#  {'timestamp': Timestamp('2025-01-14 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 580.469970703125,
#   'high': 582.2899780273438,
#   'low': 579.5800170898438,
#   'close': 582.1900024414062,
#   'volume': 7537574},
#  {'timestamp': Timestamp('2025-01-14 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 583.0399780273438,
#   'high': 583.739990234375,
#   'low': 578.9000244140625,
#   'close': 580.489990234375,
#   'volume': 5815486},
#  {'timestamp': Timestamp('2025-01-14 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 582.02001953125,
#   'high': 583.8099975585938,
#   'low': 581.7899780273438,
#   'close': 583.0399780273438,
#   'volume': 5136583},
#  {'timestamp': Timestamp('2025-01-14 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 579.7100219726562,
#   'high': 582.2369995117188,
#   'low': 578.3499755859375,
#   'close': 582.02001953125,
#   'volume': 4224093},
#  {'timestamp': Timestamp('2025-01-14 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 580.8300170898438,
#   'high': 581.4000244140625,
#   'low': 578.5700073242188,
#   'close': 579.719970703125,
#   'volume': 5171613},
#  {'timestamp': Timestamp('2025-01-14 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 583.1751708984375,
#   'high': 583.5590209960938,
#   'low': 580.1799926757812,
#   'close': 580.8599853515625,
#   'volume': 5105485},
#  {'timestamp': Timestamp('2025-01-14 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 584.3599853515625,
#   'high': 585.0,
#   'low': 581.969970703125,
#   'close': 583.1500244140625,
#   'volume': 10073998},
#  {'timestamp': Timestamp('2025-01-13 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 580.0999755859375,
#   'high': 581.75,
#   'low': 579.8699951171875,
#   'close': 581.5399780273438,
#   'volume': 5872260},
#  {'timestamp': Timestamp('2025-01-13 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 580.2899780273438,
#   'high': 581.0,
#   'low': 579.5700073242188,
#   'close': 580.0999755859375,
#   'volume': 5247105},
#  {'timestamp': Timestamp('2025-01-13 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 579.6900024414062,
#   'high': 580.3599853515625,
#   'low': 579.0900268554688,
#   'close': 580.3099975585938,
#   'volume': 4323353},
#  {'timestamp': Timestamp('2025-01-13 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 578.2000122070312,
#   'high': 579.75,
#   'low': 577.5999755859375,
#   'close': 579.719970703125,
#   'volume': 3520069},
#  {'timestamp': Timestamp('2025-01-13 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 576.969970703125,
#   'high': 578.530029296875,
#   'low': 575.6799926757812,
#   'close': 578.22998046875,
#   'volume': 4259359},
#  {'timestamp': Timestamp('2025-01-13 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 576.072998046875,
#   'high': 579.1799926757812,
#   'low': 576.030029296875,
#   'close': 576.989990234375,
#   'volume': 4988325},
#  {'timestamp': Timestamp('2025-01-13 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 575.77001953125,
#   'high': 578.6199951171875,
#   'low': 575.3499755859375,
#   'close': 576.02001953125,
#   'volume': 10234487},
#  {'timestamp': Timestamp('2025-01-10 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 580.3300170898438,
#   'high': 581.1199951171875,
#   'low': 579.7000122070312,
#   'close': 580.510009765625,
#   'volume': 8981276},
#  {'timestamp': Timestamp('2025-01-10 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 582.6099853515625,
#   'high': 582.6199951171875,
#   'low': 579.969970703125,
#   'close': 580.344970703125,
#   'volume': 7098364},
#  {'timestamp': Timestamp('2025-01-10 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 583.239990234375,
#   'high': 584.5,
#   'low': 581.5800170898438,
#   'close': 582.5999755859375,
#   'volume': 6052200},
#  {'timestamp': Timestamp('2025-01-10 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 579.97998046875,
#   'high': 583.75,
#   'low': 579.9000244140625,
#   'close': 583.239990234375,
#   'volume': 5835457},
#  {'timestamp': Timestamp('2025-01-10 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 579.8699951171875,
#   'high': 580.8099975585938,
#   'low': 578.5499877929688,
#   'close': 580.0,
#   'volume': 6304602},
#  {'timestamp': Timestamp('2025-01-10 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 581.9000244140625,
#   'high': 583.2288208007812,
#   'low': 579.5900268554688,
#   'close': 579.8599853515625,
#   'volume': 8238517},
#  {'timestamp': Timestamp('2025-01-10 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 585.8800048828125,
#   'high': 585.9500122070312,
#   'low': 579.1500244140625,
#   'close': 581.8900146484375,
#   'volume': 18574871},
#  {'timestamp': Timestamp('2025-01-08 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 589.10498046875,
#   'high': 589.7899780273438,
#   'low': 588.22998046875,
#   'close': 589.4199829101562,
#   'volume': 7883359},
#  {'timestamp': Timestamp('2025-01-08 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 590.280029296875,
#   'high': 590.280029296875,
#   'low': 587.8800048828125,
#   'close': 589.0900268554688,
#   'volume': 3925037},
#  {'timestamp': Timestamp('2025-01-08 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 589.1199951171875,
#   'high': 590.4400024414062,
#   'low': 586.9600219726562,
#   'close': 590.2716064453125,
#   'volume': 5551383},
#  {'timestamp': Timestamp('2025-01-08 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 585.6400146484375,
#   'high': 589.5700073242188,
#   'low': 585.1950073242188,
#   'close': 589.1099853515625,
#   'volume': 4732034},
#  {'timestamp': Timestamp('2025-01-08 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 588.1199951171875,
#   'high': 589.9400024414062,
#   'low': 585.3800048828125,
#   'close': 585.6300048828125,
#   'volume': 4361539},
#  {'timestamp': Timestamp('2025-01-08 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 586.469970703125,
#   'high': 588.719970703125,
#   'low': 586.3800048828125,
#   'close': 588.1099853515625,
#   'volume': 3913519},
#  {'timestamp': Timestamp('2025-01-08 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 588.7000122070312,
#   'high': 588.77001953125,
#   'low': 586.0,
#   'close': 586.4749755859375,
#   'volume': 9870599},
#  {'timestamp': Timestamp('2025-01-07 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 587.8200073242188,
#   'high': 588.8502197265625,
#   'low': 586.780029296875,
#   'close': 588.719970703125,
#   'volume': 11654859},
#  {'timestamp': Timestamp('2025-01-07 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 591.0700073242188,
#   'high': 591.0999755859375,
#   'low': 587.6900024414062,
#   'close': 587.8300170898438,
#   'volume': 5890935},
#  {'timestamp': Timestamp('2025-01-07 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 592.280029296875,
#   'high': 592.280029296875,
#   'low': 590.5499877929688,
#   'close': 591.1099853515625,
#   'volume': 3594071},
#  {'timestamp': Timestamp('2025-01-07 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 590.6500244140625,
#   'high': 592.3970947265625,
#   'low': 589.6400146484375,
#   'close': 592.280029296875,
#   'volume': 3357008},
#  {'timestamp': Timestamp('2025-01-07 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 593.02001953125,
#   'high': 593.260009765625,
#   'low': 590.2125244140625,
#   'close': 590.6199951171875,
#   'volume': 4219424},
#  {'timestamp': Timestamp('2025-01-07 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 593.6099853515625,
#   'high': 593.75,
#   'low': 590.27001953125,
#   'close': 593.1099853515625,
#   'volume': 7309605},
#  {'timestamp': Timestamp('2025-01-07 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 597.4199829101562,
#   'high': 597.75,
#   'low': 592.030029296875,
#   'close': 593.5999755859375,
#   'volume': 9531785},
#  {'timestamp': Timestamp('2025-01-06 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 595.0549926757812,
#   'high': 595.5,
#   'low': 593.5999755859375,
#   'close': 595.4000244140625,
#   'volume': 8009219},
#  {'timestamp': Timestamp('2025-01-06 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 595.52001953125,
#   'high': 595.5800170898438,
#   'low': 594.0399780273438,
#   'close': 595.0549926757812,
#   'volume': 5716723},
#  {'timestamp': Timestamp('2025-01-06 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 597.3499755859375,
#   'high': 597.4298706054688,
#   'low': 594.8800048828125,
#   'close': 595.3499755859375,
#   'volume': 4467432},
#  {'timestamp': Timestamp('2025-01-06 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 598.530029296875,
#   'high': 598.739990234375,
#   'low': 596.5800170898438,
#   'close': 597.3900146484375,
#   'volume': 4129019},
#  {'timestamp': Timestamp('2025-01-06 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 599.4920043945312,
#   'high': 599.7000122070312,
#   'low': 598.3699951171875,
#   'close': 598.5700073242188,
#   'volume': 3142058},
#  {'timestamp': Timestamp('2025-01-06 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 598.9099731445312,
#   'high': 599.510009765625,
#   'low': 598.0700073242188,
#   'close': 599.5089721679688,
#   'volume': 5070586},
#  {'timestamp': Timestamp('2025-01-06 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 596.27001953125,
#   'high': 599.0,
#   'low': 595.9000244140625,
#   'close': 598.8900146484375,
#   'volume': 10454522},
#  {'timestamp': Timestamp('2025-01-03 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 591.9299926757812,
#   'high': 592.2100219726562,
#   'low': 591.0499877929688,
#   'close': 591.8599853515625,
#   'volume': 7074389},
#  {'timestamp': Timestamp('2025-01-03 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 592.0800170898438,
#   'high': 592.5999755859375,
#   'low': 591.4299926757812,
#   'close': 591.9299926757812,
#   'volume': 3775669},
#  {'timestamp': Timestamp('2025-01-03 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 591.5,
#   'high': 592.2000122070312,
#   'low': 591.0499877929688,
#   'close': 592.0999755859375,
#   'volume': 3161826},
#  {'timestamp': Timestamp('2025-01-03 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 590.1500244140625,
#   'high': 591.5,
#   'low': 589.9000244140625,
#   'close': 591.4949951171875,
#   'volume': 3211923},
#  {'timestamp': Timestamp('2025-01-03 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 589.5999755859375,
#   'high': 591.010009765625,
#   'low': 589.5549926757812,
#   'close': 590.14501953125,
#   'volume': 3213495},
#  {'timestamp': Timestamp('2025-01-03 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 588.239990234375,
#   'high': 589.8499755859375,
#   'low': 587.5499877929688,
#   'close': 589.6300048828125,
#   'volume': 3540939},
#  {'timestamp': Timestamp('2025-01-03 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 587.530029296875,
#   'high': 589.5449829101562,
#   'low': 586.4299926757812,
#   'close': 588.219970703125,
#   'volume': 9304664},
#  {'timestamp': Timestamp('2025-01-02 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 584.47998046875,
#   'high': 585.3699951171875,
#   'low': 583.5501708984375,
#   'close': 584.5700073242188,
#   'volume': 5791461},
#  {'timestamp': Timestamp('2025-01-02 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 583.2650146484375,
#   'high': 584.8099975585938,
#   'low': 582.02001953125,
#   'close': 584.469970703125,
#   'volume': 4679389},
#  {'timestamp': Timestamp('2025-01-02 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 582.3250122070312,
#   'high': 583.5050048828125,
#   'low': 580.5,
#   'close': 583.280029296875,
#   'volume': 6223597},
#  {'timestamp': Timestamp('2025-01-02 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 584.469970703125,
#   'high': 584.4733276367188,
#   'low': 580.9400024414062,
#   'close': 582.3599853515625,
#   'volume': 8459871},
#  {'timestamp': Timestamp('2025-01-02 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 587.469970703125,
#   'high': 588.77001953125,
#   'low': 584.2100219726562,
#   'close': 584.489990234375,
#   'volume': 3517777},
#  {'timestamp': Timestamp('2025-01-02 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 587.8099975585938,
#   'high': 588.780029296875,
#   'low': 585.3699951171875,
#   'close': 587.5300903320312,
#   'volume': 5105750},
#  {'timestamp': Timestamp('2025-01-02 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 589.3900146484375,
#   'high': 591.1300048828125,
#   'low': 586.1900024414062,
#   'close': 587.8300170898438,
#   'volume': 10951663},
#  {'timestamp': Timestamp('2024-12-31 20:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 587.22998046875,
#   'high': 587.4998779296875,
#   'low': 584.969970703125,
#   'close': 586.0,
#   'volume': 12566405},
#  {'timestamp': Timestamp('2024-12-31 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 584.9199829101562,
#   'high': 587.2999877929688,
#   'low': 584.4199829101562,
#   'close': 587.2301025390625,
#   'volume': 6727803},
#  {'timestamp': Timestamp('2024-12-31 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 585.0150146484375,
#   'high': 586.5598754882812,
#   'low': 584.5800170898438,
#   'close': 584.9400024414062,
#   'volume': 4971522},
#  {'timestamp': Timestamp('2024-12-31 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 585.8599853515625,
#   'high': 587.5798950195312,
#   'low': 584.7899780273438,
#   'close': 585.010009765625,
#   'volume': 5608244},
#  {'timestamp': Timestamp('2024-12-31 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 586.9498901367188,
#   'high': 587.8400268554688,
#   'low': 585.739990234375,
#   'close': 585.888671875,
#   'volume': 3756070},
#  {'timestamp': Timestamp('2024-12-31 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 589.6099853515625,
#   'high': 590.0599975585938,
#   'low': 586.8200073242188,
#   'close': 586.9500122070312,
#   'volume': 3571992},
#  {'timestamp': Timestamp('2024-12-31 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 589.905029296875,
#   'high': 590.639892578125,
#   'low': 588.1701049804688,
# ...
#   'low': 519.0999755859375,
#   'close': 523.5700073242188,
#   'volume': 10599758},
#  {'timestamp': Timestamp('2024-08-05 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 514.6699829101562,
#   'high': 521.0,
#   'low': 514.6199951171875,
#   'close': 519.6799926757812,
#   'volume': 13547487},
#  {'timestamp': Timestamp('2024-08-05 13:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 511.0,
#   'high': 520.9299926757812,
#   'low': 510.67999267578125,
#   'close': 514.6400146484375,
#   'volume': 46359416},
#  {'timestamp': Timestamp('2024-08-02 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 532.3499755859375,
#   'high': 533.1699829101562,
#   'low': 530.52001953125,
#   'close': 532.989990234375,
#   'volume': 12026320},
#  {'timestamp': Timestamp('2024-08-02 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 531.72998046875,
#   'high': 532.6179809570312,
#   'low': 530.6300048828125,
#   'close': 532.3200073242188,
#   'volume': 6697640},
#  {'timestamp': Timestamp('2024-08-02 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 530.5700073242188,
#   'high': 531.780029296875,
#   'low': 529.5399780273438,
#   'close': 531.75,
#   'volume': 5934159},
#  {'timestamp': Timestamp('2024-08-02 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 532.7000122070312,
#   'high': 533.52001953125,
#   'low': 530.510009765625,
#   'close': 530.5800170898438,
#   'volume': 6167133},
#  {'timestamp': Timestamp('2024-08-02 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 529.4299926757812,
#   'high': 533.2100219726562,
#   'low': 529.2000122070312,
#   'close': 532.719970703125,
#   'volume': 10348217},
#  {'timestamp': Timestamp('2024-08-02 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 530.47998046875,
#   'high': 531.5,
#   'low': 528.5999755859375,
#   'close': 529.4199829101562,
#   'volume': 11037405},
#  {'timestamp': Timestamp('2024-08-02 13:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 535.75,
#   'high': 536.989990234375,
#   'low': 529.5900268554688,
#   'close': 530.47998046875,
#   'volume': 20376913},
#  {'timestamp': Timestamp('2024-08-01 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 541.4600219726562,
#   'high': 543.469970703125,
#   'low': 541.1599731445312,
#   'close': 543.0399780273438,
#   'volume': 13590112},
#  {'timestamp': Timestamp('2024-08-01 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 540.239990234375,
#   'high': 541.7000122070312,
#   'low': 539.4299926757812,
#   'close': 541.469970703125,
#   'volume': 7814437},
#  {'timestamp': Timestamp('2024-08-01 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 542.2999877929688,
#   'high': 542.859619140625,
#   'low': 539.8198852539062,
#   'close': 540.260009765625,
#   'volume': 43649411},
#  {'timestamp': Timestamp('2024-08-01 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 545.0499877929688,
#   'high': 545.0499877929688,
#   'low': 541.8200073242188,
#   'close': 542.2999877929688,
#   'volume': 0},
#  {'timestamp': Timestamp('2024-08-01 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 546.1099853515625,
#   'high': 546.5800170898438,
#   'low': 544.1699829101562,
#   'close': 545.030029296875,
#   'volume': 7656258},
#  {'timestamp': Timestamp('2024-08-01 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 549.8699951171875,
#   'high': 550.25,
#   'low': 546.0,
#   'close': 546.1699829101562,
#   'volume': 8288522},
#  {'timestamp': Timestamp('2024-08-01 13:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 552.5700073242188,
#   'high': 554.8687744140625,
#   'low': 549.8099975585938,
#   'close': 549.830078125,
#   'volume': 11895611},
#  {'timestamp': Timestamp('2024-07-31 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 549.6599731445312,
#   'high': 552.2667846679688,
#   'low': 549.280029296875,
#   'close': 550.4299926757812,
#   'volume': 15135770},
#  {'timestamp': Timestamp('2024-07-31 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 550.9600219726562,
#   'high': 553.5,
#   'low': 549.22998046875,
#   'close': 549.6799926757812,
#   'volume': 12032711},
#  {'timestamp': Timestamp('2024-07-31 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 550.3300170898438,
#   'high': 551.3049926757812,
#   'low': 548.6599731445312,
#   'close': 550.9550170898438,
#   'volume': 5407430},
#  {'timestamp': Timestamp('2024-07-31 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 550.5,
#   'high': 550.97998046875,
#   'low': 549.9199829101562,
#   'close': 550.338623046875,
#   'volume': 4039165},
#  {'timestamp': Timestamp('2024-07-31 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 551.1199951171875,
#   'high': 551.7100219726562,
#   'low': 550.280029296875,
#   'close': 550.5100708007812,
#   'volume': 3353576},
#  {'timestamp': Timestamp('2024-07-31 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 550.2899780273438,
#   'high': 551.280029296875,
#   'low': 549.6199951171875,
#   'close': 551.1199951171875,
#   'volume': 4619368},
#  {'timestamp': Timestamp('2024-07-31 13:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 548.97998046875,
#   'high': 550.5499877929688,
#   'low': 547.5798950195312,
#   'close': 550.2999877929688,
#   'volume': 10236612},
#  {'timestamp': Timestamp('2024-07-30 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 541.7100219726562,
#   'high': 543.655029296875,
#   'low': 541.25,
#   'close': 541.9099731445312,
#   'volume': 8810410},
#  {'timestamp': Timestamp('2024-07-30 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 541.9099731445312,
#   'high': 542.219970703125,
#   'low': 540.77001953125,
#   'close': 541.719970703125,
#   'volume': 3851350},
#  {'timestamp': Timestamp('2024-07-30 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 540.5,
#   'high': 542.6599731445312,
#   'low': 540.1900024414062,
#   'close': 541.9351196289062,
#   'volume': 3811063},
#  {'timestamp': Timestamp('2024-07-30 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 540.8099975585938,
#   'high': 541.1500244140625,
#   'low': 538.5150146484375,
#   'close': 540.5125732421875,
#   'volume': 4459098},
#  {'timestamp': Timestamp('2024-07-30 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 542.1199951171875,
#   'high': 542.3900146484375,
#   'low': 540.0999755859375,
#   'close': 540.8099975585938,
#   'volume': 4738584},
#  {'timestamp': Timestamp('2024-07-30 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 544.97998046875,
#   'high': 545.0800170898438,
#   'low': 541.2135009765625,
#   'close': 542.1400146484375,
#   'volume': 6578602},
#  {'timestamp': Timestamp('2024-07-30 13:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 546.260009765625,
#   'high': 547.3400268554688,
#   'low': 544.780029296875,
#   'close': 544.9600219726562,
#   'volume': 7504304},
#  {'timestamp': Timestamp('2024-07-29 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 545.4299926757812,
#   'high': 546.0499877929688,
#   'low': 544.52001953125,
#   'close': 544.760009765625,
#   'volume': 6371515},
#  {'timestamp': Timestamp('2024-07-29 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 544.9400024414062,
#   'high': 545.64501953125,
#   'low': 544.4600219726562,
#   'close': 545.4299926757812,
#   'volume': 3007235},
#  {'timestamp': Timestamp('2024-07-29 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 545.3200073242188,
#   'high': 545.989990234375,
#   'low': 544.5900268554688,
#   'close': 544.9600219726562,
#   'volume': 2466952},
#  {'timestamp': Timestamp('2024-07-29 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 546.0,
#   'high': 547.0499877929688,
#   'low': 545.2999877929688,
#   'close': 545.3099975585938,
#   'volume': 2557957},
#  {'timestamp': Timestamp('2024-07-29 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 544.1500244140625,
#   'high': 546.780029296875,
#   'low': 542.719970703125,
#   'close': 545.9962768554688,
#   'volume': 3842651},
#  {'timestamp': Timestamp('2024-07-29 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 545.3900146484375,
#   'high': 545.6500244140625,
#   'low': 543.3499755859375,
#   'close': 544.1500244140625,
#   'volume': 4972352},
#  {'timestamp': Timestamp('2024-07-29 13:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 546.02001953125,
#   'high': 547.0399780273438,
#   'low': 544.75,
#   'close': 545.3699951171875,
#   'volume': 8329658},
#  {'timestamp': Timestamp('2024-07-26 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 544.75,
#   'high': 544.8400268554688,
#   'low': 542.7249755859375,
#   'close': 544.3800048828125,
#   'volume': 46246282},
#  {'timestamp': Timestamp('2024-07-26 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 544.510009765625,
#   'high': 545.0700073242188,
#   'low': 543.030029296875,
#   'close': 544.760009765625,
#   'volume': 0},
#  {'timestamp': Timestamp('2024-07-26 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 547.0499877929688,
#   'high': 547.1300048828125,
#   'low': 544.010009765625,
#   'close': 544.489990234375,
#   'volume': 6334187},
#  {'timestamp': Timestamp('2024-07-26 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 545.5700073242188,
#   'high': 547.1900024414062,
#   'low': 545.2999877929688,
#   'close': 547.0499877929688,
#   'volume': 3270563},
#  {'timestamp': Timestamp('2024-07-26 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 543.2100219726562,
#   'high': 546.02001953125,
#   'low': 542.8889770507812,
#   'close': 545.5712280273438,
#   'volume': 7755037},
#  {'timestamp': Timestamp('2024-07-26 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 543.6300048828125,
#   'high': 544.030029296875,
#   'low': 541.6699829101562,
#   'close': 543.2100219726562,
#   'volume': 5445711},
#  {'timestamp': Timestamp('2024-07-26 13:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 542.280029296875,
#   'high': 544.6300048828125,
#   'low': 541.489990234375,
#   'close': 543.6309204101562,
#   'volume': 9842268},
#  {'timestamp': Timestamp('2024-07-25 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 543.1300048828125,
#   'high': 543.3099975585938,
#   'low': 538.1300048828125,
#   'close': 538.3400268554688,
#   'volume': 10394986},
#  {'timestamp': Timestamp('2024-07-25 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 542.9500122070312,
#   'high': 543.6799926757812,
#   'low': 540.52001953125,
#   'close': 543.1400146484375,
#   'volume': 7501788},
#  {'timestamp': Timestamp('2024-07-25 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 544.719970703125,
#   'high': 545.0999755859375,
#   'low': 542.530029296875,
#   'close': 542.969970703125,
#   'volume': 4399882},
#  {'timestamp': Timestamp('2024-07-25 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 546.1799926757812,
#   'high': 547.4550170898438,
#   'low': 544.4605102539062,
#   'close': 544.719970703125,
#   'volume': 5362837},
#  {'timestamp': Timestamp('2024-07-25 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 543.219970703125,
#   'high': 546.3800048828125,
#   'low': 542.4000244140625,
#   'close': 546.1500244140625,
#   'volume': 5163022},
#  {'timestamp': Timestamp('2024-07-25 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 540.5800170898438,
#   'high': 544.6296997070312,
#   'low': 540.02001953125,
#   'close': 543.22998046875,
#   'volume': 7899285},
#  {'timestamp': Timestamp('2024-07-25 13:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 541.3499755859375,
#   'high': 541.6199951171875,
#   'low': 537.4500122070312,
#   'close': 540.5999755859375,
#   'volume': 12824669},
#  {'timestamp': Timestamp('2024-07-24 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 541.655029296875,
#   'high': 542.9000244140625,
#   'low': 540.2899780273438,
#   'close': 541.2100219726562,
#   'volume': 16010792},
#  {'timestamp': Timestamp('2024-07-24 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 543.35498046875,
#   'high': 543.589599609375,
#   'low': 541.489990234375,
#   'close': 541.6500244140625,
#   'volume': 9631294},
#  {'timestamp': Timestamp('2024-07-24 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 544.2849731445312,
#   'high': 544.9500122070312,
#   'low': 543.1799926757812,
#   'close': 543.3599853515625,
#   'volume': 4494870},
#  {'timestamp': Timestamp('2024-07-24 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 544.2689819335938,
#   'high': 545.030029296875,
#   'low': 543.6300048828125,
#   'close': 544.3040161132812,
#   'volume': 5188485},
#  {'timestamp': Timestamp('2024-07-24 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 544.760009765625,
#   'high': 545.280029296875,
#   'low': 543.8900146484375,
#   'close': 544.1995239257812,
#   'volume': 4671278},
#  {'timestamp': Timestamp('2024-07-24 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 546.030029296875,
#   'high': 546.1900024414062,
#   'low': 544.1900024414062,
#   'close': 544.739990234375,
#   'volume': 6683031},
#  {'timestamp': Timestamp('2024-07-24 13:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 548.8599853515625,
#   'high': 549.1699829101562,
#   'low': 545.4349975585938,
#   'close': 546.0399780273438,
#   'volume': 11976984},
#  {'timestamp': Timestamp('2024-07-23 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 555.1699829101562,
#   'high': 555.1799926757812,
#   'low': 553.2750244140625,
#   'close': 553.72998046875,
#   'volume': 6783560},
#  {'timestamp': Timestamp('2024-07-23 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 554.9000244140625,
#   'high': 555.3900146484375,
#   'low': 554.75,
#   'close': 555.2100219726562,
#   'volume': 2197232},
#  {'timestamp': Timestamp('2024-07-23 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 554.72998046875,
#   'high': 555.5499877929688,
#   'low': 554.27001953125,
#   'close': 554.8886108398438,
#   'volume': 2309908},
#  {'timestamp': Timestamp('2024-07-23 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 555.0599975585938,
#   'high': 555.1500244140625,
#   'low': 554.1799926757812,
#   'close': 554.760009765625,
#   'volume': 4090280},
#  {'timestamp': Timestamp('2024-07-23 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 556.4254760742188,
#   'high': 556.6500244140625,
#   'low': 554.530029296875,
#   'close': 555.0651245117188,
#   'volume': 2800687},
#  {'timestamp': Timestamp('2024-07-23 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 556.02001953125,
#   'high': 556.7349853515625,
#   'low': 554.280029296875,
#   'close': 556.4299926757812,
#   'volume': 4101597},
#  {'timestamp': Timestamp('2024-07-23 13:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 554.5399780273438,
#   'high': 556.4099731445312,
#   'low': 554.1300048828125,
#   'close': 556.0001220703125,
#   'volume': 5932413},
#  {'timestamp': Timestamp('2024-07-22 19:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 554.510009765625,
#   'high': 555.1400146484375,
#   'low': 554.3300170898438,
#   'close': 554.6500244140625,
#   'volume': 6511374},
#  {'timestamp': Timestamp('2024-07-22 18:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 554.5750122070312,
#   'high': 555.27001953125,
#   'low': 554.155029296875,
#   'close': 554.52001953125,
#   'volume': 3598136},
#  {'timestamp': Timestamp('2024-07-22 17:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 554.1400146484375,
#   'high': 555.0800170898438,
#   'low': 554.0999755859375,
#   'close': 554.5800170898438,
#   'volume': 3511091},
#  {'timestamp': Timestamp('2024-07-22 16:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 552.1099853515625,
#   'high': 554.3900146484375,
#   'low': 551.8004150390625,
#   'close': 554.135009765625,
#   'volume': 2994151},
#  {'timestamp': Timestamp('2024-07-22 15:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 551.75,
#   'high': 552.4199829101562,
#   'low': 551.02001953125,
#   'close': 552.14501953125,
#   'volume': 3534249},
#  {'timestamp': Timestamp('2024-07-22 14:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 553.2100219726562,
#   'high': 554.4600219726562,
#   'low': 551.6998901367188,
#   'close': 551.739990234375,
#   'volume': 5337648},
#  {'timestamp': Timestamp('2024-07-22 13:30:00+0000', tz='UTC'),
#   'symbol': 'SPY-USD',
#   'open': 553.0,
#   'high': 554.4100952148438,
#   'low': 551.3400268554688,
#   'close': 553.2000122070312,
#   'volume': 9580954},
#  ...]

# %%
def insert_market_data(db, df):
    """
    Inserts the transformed DataFrame into the MongoDB time-series collection `yfinanceMarketHistoricalData`.
    
    Parameters:
        - db (pymongo.database.Database): The MongoDB database object.
        - df (pd.DataFrame): The transformed DataFrame containing market data.
    
    Returns:
    - dict: MongoDB insert result.
    """
    # Confirm timestamp is aware and in UTC
    if df['timestamp'].dt.tz is None:
        # If timestamp is naive, localize to UTC
        df['timestamp'] = pd.to_datetime(df['timestamp']).dt.tz_localize('UTC')
    else:
        # If timestamp is aware, convert to UTC
        df['timestamp'] = df['timestamp'].dt.tz_convert('UTC')
    
    # Convert timestamp to Python datetime object (ensuring stored as ISODate)
    df['timestamp'] = df['timestamp'].apply(lambda x: x.to_pydatetime())
    
    # Convert DataFrame to list of dictionaries
    records = df.to_dict(orient="records")
    
    # Insert data into the collection
    result = db.yfinanceMarketHistoricalData.insert_many(records)
    
    return {"inserted_count": len(result.inserted_ids)}

# %%
print("Inserting SPY market data...")
inserted_count = insert_market_data(db=db, df=df_spy)
print(f"Inserted {inserted_count} documents.")

print("Inserting QQQ market data...")
inserted_count = insert_market_data(db=db, df=df_qqq)
print(f"Inserted {inserted_count} documents.")

print("Inserting EEM market data...")
inserted_count = insert_market_data(db=db, df=df_eem)
print(f"Inserted {inserted_count} documents.")

print("Inserting XLE market data...")
inserted_count = insert_market_data(db=db, df=df_xle)
print(f"Inserted {inserted_count} documents.")

print("Inserting TLT market data...")
inserted_count = insert_market_data(db=db, df=df_tlt)
print(f"Inserted {inserted_count} documents.")

print("Inserting LQD market data...")
inserted_count = insert_market_data(db=db, df=df_lqd)
print(f"Inserted {inserted_count} documents.")

print("Inserting HYG market data...")
inserted_count = insert_market_data(db=db, df=df_hyg)
print(f"Inserted {inserted_count} documents.")

print("Inserting GLD market data...")
inserted_count = insert_market_data(db=db, df=df_gld)
print(f"Inserted {inserted_count} documents.")

print("Inserting USO market data...")
inserted_count = insert_market_data(db=db, df=df_uso)
print(f"Inserted {inserted_count} documents.")

print("Inserting VIX market data...")
inserted_count = insert_market_data(db=db, df=df_vix)
print(f"Inserted {inserted_count} documents.")
# Out:
# Inserting SPY market data...
# Inserted {'inserted_count': 1962} documents.
# Inserting QQQ market data...
# Inserted {'inserted_count': 1962} documents.
# Inserting EEM market data...
# Inserted {'inserted_count': 1962} documents.
# Inserting XLE market data...
# Inserted {'inserted_count': 1962} documents.
# Inserting TLT market data...
# Inserted {'inserted_count': 1962} documents.
# Inserting LQD market data...
# Inserted {'inserted_count': 1962} documents.
# Inserting HYG market data...
# Inserted {'inserted_count': 1962} documents.
# Inserting GLD market data...
# Inserted {'inserted_count': 1962} documents.
# Inserting USO market data...
# Inserted {'inserted_count': 1962} documents.
# Inserting VIX market data...
# Inserted {'inserted_count': 4021} documents.

# %%
from pprint import pprint

# Query and sort data by timestamp in descending order
cursor = db.yfinanceMarketHistoricalData.find({"symbol": "SPY-USD"}).sort("timestamp", -1)

# Pretty-print the results
for document in cursor:
    pprint(document)
# Out:
# {'_id': ObjectId('67bc8238cf828636c3756558'),
#  'close': 609.7000122070312,
#  'high': 610.2899780273438,
#  'low': 609.5449829101562,
#  'open': 609.6599731445312,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 14, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 5528441}
# {'_id': ObjectId('67bc8238cf828636c3756559'),
#  'close': 609.6699829101562,
#  'high': 610.3024291992188,
#  'low': 609.5900268554688,
#  'open': 610.1500244140625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 14, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2430485}
# {'_id': ObjectId('67bc8238cf828636c375655a'),
#  'close': 610.1300048828125,
#  'high': 610.7506713867188,
#  'low': 609.8800048828125,
#  'open': 609.9299926757812,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 14, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2059667}
# {'_id': ObjectId('67bc8238cf828636c375655b'),
#  'close': 609.9298706054688,
#  'high': 610.0900268554688,
#  'low': 609.0700073242188,
#  'open': 609.3499755859375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 14, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 1443250}
# {'_id': ObjectId('67bc8238cf828636c375655c'),
#  'close': 609.3201293945312,
#  'high': 610.2949829101562,
#  'low': 609.27001953125,
#  'open': 610.010009765625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 14, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2764489}
# {'_id': ObjectId('67bc8238cf828636c375655d'),
#  'close': 609.989990234375,
#  'high': 610.8499755859375,
#  'low': 609.4000244140625,
#  'open': 610.239990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 14, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3910433}
# {'_id': ObjectId('67bc8238cf828636c375655e'),
#  'close': 610.239990234375,
#  'high': 610.989990234375,
#  'low': 609.760009765625,
#  'open': 609.9400024414062,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 14, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 5214577}
# {'_id': ObjectId('67bc8238cf828636c375655f'),
#  'close': 609.6900024414062,
#  'high': 609.9400024414062,
#  'low': 609.0900268554688,
#  'open': 609.5700073242188,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 13, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 8181588}
# {'_id': ObjectId('67bc8238cf828636c3756560'),
#  'close': 609.5798950195312,
#  'high': 609.7100219726562,
#  'low': 608.1422119140625,
#  'open': 608.280029296875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 13, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 5920998}
# {'_id': ObjectId('67bc8238cf828636c3756561'),
#  'close': 608.280029296875,
#  'high': 608.4099731445312,
#  'low': 605.3099975585938,
#  'open': 606.2000122070312,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 13, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 5699770}
# {'_id': ObjectId('67bc8238cf828636c3756562'),
#  'close': 606.2000122070312,
#  'high': 606.969970703125,
#  'low': 604.989990234375,
#  'open': 606.5399780273438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 13, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2449362}
# {'_id': ObjectId('67bc8238cf828636c3756563'),
#  'close': 606.5399780273438,
#  'high': 606.9600219726562,
#  'low': 605.719970703125,
#  'open': 606.7000122070312,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 13, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2320305}
# {'_id': ObjectId('67bc8238cf828636c3756564'),
#  'close': 606.6900024414062,
#  'high': 607.489990234375,
#  'low': 606.0,
#  'open': 606.0848999023438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 13, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3563509}
# {'_id': ObjectId('67bc8238cf828636c3756565'),
#  'close': 606.0800170898438,
#  'high': 606.419921875,
#  'low': 603.2000122070312,
#  'open': 604.47998046875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 13, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 7644381}
# {'_id': ObjectId('67bc8238cf828636c3756566'),
#  'close': 603.3599853515625,
#  'high': 603.5900268554688,
#  'low': 602.5700073242188,
#  'open': 603.3250122070312,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 12, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4583717}
# {'_id': ObjectId('67bc8238cf828636c3756567'),
#  'close': 603.3200073242188,
#  'high': 604.22998046875,
#  'low': 603.0599975585938,
#  'open': 603.113525390625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 12, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4147162}
# {'_id': ObjectId('67bc8238cf828636c3756568'),
#  'close': 603.0800170898438,
#  'high': 603.7598876953125,
#  'low': 602.530029296875,
#  'open': 603.5899047851562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 12, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2782930}
# {'_id': ObjectId('67bc8238cf828636c3756569'),
#  'close': 603.5700073242188,
#  'high': 604.5499877929688,
#  'low': 603.0900268554688,
#  'open': 603.780029296875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 12, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2558860}
# {'_id': ObjectId('67bc8238cf828636c375656a'),
#  'close': 603.7899780273438,
#  'high': 603.989990234375,
#  'low': 600.5999755859375,
#  'open': 600.6300048828125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 12, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4270148}
# {'_id': ObjectId('67bc8238cf828636c375656b'),
#  'close': 600.659912109375,
#  'high': 603.3200073242188,
#  'low': 600.1699829101562,
#  'open': 601.4439697265625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 12, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3948328}
# {'_id': ObjectId('67bc8238cf828636c375656c'),
#  'close': 601.4349975585938,
#  'high': 602.3599853515625,
#  'low': 598.510009765625,
#  'open': 599.2000122070312,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 12, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 18533540}
# {'_id': ObjectId('67bc8238cf828636c375656d'),
#  'close': 605.2100219726562,
#  'high': 605.5800170898438,
#  'low': 604.6099853515625,
#  'open': 605.280029296875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 11, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 5206725}
# {'_id': ObjectId('67bc8238cf828636c375656e'),
#  'close': 605.27001953125,
#  'high': 605.8599853515625,
#  'low': 604.7100219726562,
#  'open': 604.719970703125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 11, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3820622}
# {'_id': ObjectId('67bc8238cf828636c375656f'),
#  'close': 604.7216186523438,
#  'high': 605.2999877929688,
#  'low': 603.9500122070312,
#  'open': 603.97998046875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 11, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2792435}
# {'_id': ObjectId('67bc8238cf828636c3756570'),
#  'close': 603.9691772460938,
#  'high': 604.4299926757812,
#  'low': 603.5,
#  'open': 604.3400268554688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 11, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 1783848}
# {'_id': ObjectId('67bc8238cf828636c3756571'),
#  'close': 604.3200073242188,
#  'high': 604.8900146484375,
#  'low': 603.0999755859375,
#  'open': 604.6199951171875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 11, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4016033}
# {'_id': ObjectId('67bc8238cf828636c3756572'),
#  'close': 604.5800170898438,
#  'high': 605.219970703125,
#  'low': 604.0,
#  'open': 604.1599731445312,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 11, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3045094}
# {'_id': ObjectId('67bc8238cf828636c3756573'),
#  'close': 604.1500244140625,
#  'high': 604.260009765625,
#  'low': 602.4299926757812,
#  'open': 602.5499877929688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 11, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4597937}
# {'_id': ObjectId('67bc8238cf828636c3756574'),
#  'close': 604.7899780273438,
#  'high': 605.030029296875,
#  'low': 604.24462890625,
#  'open': 604.8800048828125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 10, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4621939}
# {'_id': ObjectId('67bc8238cf828636c3756575'),
#  'close': 604.8900146484375,
#  'high': 605.3699951171875,
#  'low': 604.719970703125,
#  'open': 605.1799926757812,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 10, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2722364}
# {'_id': ObjectId('67bc8238cf828636c3756576'),
#  'close': 605.1900024414062,
#  'high': 605.4998779296875,
#  'low': 604.5599975585938,
#  'open': 604.6801147460938,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 10, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 1947261}
# {'_id': ObjectId('67bc8238cf828636c3756577'),
#  'close': 604.6799926757812,
#  'high': 604.989990234375,
#  'low': 603.6400146484375,
#  'open': 603.6500244140625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 10, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 1584659}
# {'_id': ObjectId('67bc8238cf828636c3756578'),
#  'close': 603.6286010742188,
#  'high': 604.4874877929688,
#  'low': 603.2108154296875,
#  'open': 604.3198852539062,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 10, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2268410}
# {'_id': ObjectId('67bc8238cf828636c3756579'),
#  'close': 604.3099975585938,
#  'high': 605.3300170898438,
#  'low': 604.0499877929688,
#  'open': 604.739990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 10, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3340580}
# {'_id': ObjectId('67bc8238cf828636c375657a'),
#  'close': 604.72998046875,
#  'high': 604.7899780273438,
#  'low': 602.739990234375,
#  'open': 604.030029296875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 10, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 6518758}
# {'_id': ObjectId('67bc8238cf828636c375657b'),
#  'close': 600.77001953125,
#  'high': 601.260009765625,
#  'low': 600.3699951171875,
#  'open': 600.3900146484375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 7, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 7304928}
# {'_id': ObjectId('67bc8238cf828636c375657c'),
#  'close': 600.4000244140625,
#  'high': 601.5999755859375,
#  'low': 600.0499877929688,
#  'open': 600.6090698242188,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 7, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3536559}
# {'_id': ObjectId('67bc8238cf828636c375657d'),
#  'close': 600.5892944335938,
#  'high': 603.6500244140625,
#  'low': 600.5,
#  'open': 603.3300170898438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 7, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3499707}
# {'_id': ObjectId('67bc8238cf828636c375657e'),
#  'close': 603.3142700195312,
#  'high': 603.75,
#  'low': 601.2999877929688,
#  'open': 601.6099853515625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 7, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2472669}
# {'_id': ObjectId('67bc8238cf828636c375657f'),
#  'close': 601.7000122070312,
#  'high': 602.9099731445312,
#  'low': 600.6400146484375,
#  'open': 602.0499877929688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 7, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 8443554}
# {'_id': ObjectId('67bc8238cf828636c3756580'),
#  'close': 602.0004272460938,
#  'high': 605.5399780273438,
#  'low': 601.1799926757812,
#  'open': 604.5,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 7, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 10254527}
# {'_id': ObjectId('67bc8238cf828636c3756581'),
#  'close': 604.5830078125,
#  'high': 608.1300048828125,
#  'low': 603.77001953125,
#  'open': 606.8900146484375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 7, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 9511824}
# {'_id': ObjectId('67bc8238cf828636c3756582'),
#  'close': 606.3400268554688,
#  'high': 606.4525146484375,
#  'low': 604.5800170898438,
#  'open': 604.77001953125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 6, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 6605760}
# {'_id': ObjectId('67bc8238cf828636c3756583'),
#  'close': 604.7650146484375,
#  'high': 604.8200073242188,
#  'low': 602.6300048828125,
#  'open': 604.5800170898438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 6, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 5268618}
# {'_id': ObjectId('67bc8238cf828636c3756584'),
#  'close': 604.5599975585938,
#  'high': 605.7899780273438,
#  'low': 604.3599853515625,
#  'open': 605.5800170898438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 6, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2839418}
# {'_id': ObjectId('67bc8238cf828636c3756585'),
#  'close': 605.5900268554688,
#  'high': 605.989990234375,
#  'low': 604.8599853515625,
#  'open': 605.1400146484375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 6, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 1936391}
# {'_id': ObjectId('67bc8238cf828636c3756586'),
#  'close': 605.1400146484375,
#  'high': 605.6300048828125,
#  'low': 604.75,
#  'open': 605.5499877929688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 6, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2002226}
# {'_id': ObjectId('67bc8238cf828636c3756587'),
#  'close': 605.530029296875,
#  'high': 605.75,
#  'low': 604.1599731445312,
#  'open': 604.9400024414062,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 6, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2859219}
# {'_id': ObjectId('67bc8238cf828636c3756588'),
#  'close': 604.9400024414062,
#  'high': 606.0999755859375,
#  'low': 604.8300170898438,
#  'open': 605.989990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 6, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 5220066}
# {'_id': ObjectId('67bc8238cf828636c3756589'),
#  'close': 604.1500244140625,
#  'high': 604.3699951171875,
#  'low': 602.9099731445312,
#  'open': 603.719970703125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 5, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 5066503}
# {'_id': ObjectId('67bc8238cf828636c375658a'),
#  'close': 603.72998046875,
#  'high': 603.969970703125,
#  'low': 602.8800048828125,
#  'open': 603.2899780273438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 5, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3207870}
# {'_id': ObjectId('67bc8238cf828636c375658b'),
#  'close': 603.27001953125,
#  'high': 603.635009765625,
#  'low': 602.3900146484375,
#  'open': 602.5599975585938,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 5, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 1921265}
# {'_id': ObjectId('67bc8238cf828636c375658c'),
#  'close': 602.5659790039062,
#  'high': 602.9000244140625,
#  'low': 602.2100219726562,
#  'open': 602.5,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 5, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 1422477}
# {'_id': ObjectId('67bc8238cf828636c375658d'),
#  'close': 602.489990234375,
#  'high': 603.1699829101562,
#  'low': 601.125,
#  'open': 601.239990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 5, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4233551}
# {'_id': ObjectId('67bc8238cf828636c375658e'),
#  'close': 601.27001953125,
#  'high': 601.4000244140625,
#  'low': 599.77001953125,
#  'open': 600.6199951171875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 5, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2769162}
# {'_id': ObjectId('67bc8238cf828636c375658f'),
#  'close': 600.6300048828125,
#  'high': 601.0999755859375,
#  'low': 598.5800170898438,
#  'open': 600.6400146484375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 5, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 6421276}
# {'_id': ObjectId('67bc8238cf828636c3756590'),
#  'close': 601.7550048828125,
#  'high': 602.27001953125,
#  'low': 600.969970703125,
#  'open': 601.0850219726562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 4, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 5774958}
# {'_id': ObjectId('67bc8238cf828636c3756591'),
#  'close': 601.0850219726562,
#  'high': 602.2999877929688,
#  'low': 600.8400268554688,
#  'open': 601.8800048828125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 4, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4026723}
# {'_id': ObjectId('67bc8238cf828636c3756592'),
#  'close': 601.8599853515625,
#  'high': 602.1400146484375,
#  'low': 600.5700073242188,
#  'open': 601.1199951171875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 4, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 1799422}
# {'_id': ObjectId('67bc8238cf828636c3756593'),
#  'close': 601.1300048828125,
#  'high': 601.25,
#  'low': 599.4053955078125,
#  'open': 599.8200073242188,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 4, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2218369}
# {'_id': ObjectId('67bc8238cf828636c3756594'),
#  'close': 599.760009765625,
#  'high': 602.0900268554688,
#  'low': 599.6699829101562,
#  'open': 601.9600219726562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 4, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3341385}
# {'_id': ObjectId('67bc8238cf828636c3756595'),
#  'close': 601.97998046875,
#  'high': 602.010009765625,
#  'low': 600.1099853515625,
#  'open': 600.5499877929688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 4, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3564932}
# {'_id': ObjectId('67bc8238cf828636c3756596'),
#  'close': 600.52001953125,
#  'high': 601.1400146484375,
#  'low': 597.280029296875,
#  'open': 597.8300170898438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 4, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 7413522}
# {'_id': ObjectId('67bc8238cf828636c3756597'),
#  'close': 597.6400146484375,
#  'high': 599.0499877929688,
#  'low': 597.3900146484375,
#  'open': 598.5599975585938,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 3, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 8486548}
# {'_id': ObjectId('67bc8238cf828636c3756598'),
#  'close': 598.5499877929688,
#  'high': 600.2899780273438,
#  'low': 598.4000244140625,
#  'open': 599.4849853515625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 3, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3962284}
# {'_id': ObjectId('67bc8238cf828636c3756599'),
#  'close': 599.47998046875,
#  'high': 600.0,
#  'low': 597.4201049804688,
#  'open': 597.8699951171875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 3, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4564312}
# {'_id': ObjectId('67bc8238cf828636c375659a'),
#  'close': 597.7949829101562,
#  'high': 598.260009765625,
#  'low': 595.969970703125,
#  'open': 597.3900146484375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 3, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 5810092}
# {'_id': ObjectId('67bc8238cf828636c375659b'),
#  'close': 597.4000244140625,
#  'high': 599.010009765625,
#  'low': 596.6900024414062,
#  'open': 597.8699951171875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 3, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 5408068}
# {'_id': ObjectId('67bc8238cf828636c375659c'),
#  'close': 597.8699951171875,
#  'high': 599.25,
#  'low': 592.4400024414062,
#  'open': 596.3800048828125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 3, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 9366779}
# {'_id': ObjectId('67bc8238cf828636c375659d'),
#  'close': 596.3800048828125,
#  'high': 596.5999755859375,
#  'low': 590.489990234375,
#  'open': 592.6699829101562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 2, 3, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 19402094}
# {'_id': ObjectId('67bc8238cf828636c375659e'),
#  'close': 601.7999877929688,
#  'high': 603.27001953125,
#  'low': 601.0499877929688,
#  'open': 601.6699829101562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 31, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 11871932}
# {'_id': ObjectId('67bc8238cf828636c375659f'),
#  'close': 601.6688842773438,
#  'high': 605.1300048828125,
#  'low': 601.3699951171875,
#  'open': 604.52001953125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 31, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 10985684}
# {'_id': ObjectId('67bc8238cf828636c37565a0'),
#  'close': 604.530029296875,
#  'high': 607.030029296875,
#  'low': 603.2999877929688,
#  'open': 606.8200073242188,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 31, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 10174398}
# {'_id': ObjectId('67bc8238cf828636c37565a1'),
#  'close': 606.8483276367188,
#  'high': 609.72998046875,
#  'low': 606.6900024414062,
#  'open': 609.5449829101562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 31, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4465678}
# {'_id': ObjectId('67bc8238cf828636c37565a2'),
#  'close': 609.5499877929688,
#  'high': 609.5499877929688,
#  'low': 608.010009765625,
#  'open': 609.0900268554688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 31, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3769483}
# {'_id': ObjectId('67bc8238cf828636c37565a3'),
#  'close': 609.0900268554688,
#  'high': 609.9600219726562,
#  'low': 608.8499755859375,
#  'open': 608.9600219726562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 31, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4039791}
# {'_id': ObjectId('67bc8238cf828636c37565a4'),
#  'close': 608.9598999023438,
#  'high': 609.02001953125,
#  'low': 607.0599975585938,
#  'open': 607.5,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 31, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 6898171}
# {'_id': ObjectId('67bc8238cf828636c37565a5'),
#  'close': 604.969970703125,
#  'high': 606.3200073242188,
#  'low': 601.8200073242188,
#  'open': 606.2899780273438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 30, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 11088596}
# {'_id': ObjectId('67bc8238cf828636c37565a6'),
#  'close': 606.3099975585938,
#  'high': 606.5999755859375,
#  'low': 604.5900268554688,
#  'open': 604.9500122070312,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 30, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3805957}
# {'_id': ObjectId('67bc8238cf828636c37565a7'),
#  'close': 604.9567260742188,
#  'high': 605.219970703125,
#  'low': 603.9400024414062,
#  'open': 603.9849853515625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 30, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2577943}
# {'_id': ObjectId('67bc8238cf828636c37565a8'),
#  'close': 604.0,
#  'high': 604.3099975585938,
#  'low': 602.1599731445312,
#  'open': 602.3900146484375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 30, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2034099}
# {'_id': ObjectId('67bc8238cf828636c37565a9'),
#  'close': 602.3699951171875,
#  'high': 604.3400268554688,
#  'low': 602.0800170898438,
#  'open': 603.0220947265625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 30, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3005783}
# {'_id': ObjectId('67bc8238cf828636c37565aa'),
#  'close': 602.52001953125,
#  'high': 603.8800048828125,
#  'low': 600.7150268554688,
#  'open': 602.3300170898438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 30, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4066330}
# {'_id': ObjectId('67bc8238cf828636c37565ab'),
#  'close': 602.6300048828125,
#  'high': 605.97998046875,
#  'low': 602.4099731445312,
#  'open': 603.9600219726562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 30, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 6657977}
# {'_id': ObjectId('67bc8238cf828636c37565ac'),
#  'close': 601.7999877929688,
#  'high': 603.6599731445312,
#  'low': 600.739990234375,
#  'open': 603.3599853515625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 29, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4985317}
# {'_id': ObjectId('67bc8238cf828636c37565ad'),
#  'close': 603.3499755859375,
#  'high': 603.6801147460938,
#  'low': 599.25,
#  'open': 599.3900146484375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 29, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 7629951}
# {'_id': ObjectId('67bc8238cf828636c37565ae'),
#  'close': 599.4000244140625,
#  'high': 602.6300048828125,
#  'low': 599.219970703125,
#  'open': 602.3300170898438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 29, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4716556}
# {'_id': ObjectId('67bc8238cf828636c37565af'),
#  'close': 602.3099975585938,
#  'high': 603.3200073242188,
#  'low': 599.6599731445312,
#  'open': 603.0599975585938,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 29, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3173554}
# {'_id': ObjectId('67bc8238cf828636c37565b0'),
#  'close': 603.0549926757812,
#  'high': 603.4600219726562,
#  'low': 601.9299926757812,
#  'open': 602.5,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 29, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 1873916}
# {'_id': ObjectId('67bc8238cf828636c37565b1'),
#  'close': 602.4600219726562,
#  'high': 603.5,
#  'low': 602.2100219726562,
#  'open': 603.010009765625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 29, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2431254}
# {'_id': ObjectId('67bc8238cf828636c37565b2'),
#  'close': 602.97998046875,
#  'high': 604.1300048828125,
#  'low': 602.4451293945312,
#  'open': 603.719970703125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 29, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4791744}
# {'_id': ObjectId('67bc8238cf828636c37565b3'),
#  'close': 604.489990234375,
#  'high': 605.22998046875,
#  'low': 604.3599853515625,
#  'open': 605.0700073242188,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 28, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 7053020}
# {'_id': ObjectId('67bc8238cf828636c37565b4'),
#  'close': 605.0900268554688,
#  'high': 605.3699951171875,
#  'low': 604.0599975585938,
#  'open': 604.0599975585938,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 28, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3854939}
# {'_id': ObjectId('67bc8238cf828636c37565b5'),
#  'close': 604.0399780273438,
#  'high': 604.4600219726562,
#  'low': 603.22998046875,
#  'open': 604.3599853515625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 28, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3277316}
# {'_id': ObjectId('67bc8238cf828636c37565b6'),
#  'close': 604.1798706054688,
#  'high': 604.7899780273438,
#  'low': 603.2899780273438,
#  'open': 603.7899780273438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 28, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3259145}
# {'_id': ObjectId('67bc8238cf828636c37565b7'),
#  'close': 603.7200927734375,
#  'high': 603.9199829101562,
#  'low': 600.9500122070312,
#  'open': 601.3400268554688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 28, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4072209}
# {'_id': ObjectId('67bc8238cf828636c37565b8'),
#  'close': 601.4199829101562,
#  'high': 603.5700073242188,
#  'low': 601.030029296875,
#  'open': 602.489990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 28, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 6736372}
# {'_id': ObjectId('67bc8238cf828636c37565b9'),
#  'close': 602.4600219726562,
#  'high': 602.7899780273438,
#  'low': 597.25,
#  'open': 600.6199951171875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 28, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 8905366}
# {'_id': ObjectId('67bc8238cf828636c37565ba'),
#  'close': 599.4099731445312,
#  'high': 599.5700073242188,
#  'low': 597.1500244140625,
#  'open': 597.4600219726562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 27, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 10318651}
# {'_id': ObjectId('67bc8238cf828636c37565bb'),
#  'close': 597.4400024414062,
#  'high': 598.989990234375,
#  'low': 596.27001953125,
#  'open': 598.9849853515625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 27, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 7700993}
# {'_id': ObjectId('67bc8238cf828636c37565bc'),
#  'close': 599.010009765625,
#  'high': 599.1199951171875,
#  'low': 596.0700073242188,
#  'open': 596.1099853515625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 27, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4838647}
# {'_id': ObjectId('67bc8238cf828636c37565bd'),
#  'close': 596.125,
#  'high': 598.2100219726562,
#  'low': 596.030029296875,
#  'open': 597.6417846679688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 27, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4033350}
# {'_id': ObjectId('67bc8238cf828636c37565be'),
#  'close': 597.6500244140625,
#  'high': 598.0399780273438,
#  'low': 596.2000122070312,
#  'open': 596.5,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 27, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 5497701}
# {'_id': ObjectId('67bc8238cf828636c37565bf'),
#  'close': 596.510009765625,
#  'high': 599.6900024414062,
#  'low': 596.2899780273438,
#  'open': 598.989990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 27, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 7647264}
# {'_id': ObjectId('67bc8238cf828636c37565c0'),
#  'close': 599.0,
#  'high': 599.2100219726562,
#  'low': 594.6400146484375,
#  'open': 594.8099975585938,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 27, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 19726133}
# {'_id': ObjectId('67bc8238cf828636c37565c1'),
#  'close': 607.9299926757812,
#  'high': 608.1500244140625,
#  'low': 606.7999877929688,
#  'open': 607.0800170898438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 24, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 6412163}
# {'_id': ObjectId('67bc8238cf828636c37565c2'),
#  'close': 607.0700073242188,
#  'high': 607.9199829101562,
#  'low': 606.9400024414062,
#  'open': 607.4000244140625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 24, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4125498}
# {'_id': ObjectId('67bc8238cf828636c37565c3'),
#  'close': 607.4299926757812,
#  'high': 608.739990234375,
#  'low': 606.9299926757812,
#  'open': 608.4299926757812,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 24, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3345671}
# {'_id': ObjectId('67bc8238cf828636c37565c4'),
#  'close': 608.4450073242188,
#  'high': 609.6199951171875,
#  'low': 608.0800170898438,
#  'open': 609.4249877929688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 24, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3126556}
# {'_id': ObjectId('67bc8238cf828636c37565c5'),
#  'close': 609.4299926757812,
#  'high': 610.3250122070312,
#  'low': 609.2999877929688,
#  'open': 609.8800048828125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 24, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2331694}
# {'_id': ObjectId('67bc8238cf828636c37565c6'),
#  'close': 609.8897705078125,
#  'high': 609.8897705078125,
#  'low': 609.0599975585938,
#  'open': 609.3499755859375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 24, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3394398}
# {'_id': ObjectId('67bc8238cf828636c37565c7'),
#  'close': 609.3499755859375,
#  'high': 610.780029296875,
#  'low': 609.25,
#  'open': 609.8099975585938,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 24, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 5714331}
# {'_id': ObjectId('67bc8238cf828636c37565c8'),
#  'close': 609.7100219726562,
#  'high': 609.739990234375,
#  'low': 607.6900024414062,
#  'open': 608.0900268554688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 23, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 6680471}
# {'_id': ObjectId('67bc8238cf828636c37565c9'),
#  'close': 608.094970703125,
#  'high': 608.27001953125,
#  'low': 607.5999755859375,
#  'open': 607.6699829101562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 23, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3238089}
# {'_id': ObjectId('67bc8238cf828636c37565ca'),
#  'close': 607.6599731445312,
#  'high': 608.25,
#  'low': 607.3099975585938,
#  'open': 608.0,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 23, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2240640}
# {'_id': ObjectId('67bc8238cf828636c37565cb'),
#  'close': 607.9849853515625,
#  'high': 608.2999877929688,
#  'low': 606.9000244140625,
#  'open': 607.1699829101562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 23, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3158231}
# {'_id': ObjectId('67bc8238cf828636c37565cc'),
#  'close': 607.1699829101562,
#  'high': 607.8699951171875,
#  'low': 606.9400024414062,
#  'open': 607.5,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 23, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 5748200}
# {'_id': ObjectId('67bc8238cf828636c37565cd'),
#  'close': 607.510009765625,
#  'high': 607.5499877929688,
#  'low': 605.6500244140625,
#  'open': 605.719970703125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 23, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4071470}
# {'_id': ObjectId('67bc8238cf828636c37565ce'),
#  'close': 605.72998046875,
#  'high': 606.2999877929688,
#  'low': 605.52001953125,
#  'open': 605.7999877929688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 23, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4504838}
# {'_id': ObjectId('67bc8238cf828636c37565cf'),
#  'close': 606.3400268554688,
#  'high': 607.3499755859375,
#  'low': 606.22998046875,
#  'open': 607.1199951171875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 22, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 8699716}
# {'_id': ObjectId('67bc8238cf828636c37565d0'),
#  'close': 607.1199951171875,
#  'high': 607.6199951171875,
#  'low': 606.7800903320312,
#  'open': 606.9099731445312,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 22, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3100757}
# {'_id': ObjectId('67bc8238cf828636c37565d1'),
#  'close': 606.905029296875,
#  'high': 607.626708984375,
#  'low': 606.8300170898438,
#  'open': 607.0800170898438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 22, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2324170}
# {'_id': ObjectId('67bc8238cf828636c37565d2'),
#  'close': 607.0662841796875,
#  'high': 607.7000122070312,
#  'low': 606.9412231445312,
#  'open': 607.5599975585938,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 22, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2835236}
# {'_id': ObjectId('67bc8238cf828636c37565d3'),
#  'close': 607.5499877929688,
#  'high': 607.8200073242188,
#  'low': 607.1950073242188,
#  'open': 607.2319946289062,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 22, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3346931}
# {'_id': ObjectId('67bc8238cf828636c37565d4'),
#  'close': 607.2374877929688,
#  'high': 607.239990234375,
#  'low': 606.260009765625,
#  'open': 606.719970703125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 22, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 5887257}
# {'_id': ObjectId('67bc8238cf828636c37565d5'),
#  'close': 606.7000122070312,
#  'high': 607.0399780273438,
#  'low': 605.3599853515625,
#  'open': 605.9199829101562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 22, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 8585388}
# {'_id': ObjectId('67bc8238cf828636c37565d6'),
#  'close': 602.9199829101562,
#  'high': 602.97998046875,
#  'low': 602.1500244140625,
#  'open': 602.719970703125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 21, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 7640038}
# {'_id': ObjectId('67bc8238cf828636c37565d7'),
#  'close': 602.7100219726562,
#  'high': 602.780029296875,
#  'low': 601.6699829101562,
#  'open': 602.3800048828125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 21, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4751032}
# {'_id': ObjectId('67bc8238cf828636c37565d8'),
#  'close': 602.3699951171875,
#  'high': 602.8200073242188,
#  'low': 601.9000244140625,
#  'open': 602.5800170898438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 21, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3368563}
# {'_id': ObjectId('67bc8238cf828636c37565d9'),
#  'close': 602.5900268554688,
#  'high': 602.8800048828125,
#  'low': 601.54150390625,
#  'open': 601.5800170898438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 21, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3524912}
# {'_id': ObjectId('67bc8238cf828636c37565da'),
#  'close': 601.5800170898438,
#  'high': 601.780029296875,
#  'low': 600.260009765625,
#  'open': 600.77001953125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 21, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2931193}
# {'_id': ObjectId('67bc8238cf828636c37565db'),
#  'close': 600.780029296875,
#  'high': 600.9400024414062,
#  'low': 599.4299926757812,
#  'open': 600.3300170898438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 21, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3154412}
# {'_id': ObjectId('67bc8238cf828636c37565dc'),
#  'close': 600.35498046875,
#  'high': 601.469970703125,
#  'low': 598.6699829101562,
#  'open': 600.6699829101562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 21, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 8003317}
# {'_id': ObjectId('67bc8238cf828636c37565dd'),
#  'close': 597.5499877929688,
#  'high': 598.5900268554688,
#  'low': 597.3499755859375,
#  'open': 598.094970703125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 17, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 7957779}
# {'_id': ObjectId('67bc8238cf828636c37565de'),
#  'close': 598.0999755859375,
#  'high': 598.7100219726562,
#  'low': 597.530029296875,
#  'open': 598.47998046875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 17, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 5170943}
# {'_id': ObjectId('67bc8238cf828636c37565df'),
#  'close': 598.447021484375,
#  'high': 599.1099853515625,
#  'low': 598.0800170898438,
#  'open': 599.0,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 17, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 5257176}
# {'_id': ObjectId('67bc8238cf828636c37565e0'),
#  'close': 599.030029296875,
#  'high': 599.3599853515625,
#  'low': 598.530029296875,
#  'open': 599.0,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 17, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3740085}
# {'_id': ObjectId('67bc8238cf828636c37565e1'),
#  'close': 598.981201171875,
#  'high': 599.0399780273438,
#  'low': 597.8200073242188,
#  'open': 598.77001953125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 17, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3509840}
# {'_id': ObjectId('67bc8238cf828636c37565e2'),
#  'close': 598.77001953125,
#  'high': 599.0999755859375,
#  'low': 596.780029296875,
#  'open': 596.989990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 17, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 11197582}
# {'_id': ObjectId('67bc8238cf828636c37565e3'),
#  'close': 596.969970703125,
#  'high': 597.5399780273438,
#  'low': 595.6099853515625,
#  'open': 596.9600219726562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 17, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 14259852}
# {'_id': ObjectId('67bc8238cf828636c37565e4'),
#  'close': 591.7000122070312,
#  'high': 593.2000122070312,
#  'low': 591.47998046875,
#  'open': 592.2899780273438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 16, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 6725109}
# {'_id': ObjectId('67bc8238cf828636c37565e5'),
#  'close': 592.2899780273438,
#  'high': 593.3300170898438,
#  'low': 591.9400024414062,
#  'open': 592.469970703125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 16, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4513509}
# {'_id': ObjectId('67bc8238cf828636c37565e6'),
#  'close': 592.4650268554688,
#  'high': 592.6126098632812,
#  'low': 590.9299926757812,
#  'open': 592.260009765625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 16, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4403041}
# {'_id': ObjectId('67bc8238cf828636c37565e7'),
#  'close': 592.260009765625,
#  'high': 593.7999877929688,
#  'low': 592.1099853515625,
#  'open': 593.780029296875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 16, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 1960963}
# {'_id': ObjectId('67bc8238cf828636c37565e8'),
#  'close': 593.780029296875,
#  'high': 593.8099975585938,
#  'low': 591.8200073242188,
#  'open': 593.3400268554688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 16, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2835661}
# {'_id': ObjectId('67bc8238cf828636c37565e9'),
#  'close': 593.360107421875,
#  'high': 594.3499755859375,
#  'low': 591.780029296875,
#  'open': 592.27001953125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 16, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4177925}
# {'_id': ObjectId('67bc8238cf828636c37565ea'),
#  'close': 592.2827758789062,
#  'high': 594.2999877929688,
#  'low': 591.3200073242188,
#  'open': 594.1749877929688,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 16, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 7680051}
# {'_id': ObjectId('67bc8238cf828636c37565eb'),
#  'close': 592.760009765625,
#  'high': 593.8400268554688,
#  'low': 592.6799926757812,
#  'open': 593.6799926757812,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 15, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 10587094}
# {'_id': ObjectId('67bc8238cf828636c37565ec'),
#  'close': 593.6900024414062,
#  'high': 593.9400024414062,
#  'low': 593.02001953125,
#  'open': 593.1199951171875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 15, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 6365535}
# {'_id': ObjectId('67bc8238cf828636c37565ed'),
#  'close': 593.0999755859375,
#  'high': 593.1400146484375,
#  'low': 591.97998046875,
#  'open': 592.2550048828125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 15, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 3105598}
# {'_id': ObjectId('67bc8238cf828636c37565ee'),
#  'close': 592.27001953125,
#  'high': 592.27001953125,
#  'low': 590.8900146484375,
#  'open': 591.1199951171875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 15, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 2652355}
# {'_id': ObjectId('67bc8238cf828636c37565ef'),
#  'close': 591.1199951171875,
#  'high': 591.3800048828125,
#  'low': 589.5,
#  'open': 591.02001953125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 15, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4001330}
# {'_id': ObjectId('67bc8238cf828636c37565f0'),
#  'close': 591.0200805664062,
#  'high': 592.530029296875,
#  'low': 590.7100219726562,
#  'open': 592.4400024414062,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 15, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4694971}
# {'_id': ObjectId('67bc8238cf828636c37565f1'),
#  'close': 592.3300170898438,
#  'high': 592.969970703125,
#  'low': 589.1950073242188,
#  'open': 590.3250122070312,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 15, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 14512387}
# {'_id': ObjectId('67bc8238cf828636c37565f2'),
#  'close': 582.1900024414062,
#  'high': 582.2899780273438,
#  'low': 579.5800170898438,
#  'open': 580.469970703125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 14, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 7537574}
# {'_id': ObjectId('67bc8238cf828636c37565f3'),
#  'close': 580.489990234375,
#  'high': 583.739990234375,
#  'low': 578.9000244140625,
#  'open': 583.0399780273438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 14, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 5815486}
# {'_id': ObjectId('67bc8238cf828636c37565f4'),
#  'close': 583.0399780273438,
#  'high': 583.8099975585938,
#  'low': 581.7899780273438,
#  'open': 582.02001953125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 14, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 5136583}
# {'_id': ObjectId('67bc8238cf828636c37565f5'),
#  'close': 582.02001953125,
#  'high': 582.2369995117188,
#  'low': 578.3499755859375,
#  'open': 579.7100219726562,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 14, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4224093}
# {'_id': ObjectId('67bc8238cf828636c37565f6'),
#  'close': 579.719970703125,
#  'high': 581.4000244140625,
#  'low': 578.5700073242188,
#  'open': 580.8300170898438,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2025, 1, 14, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 5171613}
# {'_id': ObjectId('67bc8238cf828636c37565f7'),
#  'close': 580.8599853515625,
#  'high': 583.5590209960938,
#  'low': 580.1799926757812,
#  'open': 583.1751708984375,
#  'symbol': 'SPY-USD',
# ...
# {'_id': ObjectId('67bc8238cf828636c3756ccd'),
#  'close': 474.75,
#  'high': 475.0400085449219,
#  'low': 472.9599914550781,
#  'open': 472.9599914550781,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 11, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 8047199}
# {'_id': ObjectId('67bc8238cf828636c3756cce'),
#  'close': 472.94000244140625,
#  'high': 473.6189880371094,
#  'low': 472.260009765625,
#  'open': 473.04998779296875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 11, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 9033453}
# {'_id': ObjectId('67bc8238cf828636c3756ccf'),
#  'close': 473.04998779296875,
#  'high': 475.57000732421875,
#  'low': 472.5199890136719,
#  'open': 474.989990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 11, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 10100121}
# {'_id': ObjectId('67bc8238cf828636c3756cd0'),
#  'close': 475.0,
#  'high': 478.1199951171875,
#  'low': 473.57000732421875,
#  'open': 477.5899963378906,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 11, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 18710378}
# {'_id': ObjectId('67bc8238cf828636c3756cd1'),
#  'close': 476.5199890136719,
#  'high': 476.8399963378906,
#  'low': 475.17999267578125,
#  'open': 476.239990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 10, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 10955168}
# {'_id': ObjectId('67bc8238cf828636c3756cd2'),
#  'close': 476.2200012207031,
#  'high': 477.4480895996094,
#  'low': 475.885009765625,
#  'open': 476.6199951171875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 10, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 11225715}
# {'_id': ObjectId('67bc8238cf828636c3756cd3'),
#  'close': 476.6199951171875,
#  'high': 476.8299865722656,
#  'low': 475.2301025390625,
#  'open': 475.30999755859375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 10, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 6882808}
# {'_id': ObjectId('67bc8238cf828636c3756cd4'),
#  'close': 475.29998779296875,
#  'high': 475.9299011230469,
#  'low': 474.8100891113281,
#  'open': 475.1300048828125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 10, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 6341304}
# {'_id': ObjectId('67bc8238cf828636c3756cd5'),
#  'close': 475.1199951171875,
#  'high': 475.17999267578125,
#  'low': 474.4800109863281,
#  'open': 474.7900085449219,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 10, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4659149}
# {'_id': ObjectId('67bc8238cf828636c3756cd6'),
#  'close': 474.7799987792969,
#  'high': 475.2749938964844,
#  'low': 474.42498779296875,
#  'open': 474.70001220703125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 10, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 6585072}
# {'_id': ObjectId('67bc8238cf828636c3756cd7'),
#  'close': 474.70001220703125,
#  'high': 475.3399963378906,
#  'low': 473.8699951171875,
#  'open': 474.1600036621094,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 10, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 9892395}
# {'_id': ObjectId('67bc8238cf828636c3756cd8'),
#  'close': 473.8500061035156,
#  'high': 474.20001220703125,
#  'low': 472.92999267578125,
#  'open': 473.7650146484375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 9, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 12758416}
# {'_id': ObjectId('67bc8238cf828636c3756cd9'),
#  'close': 473.7799987792969,
#  'high': 474.25,
#  'low': 473.19000244140625,
#  'open': 473.6000061035156,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 9, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 6075632}
# {'_id': ObjectId('67bc8238cf828636c3756cda'),
#  'close': 473.5950012207031,
#  'high': 474.6698913574219,
#  'low': 473.1499938964844,
#  'open': 473.80999755859375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 9, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 7002378}
# {'_id': ObjectId('67bc8238cf828636c3756cdb'),
#  'close': 473.79998779296875,
#  'high': 474.92999267578125,
#  'low': 473.7550048828125,
#  'open': 474.239990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 9, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 5510511}
# {'_id': ObjectId('67bc8238cf828636c3756cdc'),
#  'close': 474.2300109863281,
#  'high': 474.375,
#  'low': 473.0799865722656,
#  'open': 473.2900085449219,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 9, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 5918919}
# {'_id': ObjectId('67bc8238cf828636c3756cdd'),
#  'close': 473.2850036621094,
#  'high': 473.3399963378906,
#  'low': 472.1600036621094,
#  'open': 472.489990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 9, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 8060549}
# {'_id': ObjectId('67bc8238cf828636c3756cde'),
#  'close': 472.5,
#  'high': 472.9501037597656,
#  'low': 471.3500061035156,
#  'open': 471.8699951171875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 9, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 14245354}
# {'_id': ObjectId('67bc8238cf828636c3756cdf'),
#  'close': 474.55999755859375,
#  'high': 474.75,
#  'low': 473.5799865722656,
#  'open': 473.6600036621094,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 8, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 16777393}
# {'_id': ObjectId('67bc8238cf828636c3756ce0'),
#  'close': 473.6600036621094,
#  'high': 474.0,
#  'low': 472.9800109863281,
#  'open': 472.9800109863281,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 8, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 10714299}
# {'_id': ObjectId('67bc8238cf828636c3756ce1'),
#  'close': 472.9700012207031,
#  'high': 473.0150146484375,
#  'low': 471.3599853515625,
#  'open': 471.375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 8, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 6753249}
# {'_id': ObjectId('67bc8238cf828636c3756ce2'),
#  'close': 471.37969970703125,
#  'high': 471.7200012207031,
#  'low': 470.67999267578125,
#  'open': 470.7550048828125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 8, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4977673}
# {'_id': ObjectId('67bc8238cf828636c3756ce3'),
#  'close': 470.7300109863281,
#  'high': 471.25,
#  'low': 470.3699951171875,
#  'open': 470.4100036621094,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 8, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 7068625}
# {'_id': ObjectId('67bc8238cf828636c3756ce4'),
#  'close': 470.4100036621094,
#  'high': 470.7449951171875,
#  'low': 469.9599914550781,
#  'open': 469.9599914550781,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 8, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 7714603}
# {'_id': ObjectId('67bc8238cf828636c3756ce5'),
#  'close': 469.95001220703125,
#  'high': 470.0199890136719,
#  'low': 468.29998779296875,
#  'open': 468.42999267578125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 8, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 13184327}
# {'_id': ObjectId('67bc8238cf828636c3756ce6'),
#  'close': 467.9599914550781,
#  'high': 468.2900085449219,
#  'low': 466.42999267578125,
#  'open': 466.92999267578125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 5, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 10991713}
# {'_id': ObjectId('67bc8238cf828636c3756ce7'),
#  'close': 466.92999267578125,
#  'high': 468.489990234375,
#  'low': 466.5,
#  'open': 468.20001220703125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 5, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 10134124}
# {'_id': ObjectId('67bc8238cf828636c3756ce8'),
#  'close': 468.2099914550781,
#  'high': 468.9800109863281,
#  'low': 467.8500061035156,
#  'open': 467.85009765625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 5, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 6499628}
# {'_id': ObjectId('67bc8238cf828636c3756ce9'),
#  'close': 467.8599853515625,
#  'high': 467.8999938964844,
#  'low': 466.67999267578125,
#  'open': 467.3800048828125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 5, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 9917632}
# {'_id': ObjectId('67bc8238cf828636c3756cea'),
#  'close': 467.38031005859375,
#  'high': 469.3999938964844,
#  'low': 467.2349853515625,
#  'open': 469.1300048828125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 5, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 10320504}
# {'_id': ObjectId('67bc8238cf828636c3756ceb'),
#  'close': 469.12200927734375,
#  'high': 470.44000244140625,
#  'low': 469.04998779296875,
#  'open': 469.4700012207031,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 5, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 9241724}
# {'_id': ObjectId('67bc8238cf828636c3756cec'),
#  'close': 469.489990234375,
#  'high': 470.4200134277344,
#  'low': 467.1300048828125,
#  'open': 467.489990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 5, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 19179429}
# {'_id': ObjectId('67bc8238cf828636c3756ced'),
#  'close': 467.2699890136719,
#  'high': 468.67950439453125,
#  'low': 467.04998779296875,
#  'open': 468.260009765625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 4, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 19959713}
# {'_id': ObjectId('67bc8238cf828636c3756cee'),
#  'close': 468.2690124511719,
#  'high': 469.0400085449219,
#  'low': 468.07000732421875,
#  'open': 468.57000732421875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 4, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 11836431}
# {'_id': ObjectId('67bc8238cf828636c3756cef'),
#  'close': 468.57989501953125,
#  'high': 469.4700012207031,
#  'low': 468.5096130371094,
#  'open': 469.3299865722656,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 4, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 7022819}
# {'_id': ObjectId('67bc8238cf828636c3756cf0'),
#  'close': 469.3200988769531,
#  'high': 469.6199951171875,
#  'low': 468.6650085449219,
#  'open': 469.6087951660156,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 4, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 4754153}
# {'_id': ObjectId('67bc8238cf828636c3756cf1'),
#  'close': 469.6099853515625,
#  'high': 470.82000732421875,
#  'low': 469.260009765625,
#  'open': 470.6600036621094,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 4, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 6137719}
# {'_id': ObjectId('67bc8238cf828636c3756cf2'),
#  'close': 470.6499938964844,
#  'high': 470.9599914550781,
#  'low': 469.6199951171875,
#  'open': 469.760009765625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 4, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 5975815}
# {'_id': ObjectId('67bc8238cf828636c3756cf3'),
#  'close': 469.7650146484375,
#  'high': 470.1499938964844,
#  'low': 468.1099853515625,
#  'open': 468.29998779296875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 4, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 12633397}
# {'_id': ObjectId('67bc8238cf828636c3756cf4'),
#  'close': 468.7300109863281,
#  'high': 469.7950134277344,
#  'low': 468.1700134277344,
#  'open': 469.2749938964844,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 3, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 18962548}
# {'_id': ObjectId('67bc8238cf828636c3756cf5'),
#  'close': 469.260009765625,
#  'high': 471.17999267578125,
#  'low': 468.9700012207031,
#  'open': 470.95001220703125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 3, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 12079010}
# {'_id': ObjectId('67bc8238cf828636c3756cf6'),
#  'close': 470.94000244140625,
#  'high': 471.19000244140625,
#  'low': 468.95001220703125,
#  'open': 470.3399963378906,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 3, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 11787244}
# {'_id': ObjectId('67bc8238cf828636c3756cf7'),
#  'close': 470.3299865722656,
#  'high': 470.7699890136719,
#  'low': 469.4205017089844,
#  'open': 469.5799865722656,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 3, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 6375672}
# {'_id': ObjectId('67bc8238cf828636c3756cf8'),
#  'close': 469.5799865722656,
#  'high': 469.8299865722656,
#  'low': 468.9700012207031,
#  'open': 469.70001220703125,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 3, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 7616562}
# {'_id': ObjectId('67bc8238cf828636c3756cf9'),
#  'close': 469.7099914550781,
#  'high': 469.92999267578125,
#  'low': 468.7099914550781,
#  'open': 469.489990234375,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 3, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 14067856}
# {'_id': ObjectId('67bc8238cf828636c3756cfa'),
#  'close': 469.5,
#  'high': 470.9599914550781,
#  'low': 469.2200012207031,
#  'open': 470.5,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 3, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 18908272}
# {'_id': ObjectId('67bc8238cf828636c3756cfb'),
#  'close': 472.6000061035156,
#  'high': 472.6700134277344,
#  'low': 470.6700134277344,
#  'open': 470.9049987792969,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 2, 20, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 24786273}
# {'_id': ObjectId('67bc8238cf828636c3756cfc'),
#  'close': 470.9100036621094,
#  'high': 472.05999755859375,
#  'low': 470.489990234375,
#  'open': 471.8599853515625,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 2, 19, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 13662376}
# {'_id': ObjectId('67bc8238cf828636c3756cfd'),
#  'close': 471.8800964355469,
#  'high': 472.9596862792969,
#  'low': 471.5450134277344,
#  'open': 472.6600036621094,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 2, 18, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 9946269}
# {'_id': ObjectId('67bc8238cf828636c3756cfe'),
#  'close': 472.6604919433594,
#  'high': 473.6700134277344,
#  'low': 472.2799987792969,
#  'open': 472.9549865722656,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 2, 17, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 7394613}
# {'_id': ObjectId('67bc8238cf828636c3756cff'),
#  'close': 472.9750061035156,
#  'high': 473.3599853515625,
#  'low': 472.2699890136719,
#  'open': 472.32000732421875,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 2, 16, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 9373953}
# {'_id': ObjectId('67bc8238cf828636c3756d00'),
#  'close': 472.3299865722656,
#  'high': 472.45001220703125,
#  'low': 471.29998779296875,
#  'open': 471.7699890136719,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 2, 15, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 9085308}
# {'_id': ObjectId('67bc8238cf828636c3756d01'),
#  'close': 471.760009765625,
#  'high': 472.79998779296875,
#  'low': 471.3599853515625,
#  'open': 472.5400085449219,
#  'symbol': 'SPY-USD',
#  'timestamp': datetime.datetime(2024, 1, 2, 14, 30, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC')),
#  'volume': 19608168}

# %% [markdown]
# ### Data Aggregation

# %%
# Aggregate the data by hour
# Hourly aggregation to get high, low, open, and close values
hourly_aggregation = db.yfinanceMarketHistoricalData.aggregate([
    {
        "$match": { "symbol": "SPY-USD" }
    },
    {
        "$group": {
            "_id": {
                "symbol": "$symbol",
                "time": {
                    "$dateTrunc": {
                        "date": "$timestamp",
                        "unit": "hour",
                        "binSize": 1
                    }
                }
            },
            "high": { "$max": "$high" },
            "low": { "$min": "$low" },
            "open": { "$first": "$open" },
            "close": { "$last": "$close" }
        }
    },
    {
        "$sort": { "_id.time": 1 }
    }
])

# Store the aggregation result in a list
hourly_results = list(hourly_aggregation)

# Pretty-print the results
for document in hourly_results:
    pprint(document)

# Count the number of documents in the results
print(f"Total documents: {len(hourly_results)}")
# Out:
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 2, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 471.760009765625,
#  'high': 472.79998779296875,
#  'low': 471.3599853515625,
#  'open': 472.5400085449219}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 2, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 472.3299865722656,
#  'high': 472.45001220703125,
#  'low': 471.29998779296875,
#  'open': 471.7699890136719}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 2, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 472.9750061035156,
#  'high': 473.3599853515625,
#  'low': 472.2699890136719,
#  'open': 472.32000732421875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 2, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 472.6604919433594,
#  'high': 473.6700134277344,
#  'low': 472.2799987792969,
#  'open': 472.9549865722656}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 2, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 471.8800964355469,
#  'high': 472.9596862792969,
#  'low': 471.5450134277344,
#  'open': 472.6600036621094}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 2, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 470.9100036621094,
#  'high': 472.05999755859375,
#  'low': 470.489990234375,
#  'open': 471.8599853515625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 2, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 472.6000061035156,
#  'high': 472.6700134277344,
#  'low': 470.6700134277344,
#  'open': 470.9049987792969}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 3, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 469.5,
#  'high': 470.9599914550781,
#  'low': 469.2200012207031,
#  'open': 470.5}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 3, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 469.7099914550781,
#  'high': 469.92999267578125,
#  'low': 468.7099914550781,
#  'open': 469.489990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 3, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 469.5799865722656,
#  'high': 469.8299865722656,
#  'low': 468.9700012207031,
#  'open': 469.70001220703125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 3, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 470.3299865722656,
#  'high': 470.7699890136719,
#  'low': 469.4205017089844,
#  'open': 469.5799865722656}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 3, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 470.94000244140625,
#  'high': 471.19000244140625,
#  'low': 468.95001220703125,
#  'open': 470.3399963378906}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 3, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 469.260009765625,
#  'high': 471.17999267578125,
#  'low': 468.9700012207031,
#  'open': 470.95001220703125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 3, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 468.7300109863281,
#  'high': 469.7950134277344,
#  'low': 468.1700134277344,
#  'open': 469.2749938964844}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 4, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 469.7650146484375,
#  'high': 470.1499938964844,
#  'low': 468.1099853515625,
#  'open': 468.29998779296875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 4, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 470.6499938964844,
#  'high': 470.9599914550781,
#  'low': 469.6199951171875,
#  'open': 469.760009765625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 4, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 469.6099853515625,
#  'high': 470.82000732421875,
#  'low': 469.260009765625,
#  'open': 470.6600036621094}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 4, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 469.3200988769531,
#  'high': 469.6199951171875,
#  'low': 468.6650085449219,
#  'open': 469.6087951660156}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 4, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 468.57989501953125,
#  'high': 469.4700012207031,
#  'low': 468.5096130371094,
#  'open': 469.3299865722656}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 4, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 468.2690124511719,
#  'high': 469.0400085449219,
#  'low': 468.07000732421875,
#  'open': 468.57000732421875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 4, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 467.2699890136719,
#  'high': 468.67950439453125,
#  'low': 467.04998779296875,
#  'open': 468.260009765625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 5, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 469.489990234375,
#  'high': 470.4200134277344,
#  'low': 467.1300048828125,
#  'open': 467.489990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 5, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 469.12200927734375,
#  'high': 470.44000244140625,
#  'low': 469.04998779296875,
#  'open': 469.4700012207031}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 5, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 467.38031005859375,
#  'high': 469.3999938964844,
#  'low': 467.2349853515625,
#  'open': 469.1300048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 5, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 467.8599853515625,
#  'high': 467.8999938964844,
#  'low': 466.67999267578125,
#  'open': 467.3800048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 5, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 468.2099914550781,
#  'high': 468.9800109863281,
#  'low': 467.8500061035156,
#  'open': 467.85009765625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 5, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 466.92999267578125,
#  'high': 468.489990234375,
#  'low': 466.5,
#  'open': 468.20001220703125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 5, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 467.9599914550781,
#  'high': 468.2900085449219,
#  'low': 466.42999267578125,
#  'open': 466.92999267578125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 8, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 469.95001220703125,
#  'high': 470.0199890136719,
#  'low': 468.29998779296875,
#  'open': 468.42999267578125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 8, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 470.4100036621094,
#  'high': 470.7449951171875,
#  'low': 469.9599914550781,
#  'open': 469.9599914550781}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 8, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 470.7300109863281,
#  'high': 471.25,
#  'low': 470.3699951171875,
#  'open': 470.4100036621094}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 8, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 471.37969970703125,
#  'high': 471.7200012207031,
#  'low': 470.67999267578125,
#  'open': 470.7550048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 8, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 472.9700012207031,
#  'high': 473.0150146484375,
#  'low': 471.3599853515625,
#  'open': 471.375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 8, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 473.6600036621094,
#  'high': 474.0,
#  'low': 472.9800109863281,
#  'open': 472.9800109863281}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 8, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 474.55999755859375,
#  'high': 474.75,
#  'low': 473.5799865722656,
#  'open': 473.6600036621094}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 9, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 472.5,
#  'high': 472.9501037597656,
#  'low': 471.3500061035156,
#  'open': 471.8699951171875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 9, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 473.2850036621094,
#  'high': 473.3399963378906,
#  'low': 472.1600036621094,
#  'open': 472.489990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 9, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 474.2300109863281,
#  'high': 474.375,
#  'low': 473.0799865722656,
#  'open': 473.2900085449219}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 9, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 473.79998779296875,
#  'high': 474.92999267578125,
#  'low': 473.7550048828125,
#  'open': 474.239990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 9, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 473.5950012207031,
#  'high': 474.6698913574219,
#  'low': 473.1499938964844,
#  'open': 473.80999755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 9, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 473.7799987792969,
#  'high': 474.25,
#  'low': 473.19000244140625,
#  'open': 473.6000061035156}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 9, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 473.8500061035156,
#  'high': 474.20001220703125,
#  'low': 472.92999267578125,
#  'open': 473.7650146484375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 10, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 474.70001220703125,
#  'high': 475.3399963378906,
#  'low': 473.8699951171875,
#  'open': 474.1600036621094}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 10, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 474.7799987792969,
#  'high': 475.2749938964844,
#  'low': 474.42498779296875,
#  'open': 474.70001220703125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 10, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 475.1199951171875,
#  'high': 475.17999267578125,
#  'low': 474.4800109863281,
#  'open': 474.7900085449219}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 10, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 475.29998779296875,
#  'high': 475.9299011230469,
#  'low': 474.8100891113281,
#  'open': 475.1300048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 10, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 476.6199951171875,
#  'high': 476.8299865722656,
#  'low': 475.2301025390625,
#  'open': 475.30999755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 10, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 476.2200012207031,
#  'high': 477.4480895996094,
#  'low': 475.885009765625,
#  'open': 476.6199951171875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 10, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 476.5199890136719,
#  'high': 476.8399963378906,
#  'low': 475.17999267578125,
#  'open': 476.239990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 11, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 475.0,
#  'high': 478.1199951171875,
#  'low': 473.57000732421875,
#  'open': 477.5899963378906}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 11, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 473.04998779296875,
#  'high': 475.57000732421875,
#  'low': 472.5199890136719,
#  'open': 474.989990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 11, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 472.94000244140625,
#  'high': 473.6189880371094,
#  'low': 472.260009765625,
#  'open': 473.04998779296875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 11, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 474.75,
#  'high': 475.0400085449219,
#  'low': 472.9599914550781,
#  'open': 472.9599914550781}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 11, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 476.1000061035156,
#  'high': 476.2300109863281,
#  'low': 474.610107421875,
#  'open': 474.760009765625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 11, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 475.9100036621094,
#  'high': 476.97900390625,
#  'low': 475.4649963378906,
#  'open': 476.1099853515625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 11, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 476.3299865722656,
#  'high': 476.70001220703125,
#  'low': 475.5400085449219,
#  'open': 475.8999938964844}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 12, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 476.5299987792969,
#  'high': 478.6000061035156,
#  'low': 475.8999938964844,
#  'open': 477.8399963378906}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 12, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 476.5794982910156,
#  'high': 476.91009521484375,
#  'low': 475.2300109863281,
#  'open': 476.5199890136719}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 12, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 475.9200134277344,
#  'high': 476.82000732421875,
#  'low': 475.364990234375,
#  'open': 476.5799865722656}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 12, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 476.6299133300781,
#  'high': 476.760009765625,
#  'low': 475.6099853515625,
#  'open': 475.94000244140625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 12, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 476.9100036621094,
#  'high': 477.3399963378906,
#  'low': 476.4901123046875,
#  'open': 476.6400146484375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 12, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 476.18951416015625,
#  'high': 476.92999267578125,
#  'low': 475.760009765625,
#  'open': 476.909912109375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 12, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 476.6600036621094,
#  'high': 476.8999938964844,
#  'low': 476.0799865722656,
#  'open': 476.2992858886719}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 16, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 475.9200134277344,
#  'high': 476.260009765625,
#  'low': 473.4700012207031,
#  'open': 475.5}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 16, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 475.88031005859375,
#  'high': 476.60980224609375,
#  'low': 474.6099853515625,
#  'open': 475.9200134277344}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 16, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 474.4100036621094,
#  'high': 476.44000244140625,
#  'low': 474.3399963378906,
#  'open': 475.8999938964844}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 16, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 475.0050048828125,
#  'high': 475.2099914550781,
#  'low': 473.8299865722656,
#  'open': 474.2699890136719}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 16, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 473.590087890625,
#  'high': 475.20001220703125,
#  'low': 473.1098937988281,
#  'open': 475.010009765625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 16, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 474.0398864746094,
#  'high': 474.5199890136719,
#  'low': 473.3599853515625,
#  'open': 473.5950012207031}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 16, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 474.94000244140625,
#  'high': 475.05999755859375,
#  'low': 473.7749938964844,
#  'open': 474.04998779296875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 17, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 471.8399963378906,
#  'high': 472.260009765625,
#  'low': 471.04998779296875,
#  'open': 471.7300109863281}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 17, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 472.5,
#  'high': 472.7799987792969,
#  'low': 471.5,
#  'open': 471.82000732421875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 17, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 471.5199890136719,
#  'high': 472.7900085449219,
#  'low': 471.4097900390625,
#  'open': 472.4649963378906}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 17, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 470.69000244140625,
#  'high': 472.0400085449219,
#  'low': 470.45001220703125,
#  'open': 471.5299987792969}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 17, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 471.2149963378906,
#  'high': 471.3999938964844,
#  'low': 469.8699951171875,
#  'open': 470.69000244140625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 17, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 470.87890625,
#  'high': 471.7650146484375,
#  'low': 470.6700134277344,
#  'open': 471.2200012207031}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 17, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 472.2799987792969,
#  'high': 472.6099853515625,
#  'low': 470.8299865722656,
#  'open': 470.8800048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 18, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 474.1600036621094,
#  'high': 474.4700012207031,
#  'low': 473.3900146484375,
#  'open': 474.010009765625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 18, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 474.6866149902344,
#  'high': 474.8800048828125,
#  'low': 473.6600036621094,
#  'open': 474.19500732421875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 18, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 473.5899963378906,
#  'high': 475.0299987792969,
#  'low': 473.0400085449219,
#  'open': 474.69000244140625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 18, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 472.7300109863281,
#  'high': 473.6600036621094,
#  'low': 472.4200134277344,
#  'open': 473.3800048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 18, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 475.6199951171875,
#  'high': 475.6600036621094,
#  'low': 472.70001220703125,
#  'open': 472.9100036621094}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 18, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 476.4100036621094,
#  'high': 476.4100036621094,
#  'low': 474.94000244140625,
#  'open': 475.6199951171875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 18, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 476.4700012207031,
#  'high': 477.05999755859375,
#  'low': 475.8999938964844,
#  'open': 476.4100036621094}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 19, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 477.95001220703125,
#  'high': 478.3840026855469,
#  'low': 476.94000244140625,
#  'open': 477.6499938964844}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 19, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 478.8500061035156,
#  'high': 479.2799987792969,
#  'low': 477.3399963378906,
#  'open': 477.94000244140625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 19, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 479.3500061035156,
#  'high': 479.510009765625,
#  'low': 478.20001220703125,
#  'open': 478.8450012207031}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 19, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 480.9599914550781,
#  'high': 481.0,
#  'low': 479.2799987792969,
#  'open': 479.3301086425781}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 19, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 481.9700012207031,
#  'high': 482.54998779296875,
#  'low': 480.94000244140625,
#  'open': 480.9501037597656}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 19, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 482.1400146484375,
#  'high': 482.54998779296875,
#  'low': 481.3299865722656,
#  'open': 481.9700012207031}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 19, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 482.4100036621094,
#  'high': 482.4800109863281,
#  'low': 481.8349914550781,
#  'open': 482.1000061035156}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 22, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 484.3699951171875,
#  'high': 485.2200012207031,
#  'low': 483.989990234375,
#  'open': 484.0703125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 22, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 484.07000732421875,
#  'high': 484.3999938964844,
#  'low': 482.9599914550781,
#  'open': 484.3800048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 22, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 483.9200134277344,
#  'high': 484.2099914550781,
#  'low': 483.19000244140625,
#  'open': 484.05999755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 22, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 482.8900146484375,
#  'high': 484.0400085449219,
#  'low': 482.7799987792969,
#  'open': 483.92120361328125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 22, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 483.6099853515625,
#  'high': 484.010009765625,
#  'low': 482.8599853515625,
#  'open': 482.8999938964844}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 22, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 484.10009765625,
#  'high': 484.20001220703125,
#  'low': 483.2699890136719,
#  'open': 483.6199951171875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 22, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 483.51019287109375,
#  'high': 484.19000244140625,
#  'low': 483.3699951171875,
#  'open': 484.1050109863281}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 23, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 483.8399963378906,
#  'high': 484.3736877441406,
#  'low': 483.44000244140625,
#  'open': 484.010009765625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 23, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 483.05999755859375,
#  'high': 483.8599853515625,
#  'low': 482.9200134277344,
#  'open': 483.8494873046875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 23, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 483.2300109863281,
#  'high': 483.5474853515625,
#  'low': 482.8900146484375,
#  'open': 483.05999755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 23, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 483.7508850097656,
#  'high': 483.989990234375,
#  'low': 483.0799865722656,
#  'open': 483.2200012207031}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 23, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 483.80999755859375,
#  'high': 484.05999755859375,
#  'low': 483.5613098144531,
#  'open': 483.760009765625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 23, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 484.6499938964844,
#  'high': 484.94000244140625,
#  'low': 483.6400146484375,
#  'open': 483.7449951171875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 23, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 484.8800048828125,
#  'high': 485.1050109863281,
#  'low': 484.3299865722656,
#  'open': 484.6499938964844}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 24, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 487.510009765625,
#  'high': 487.67999267578125,
#  'low': 486.409912109375,
#  'open': 487.44000244140625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 24, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 487.9700012207031,
#  'high': 488.6099853515625,
#  'low': 487.3699951171875,
#  'open': 487.5199890136719}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 24, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 488.3299865722656,
#  'high': 488.5050048828125,
#  'low': 487.67999267578125,
#  'open': 487.9700012207031}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 24, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 488.0299987792969,
#  'high': 488.7699890136719,
#  'low': 487.44000244140625,
#  'open': 488.3399963378906}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 24, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 486.2099914550781,
#  'high': 488.04998779296875,
#  'low': 485.9695129394531,
#  'open': 488.0299987792969}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 24, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 485.5199890136719,
#  'high': 487.07000732421875,
#  'low': 485.3999938964844,
#  'open': 486.2200012207031}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 24, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 485.3599853515625,
#  'high': 486.3999938964844,
#  'low': 485.010009765625,
#  'open': 485.510009765625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 25, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 488.0799865722656,
#  'high': 488.30499267578125,
#  'low': 486.7699890136719,
#  'open': 487.0}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 25, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 487.7799987792969,
#  'high': 488.17010498046875,
#  'low': 486.82000732421875,
#  'open': 488.0899963378906}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 25, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 486.6300048828125,
#  'high': 488.1099853515625,
#  'low': 486.4100036621094,
#  'open': 487.7900085449219}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 25, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 486.27398681640625,
#  'high': 487.30999755859375,
#  'low': 486.0799865722656,
#  'open': 486.6499938964844}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 25, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 486.17498779296875,
#  'high': 486.8399963378906,
#  'low': 485.489990234375,
#  'open': 486.25}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 25, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 486.54998779296875,
#  'high': 486.8999938964844,
#  'low': 485.7900085449219,
#  'open': 486.17999267578125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 25, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 488.0,
#  'high': 488.0400085449219,
#  'low': 486.42498779296875,
#  'open': 486.54998779296875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 26, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 488.1400146484375,
#  'high': 488.3500061035156,
#  'low': 487.0398864746094,
#  'open': 487.5899963378906}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 26, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 488.67999267578125,
#  'high': 489.1199951171875,
#  'low': 488.0589904785156,
#  'open': 488.1400146484375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 26, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 488.3500061035156,
#  'high': 488.8800048828125,
#  'low': 488.1000061035156,
#  'open': 488.6700134277344}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 26, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 487.4200134277344,
#  'high': 488.3599853515625,
#  'low': 486.7099914550781,
#  'open': 488.3500061035156}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 26, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 487.20001220703125,
#  'high': 487.5299987792969,
#  'low': 486.5400085449219,
#  'open': 487.4100036621094}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 26, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 487.4700012207031,
#  'high': 488.1499938964844,
#  'low': 486.94500732421875,
#  'open': 487.2099914550781}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 26, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 487.4599914550781,
#  'high': 487.67999267578125,
#  'low': 487.0249938964844,
#  'open': 487.4750061035156}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 29, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 487.6700134277344,
#  'high': 488.2699890136719,
#  'low': 487.3999938964844,
#  'open': 487.7300109863281}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 29, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 487.739990234375,
#  'high': 487.9198913574219,
#  'low': 487.1700134277344,
#  'open': 487.67999267578125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 29, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 488.239990234375,
#  'high': 488.4800109863281,
#  'low': 487.7300109863281,
#  'open': 487.739990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 29, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 488.4299011230469,
#  'high': 488.5899963378906,
#  'low': 487.8399963378906,
#  'open': 488.239990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 29, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 488.7950134277344,
#  'high': 488.9100036621094,
#  'low': 488.1311950683594,
#  'open': 488.3999938964844}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 29, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 490.92999267578125,
#  'high': 491.4150085449219,
#  'low': 488.7099914550781,
#  'open': 488.739990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 29, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 491.260009765625,
#  'high': 491.364990234375,
#  'low': 490.3800048828125,
#  'open': 490.94000244140625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 30, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 490.7497863769531,
#  'high': 491.3595886230469,
#  'low': 490.3399963378906,
#  'open': 490.55999755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 30, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 491.05999755859375,
#  'high': 491.1300048828125,
#  'low': 490.3399963378906,
#  'open': 490.760009765625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 30, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 490.55999755859375,
#  'high': 491.4800109863281,
#  'low': 490.5299987792969,
#  'open': 491.07000732421875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 30, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 490.91400146484375,
#  'high': 490.95001220703125,
#  'low': 490.1300048828125,
#  'open': 490.55999755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 30, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 491.2300109863281,
#  'high': 491.260009765625,
#  'low': 490.4599914550781,
#  'open': 490.9200134277344}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 30, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 491.3699951171875,
#  'high': 491.6199951171875,
#  'low': 490.95001220703125,
#  'open': 491.2300109863281}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 30, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 490.8599853515625,
#  'high': 491.44000244140625,
#  'low': 490.7200012207031,
#  'open': 491.375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 31, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 487.29998779296875,
#  'high': 489.081298828125,
#  'low': 487.17999267578125,
#  'open': 488.6199951171875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 31, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 487.0299987792969,
#  'high': 487.4800109863281,
#  'low': 486.3900146484375,
#  'open': 487.30999755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 31, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 487.3382873535156,
#  'high': 487.4100036621094,
#  'low': 486.3399963378906,
#  'open': 487.0400085449219}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 31, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 487.20001220703125,
#  'high': 487.67498779296875,
#  'low': 486.55999755859375,
#  'open': 487.3399963378906}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 31, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 486.1400146484375,
#  'high': 487.8299865722656,
#  'low': 485.6300048828125,
#  'open': 487.2099914550781}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 31, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 484.68499755859375,
#  'high': 489.0,
#  'low': 483.67999267578125,
#  'open': 486.1499938964844}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 1, 31, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 482.9200134277344,
#  'high': 484.44000244140625,
#  'low': 482.8999938964844,
#  'open': 484.30999755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 1, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 486.17999267578125,
#  'high': 486.2049865722656,
#  'low': 484.260009765625,
#  'open': 485.25}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 1, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 484.57000732421875,
#  'high': 486.2099914550781,
#  'low': 483.79998779296875,
#  'open': 486.17999267578125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 1, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 486.4798889160156,
#  'high': 487.2699890136719,
#  'low': 484.54998779296875,
#  'open': 484.54998779296875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 1, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 487.0199890136719,
#  'high': 488.239990234375,
#  'low': 486.2099914550781,
#  'open': 486.4599914550781}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 1, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 487.44000244140625,
#  'high': 487.95001220703125,
#  'low': 486.3800048828125,
#  'open': 487.0400085449219}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 1, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 488.69000244140625,
#  'high': 488.989990234375,
#  'low': 487.0799865722656,
#  'open': 487.44000244140625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 1, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 489.2300109863281,
#  'high': 489.2300109863281,
#  'low': 488.1000061035156,
#  'open': 488.7900085449219}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 2, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 490.8500061035156,
#  'high': 491.3349914550781,
#  'low': 489.29998779296875,
#  'open': 489.6499938964844}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 2, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 492.9200134277344,
#  'high': 493.07000732421875,
#  'low': 490.3399963378906,
#  'open': 490.8599853515625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 2, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 494.3699951171875,
#  'high': 494.45001220703125,
#  'low': 492.9200134277344,
#  'open': 492.9200134277344}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 2, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 493.75,
#  'high': 494.6600036621094,
#  'low': 492.25,
#  'open': 494.3800048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 2, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 494.95001220703125,
#  'high': 495.3900146484375,
#  'low': 493.3139953613281,
#  'open': 493.75}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 2, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 495.8949890136719,
#  'high': 496.04998779296875,
#  'low': 494.8999938964844,
#  'open': 494.989990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 2, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 494.2699890136719,
#  'high': 495.9100036621094,
#  'low': 494.260009765625,
#  'open': 495.9049987792969}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 5, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 491.3901062011719,
#  'high': 493.5249938964844,
#  'low': 490.7900085449219,
#  'open': 493.25}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 5, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 491.32501220703125,
#  'high': 491.8299865722656,
#  'low': 490.2300109863281,
#  'open': 491.3999938964844}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 5, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 492.7349853515625,
#  'high': 492.75,
#  'low': 491.3299865722656,
#  'open': 491.3299865722656}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 5, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 492.6000061035156,
#  'high': 493.5,
#  'low': 492.5799865722656,
#  'open': 492.75}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 5, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 493.4800109863281,
#  'high': 493.54998779296875,
#  'low': 492.5799865722656,
#  'open': 492.6099853515625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 5, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 493.6700134277344,
#  'high': 494.1700134277344,
#  'low': 492.5899963378906,
#  'open': 493.4700012207031}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 5, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 492.5799865722656,
#  'high': 493.95001220703125,
#  'low': 492.5199890136719,
#  'open': 493.6600036621094}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 6, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 492.5,
#  'high': 494.32000732421875,
#  'low': 492.04998779296875,
#  'open': 493.5199890136719}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 6, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 493.2900085449219,
#  'high': 493.42999267578125,
#  'low': 492.42999267578125,
#  'open': 492.6099853515625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 6, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 492.8799133300781,
#  'high': 493.4100036621094,
#  'low': 492.1000061035156,
#  'open': 493.30999755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 6, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 492.9200134277344,
#  'high': 493.0799865722656,
#  'low': 492.4100036621094,
#  'open': 492.8399963378906}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 6, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 492.4999084472656,
#  'high': 493.57000732421875,
#  'low': 492.1099853515625,
#  'open': 492.9549865722656}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 6, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 493.1600036621094,
#  'high': 493.5400085449219,
#  'low': 492.239990234375,
#  'open': 492.5199890136719}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 6, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 493.9700012207031,
#  'high': 494.0400085449219,
#  'low': 492.635009765625,
#  'open': 493.1600036621094}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 7, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 497.95001220703125,
#  'high': 497.9750061035156,
#  'low': 495.3599853515625,
#  'open': 496.2900085449219}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 7, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 497.135009765625,
#  'high': 497.92999267578125,
#  'low': 496.8299865722656,
#  'open': 497.8399963378906}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 7, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 497.3086853027344,
#  'high': 497.8599853515625,
#  'low': 496.8699951171875,
#  'open': 497.1400146484375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 7, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 498.20001220703125,
#  'high': 498.2049865722656,
#  'low': 496.7900085449219,
#  'open': 497.32000732421875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 7, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 497.95001220703125,
#  'high': 498.42999267578125,
#  'low': 497.6600036621094,
#  'open': 498.2099914550781}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 7, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 498.1499938964844,
#  'high': 498.5299987792969,
#  'low': 497.7900085449219,
#  'open': 497.9599914550781}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 7, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 498.04998779296875,
#  'high': 498.2699890136719,
#  'low': 497.6099853515625,
#  'open': 498.1499938964844}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 8, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 497.8500061035156,
#  'high': 498.3500061035156,
#  'low': 497.6300048828125,
#  'open': 498.1000061035156}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 8, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 497.3500061035156,
#  'high': 498.2099914550781,
#  'low': 497.30999755859375,
#  'open': 497.8349914550781}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 8, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 498.0350036621094,
#  'high': 498.1400146484375,
#  'low': 497.260009765625,
#  'open': 497.3500061035156}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 8, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 498.0450134277344,
#  'high': 498.2799987792969,
#  'low': 497.4200134277344,
#  'open': 498.0350036621094}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 8, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 497.8310852050781,
#  'high': 498.3399963378906,
#  'low': 497.7799987792969,
#  'open': 498.0400085449219}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 8, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 498.4150085449219,
#  'high': 498.5849914550781,
#  'low': 497.5801086425781,
#  'open': 497.8299865722656}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 8, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 498.3999938964844,
#  'high': 498.7099914550781,
#  'low': 497.8599853515625,
#  'open': 498.4200134277344}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 9, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 499.6488037109375,
#  'high': 499.7900085449219,
#  'low': 498.489990234375,
#  'open': 498.8399963378906}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 9, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 499.75,
#  'high': 500.2099914550781,
#  'low': 499.5199890136719,
#  'open': 499.6600036621094}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 9, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 500.1300048828125,
#  'high': 500.1300048828125,
#  'low': 499.3699951171875,
#  'open': 499.760009765625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 9, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 500.7349853515625,
#  'high': 500.8299865722656,
#  'low': 499.8299865722656,
#  'open': 500.1300048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2024, 2, 9, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 501.05999755859375,
#  'high': 501.1499938964844,
#  'low': 500.4800109863281,
#  'open': 500.75}
# {'_id': {'symbol': 'SPY-USD',
# ...
#  'open': 597.8699951171875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 3, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 598.5499877929688,
#  'high': 600.2899780273438,
#  'low': 598.4000244140625,
#  'open': 599.4849853515625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 3, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 597.6400146484375,
#  'high': 599.0499877929688,
#  'low': 597.3900146484375,
#  'open': 598.5599975585938}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 4, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.52001953125,
#  'high': 601.1400146484375,
#  'low': 597.280029296875,
#  'open': 597.8300170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 4, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 601.97998046875,
#  'high': 602.010009765625,
#  'low': 600.1099853515625,
#  'open': 600.5499877929688}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 4, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 599.760009765625,
#  'high': 602.0900268554688,
#  'low': 599.6699829101562,
#  'open': 601.9600219726562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 4, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 601.1300048828125,
#  'high': 601.25,
#  'low': 599.4053955078125,
#  'open': 599.8200073242188}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 4, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 601.8599853515625,
#  'high': 602.1400146484375,
#  'low': 600.5700073242188,
#  'open': 601.1199951171875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 4, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 601.0850219726562,
#  'high': 602.2999877929688,
#  'low': 600.8400268554688,
#  'open': 601.8800048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 4, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 601.7550048828125,
#  'high': 602.27001953125,
#  'low': 600.969970703125,
#  'open': 601.0850219726562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 5, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.6300048828125,
#  'high': 601.0999755859375,
#  'low': 598.5800170898438,
#  'open': 600.6400146484375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 5, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 601.27001953125,
#  'high': 601.4000244140625,
#  'low': 599.77001953125,
#  'open': 600.6199951171875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 5, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 602.489990234375,
#  'high': 603.1699829101562,
#  'low': 601.125,
#  'open': 601.239990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 5, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 602.5659790039062,
#  'high': 602.9000244140625,
#  'low': 602.2100219726562,
#  'open': 602.5}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 5, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 603.27001953125,
#  'high': 603.635009765625,
#  'low': 602.3900146484375,
#  'open': 602.5599975585938}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 5, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 603.72998046875,
#  'high': 603.969970703125,
#  'low': 602.8800048828125,
#  'open': 603.2899780273438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 5, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 604.1500244140625,
#  'high': 604.3699951171875,
#  'low': 602.9099731445312,
#  'open': 603.719970703125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 6, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 604.9400024414062,
#  'high': 606.0999755859375,
#  'low': 604.8300170898438,
#  'open': 605.989990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 6, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 605.530029296875,
#  'high': 605.75,
#  'low': 604.1599731445312,
#  'open': 604.9400024414062}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 6, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 605.1400146484375,
#  'high': 605.6300048828125,
#  'low': 604.75,
#  'open': 605.5499877929688}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 6, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 605.5900268554688,
#  'high': 605.989990234375,
#  'low': 604.8599853515625,
#  'open': 605.1400146484375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 6, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 604.5599975585938,
#  'high': 605.7899780273438,
#  'low': 604.3599853515625,
#  'open': 605.5800170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 6, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 604.7650146484375,
#  'high': 604.8200073242188,
#  'low': 602.6300048828125,
#  'open': 604.5800170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 6, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 606.3400268554688,
#  'high': 606.4525146484375,
#  'low': 604.5800170898438,
#  'open': 604.77001953125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 7, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 604.5830078125,
#  'high': 608.1300048828125,
#  'low': 603.77001953125,
#  'open': 606.8900146484375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 7, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 602.0004272460938,
#  'high': 605.5399780273438,
#  'low': 601.1799926757812,
#  'open': 604.5}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 7, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 601.7000122070312,
#  'high': 602.9099731445312,
#  'low': 600.6400146484375,
#  'open': 602.0499877929688}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 7, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 603.3142700195312,
#  'high': 603.75,
#  'low': 601.2999877929688,
#  'open': 601.6099853515625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 7, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.5892944335938,
#  'high': 603.6500244140625,
#  'low': 600.5,
#  'open': 603.3300170898438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 7, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.4000244140625,
#  'high': 601.5999755859375,
#  'low': 600.0499877929688,
#  'open': 600.6090698242188}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 7, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.77001953125,
#  'high': 601.260009765625,
#  'low': 600.3699951171875,
#  'open': 600.3900146484375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 10, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 604.72998046875,
#  'high': 604.7899780273438,
#  'low': 602.739990234375,
#  'open': 604.030029296875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 10, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 604.3099975585938,
#  'high': 605.3300170898438,
#  'low': 604.0499877929688,
#  'open': 604.739990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 10, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 603.6286010742188,
#  'high': 604.4874877929688,
#  'low': 603.2108154296875,
#  'open': 604.3198852539062}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 10, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 604.6799926757812,
#  'high': 604.989990234375,
#  'low': 603.6400146484375,
#  'open': 603.6500244140625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 10, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 605.1900024414062,
#  'high': 605.4998779296875,
#  'low': 604.5599975585938,
#  'open': 604.6801147460938}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 10, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 604.8900146484375,
#  'high': 605.3699951171875,
#  'low': 604.719970703125,
#  'open': 605.1799926757812}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 10, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 604.7899780273438,
#  'high': 605.030029296875,
#  'low': 604.24462890625,
#  'open': 604.8800048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 11, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 604.1500244140625,
#  'high': 604.260009765625,
#  'low': 602.4299926757812,
#  'open': 602.5499877929688}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 11, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 604.5800170898438,
#  'high': 605.219970703125,
#  'low': 604.0,
#  'open': 604.1599731445312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 11, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 604.3200073242188,
#  'high': 604.8900146484375,
#  'low': 603.0999755859375,
#  'open': 604.6199951171875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 11, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 603.9691772460938,
#  'high': 604.4299926757812,
#  'low': 603.5,
#  'open': 604.3400268554688}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 11, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 604.7216186523438,
#  'high': 605.2999877929688,
#  'low': 603.9500122070312,
#  'open': 603.97998046875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 11, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 605.27001953125,
#  'high': 605.8599853515625,
#  'low': 604.7100219726562,
#  'open': 604.719970703125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 11, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 605.2100219726562,
#  'high': 605.5800170898438,
#  'low': 604.6099853515625,
#  'open': 605.280029296875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 12, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 601.4349975585938,
#  'high': 602.3599853515625,
#  'low': 598.510009765625,
#  'open': 599.2000122070312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 12, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 600.659912109375,
#  'high': 603.3200073242188,
#  'low': 600.1699829101562,
#  'open': 601.4439697265625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 12, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 603.7899780273438,
#  'high': 603.989990234375,
#  'low': 600.5999755859375,
#  'open': 600.6300048828125}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 12, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 603.5700073242188,
#  'high': 604.5499877929688,
#  'low': 603.0900268554688,
#  'open': 603.780029296875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 12, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 603.0800170898438,
#  'high': 603.7598876953125,
#  'low': 602.530029296875,
#  'open': 603.5899047851562}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 12, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 603.3200073242188,
#  'high': 604.22998046875,
#  'low': 603.0599975585938,
#  'open': 603.113525390625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 12, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 603.3599853515625,
#  'high': 603.5900268554688,
#  'low': 602.5700073242188,
#  'open': 603.3250122070312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 13, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 606.0800170898438,
#  'high': 606.419921875,
#  'low': 603.2000122070312,
#  'open': 604.47998046875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 13, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 606.6900024414062,
#  'high': 607.489990234375,
#  'low': 606.0,
#  'open': 606.0848999023438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 13, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 606.5399780273438,
#  'high': 606.9600219726562,
#  'low': 605.719970703125,
#  'open': 606.7000122070312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 13, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 606.2000122070312,
#  'high': 606.969970703125,
#  'low': 604.989990234375,
#  'open': 606.5399780273438}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 13, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 608.280029296875,
#  'high': 608.4099731445312,
#  'low': 605.3099975585938,
#  'open': 606.2000122070312}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 13, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.5798950195312,
#  'high': 609.7100219726562,
#  'low': 608.1422119140625,
#  'open': 608.280029296875}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 13, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.6900024414062,
#  'high': 609.9400024414062,
#  'low': 609.0900268554688,
#  'open': 609.5700073242188}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 14, 14, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.239990234375,
#  'high': 610.989990234375,
#  'low': 609.760009765625,
#  'open': 609.9400024414062}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 14, 15, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.989990234375,
#  'high': 610.8499755859375,
#  'low': 609.4000244140625,
#  'open': 610.239990234375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 14, 16, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.3201293945312,
#  'high': 610.2949829101562,
#  'low': 609.27001953125,
#  'open': 610.010009765625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 14, 17, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.9298706054688,
#  'high': 610.0900268554688,
#  'low': 609.0700073242188,
#  'open': 609.3499755859375}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 14, 18, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 610.1300048828125,
#  'high': 610.7506713867188,
#  'low': 609.8800048828125,
#  'open': 609.9299926757812}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 14, 19, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.6699829101562,
#  'high': 610.3024291992188,
#  'low': 609.5900268554688,
#  'open': 610.1500244140625}
# {'_id': {'symbol': 'SPY-USD',
#          'time': datetime.datetime(2025, 2, 14, 20, 0, tzinfo=FixedOffset(datetime.timedelta(0), 'UTC'))},
#  'close': 609.7000122070312,
#  'high': 610.2899780273438,
#  'low': 609.5449829101562,
#  'open': 609.6599731445312}
# Total documents: 1962
